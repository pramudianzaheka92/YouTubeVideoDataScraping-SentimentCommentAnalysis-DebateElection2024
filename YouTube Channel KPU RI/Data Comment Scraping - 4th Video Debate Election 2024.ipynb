# %% [markdown]
# ## 1. Import Libraries for Scraping Data YouTube Comments and Create API based on Google YouTube Data API

# %%
"""
Melakukan proses import library pandas untuk membuat data-data komentar dari hasil web scraping menjadi DataFrame
serta juga meng-import library khusus yang dimiliki oleh Google API Client agar dapat mengambil informasi/data dari
video komentar debat capres-cawapres babak keempat dari channel YouTube KPU RI menggunakan API yang akan didapatkan dari
salah satu service pada Google Cloud Platform yaitu YouTube Data API v3
"""
import pandas as pd
from googleapiclient.discovery import build

# %%
"""
Mendefinisikan resource utama/sumber daya dari Google API Client seperti nama layanan atas API yang digunakan,
kode API dan tipe versi pada nama service yang digunakan sehingga dengan resource tersebut,
Google API dapat melakukan proses pengambilan (scraping) data/informasi pada serangkaian
komentar utama (bukan teks komentar yang bersifat balasan/reply dari suatu komentar) yang ada di dalam video debat
capres-cawapres babak keempat Republik Indonesia tahun 2024 yang di-upload oleh channel YouTube KPU RI menggunakan
API yang telah berhasil dibuat dan didapatkan dari CREDENTIALS YouTube Data API v3 yang ada di dalam Google Cloud Platform
"""

API_Service_Name = "youtube" # Merupakan nama service yang digunakan untuk generate kode API
API_Version_Name = "v3" # Merupakan jenis/tipe versi dari nama service dalam menghasilkan kode API (YouTube Data API v3)
API_Key = "AIzaSyCTEBkjSYN0dPHA95Oipoks9A9b8aIOZb8" # Meng-copy kode API dari CREDENTIALS pada YouTube Data API v3


"""
Menyimpan 3 variabel yang menyimpan resource utama dari Google API Client yang sebelumnya
telah didefinisikan seperti nama service API (API_Version_Name), versi API Youtube yang digunakan (API_Version_Name)
serta kunci/kode API (API_Key) yang telah dibuat dan didapatkan melalui CREDENTIALS
YouTube Data API v3 yang ada di dalam Google Cloud Platform Console yaitu 
dan disimpan di dalam variabel bernama "youtube_scrape_comment_objects"
"""
youtube_scrape_comment_objects = build(API_Service_Name, API_Version_Name, developerKey = API_Key)

# %% [markdown]
# Code script diatas merupakan proses inisialisasi API Key yang telah berhasil didapatkan melalui Google Cloud Platform dengan pilihan service yakni YouTube Data API v3. Maka dari itu nama service API yang digunakan (API_Service_Name) ditulis sebagai "youtube" karena service/layanan Google pada Google Cloud Platform yang digunakan di dalam penelitian kali ini adalah sebuah video yang ter-upload pada media sosial YouTube dan versi API yang digunakan adalah versi ketiga dari API YouTube Data sehingga nilai dari variabel API_Version_Name yang disimpan adalah "v3".
#
# Selain itu, untuk mendapatkan kunci API dari layanan yang bernama "youtube", pertama-tama saya harus masuk ke dalam service YouTube Data API v3 di dalam Google Cloud Platform dan mengaktifkan (enable) service tersebut dan memilih fitur/opsi CREDENTIALS karena API Key berada di dalam fitur tersebut. Jadi dapat disimpulkan kalau untuk membuat API Key agar dapat mengambil data-data yang ada di dalam suatu video YouTube seperti komentar dari 1 video YouTube, Playlist, Subscription, dll., maka terlebih dahulu harus mengaktifkan service YouTube Data API v3 di dalam Google Cloud Platform dan kemudian membuat/generate API Key di dalam opsi CREDENTIALS. Jika API sudah berhasil dibuat, maka kita dapat meng-copy API tersebut untuk diletakkan di dalam variabel. Pada code script diatas, API yang berhasil didapatkan disimpan di dalam variabel yang bernama "API_KEY".
#
# Di samping itu, fungsi build pada library googleapiclient.discovery merupakan sebuah Software Development Kits (SDKs) yang telah disediakan oleh Google agar para developer/scientist dapat mengakses semua layanan berbasis Google melalui API seperti video/konten YouTube, BigQuery, dll. Jadi dapat disimpulkan bahwasanya dengan mendefinisikan nama layanan Google yang akan digunakan dan API yang telah didapatkan berdasarkan layanan yang akan digunakan, maka setiap orang diseluruh dunia dapat mengakses dan mendapatkan data-data atau informasi dunia melalui layanan Google. Seperti pada penelitian kali ini yang sumber datanya merupakan data-data komentar dari video debat babak keempat capres-cawapres yang di-upload oleh channel KPU RI yang ada di dalam media sosial YouTube.

# %% [markdown]
# ## 2. Request Access to Retrieve Main Comments Data Objects on YouTube Video based on API Key, API Service Name, and API Version

# %%
"""
Melakukan proses permintaan kepada Google Client dengan menggunakan API yang sudah
di=generate oleh CREDENTIALS dan disimpan di dalam variabel "youtube_scrape_comment_objects"
(bersamaan dengan nama service dan jenis versi dari service yang digunakan)
untuk dapat mengambil 100 data/informasi (sesuai jumlah batasan/limit data komentar yang dapat
diambil dari komentar pada konten video YouTube menggunakan API dari Google Client) pada serangkaian komentar utama
tentang debat capres-cawapres babak keempat Republik Indonesia tahun 2024 yang di-upload oleh
channel YouTube KPU RI berdasarkan dari ID yang dimiliki oleh video tersebut
"""

video_youtube_data_request = youtube_scrape_comment_objects.commentThreads().list(
    part = "snippet", # snippet pada parameter part adalah objek list dari seluruh elemen yang dimiliki oleh komentar utama
    videoId = "anuQxiXpQ7I", # Merupakan ID dari video debat babak keempat capres-cawapres yang di-upload oleh channel KPU RI 
    maxResults = 100, # Jumlah informasi komentar yang akan terambil dari video debat keempat namun 100 data adalah batasannya
    order = "time", # Nilai time pada parameter order adalah urutan tanggal dan waktu terbaru hingga terlama dari komentar
)


"""
Menjalankan proses permintaan untuk mendapatkan seluruh elemen/objek dari 100 rangkaian komentar
paling terbaru hingga terlama dari video ID yaitu anuQxiXpQ7I yang merupakan ID video dari debat
capres-cawapres babak keempat yang di-upload oleh YouTube channel KPU RI yyang telah dibuat dan disimpan
pada variabel "video_youtube_data_request"
"""
video_youtube_data_response = video_youtube_data_request.execute()

# %% [markdown]
# Berikut adalah penjelasan mengenai code script diatas berikut ini:
#
# 1. youtube_scrape_comment_objects merupakan sebuah nama variabel yang berisikan parameter-parameter beserta nilainya yang berfungsi sebagai tempat menyimpan resource utama Google Client serta API dari YouTube untuk dapat mengakses data-data dan informasi yang dimiliki oleh suatu konten video YouTube seperti informasi video, komentar di dalam suatu video, playlist dari suatu channel, dll, dengan memanfaatkan kode API (API KEY) yang didapatkan melalui Google Cloud Platform dengan cara membuat credentials API di dalam salah satu service Google Cloud Platform yaitu YouTube Data API v3.
#
# 2. commentThreads merupakan suatu sumber daya dari YouTube Data API yang berisikan objek/elemen atas informasi-informasi dari komentar utama (teks komentar yang bukan menjadi komentar balasan) dari suatu video di YouTube. Salah satu contoh informasi yang terdapat di dalam komentar utama adalah teks komentar yang dibuat oleh user/penonton dari video tersebut bukan teks komentar yang menanggapi/merespon komentar utama. Atau identitas nama user/akun YouTube yang berkomentar di video tersebut sebagai bentuk pendapat atas video yang ditonton.
#
# 3. Parameter "part" bertujuan untuk mendapatkan banyak objek list properti yang dipisahkan oleh tanda koma (comma-separated list) dari sumber daya yang dimiliki oleh service YouTube Data API v3 yang membentuk komentar paling utama (komentar teratas) dari suatu video. Sedangkan "snippet" pada parameter "part" bertujuan untuk mendapatkan objek detail dasar tentang elemen-elemen/item dari komentar utama sebagai bentuk respon API YouTube terhadap permintaan dalam mengambil objek-objek data dari sebuah konten video berdasarkan video id yang didefinisikan pada parameter "videoId". Salah satu contoh detail dasar dari komentar utama seperti channel id sebagai identitas unik dari suatu channel yang ada di media sosial YouTube.
#
# 4. Parameter videoId merupakan sebuah identitas unik dari video (ID dari suatu konten video YouTube) yang informasi dasarnya ingin diambil (data scraping) untuk kebutuhan yang berbeda-beda. Sebagai contohnya pada penelitian kali ini, saya ingin menggunakan video tentang debat babak keempat capres-cawapres Republik Indonesia tahun 2024 dari channel YouTube KPU RI dan video tersebut memiliki alamat URL yakni https://www.youtube.com/watch?v=anuQxiXpQ7I. Jadi ID video "anuQxiXpQ7I" diambil dari URL pada video tersebut yang letaknya setelah v=.
#
# 2. Parameter maxResult merupakan sebuah parameter yang secara spesifik bertujuan untuk mengambil jumlah kuantitas dari data/informasi komentar utama yang ingin diambil dari suatu konten video di media sosial YouTube berdasarkan ID unik yang didefinisikan pada parameter videoId. Tetapi kuantitas jumlah data/informasi komentar yang dapat diambil menggunakan API dari service Google Client hanya 100 data saja, tidak bisa lebih dari 100 data. Sehingga karena penelitian kali ini akan mengambil lebih dari 100 data, maka diperlukan tahapan/teknik pengulangan supaya data komentar yang terambil dapat melebihi 100 data. Tahapan untuk mengambil data lebih dari 100 data akan dilakukan setelah berhasil mendapatkan 100 data komentar (berdasarkan jumlah maksimal data komentar yang dapat diambil menggunakan API Google YouTube v3).
#
# 4. Parameter order merupakan sebuah parameter yang dimiliki oleh fungsi commentThreads() yang bertujuan untuk menentukan urutan data komentar yang ingin diambil (di-scraping) sebagai permintaan/request dari Google API Client terhadap komentar yang dimiliki oleh konten-konten video yang berada di media sosial YouTube. Konten video tersebut ditentukan oleh video ID yang dimiliki oleh parameter videoId. Parameter order memiliki 2 nilai yang valid yaitu time dan relevance. Jika nilai dari parameter order adalah time, maka urutan data komentar yang diambil akan terdiri dari komentar-komentar yang paling baru dibuat pada video tersebut berdasarkan tanggal dan waktu dari setiap teks komentar. Sebagai contoh jika terdapat teks komentar pada suatu konten video YouTube yang ditulis dengan teks "Hari Buruh dirayakan disetiap tanggal 1 Mei termasuk Negara Indonesia" dibuat di tanggal 1 Mei 2024 dan teks komentar lainnya adalah "Perayaan hari buruh di beberapa tempat dirayakan dengan sangat tentram dan demokratis" dibuat di tanggal 1 Mei tahun 2023, maka urutan teks komentar yang tersimpan terlebih dahulu/teks komentar paling atas dari urutan teks komentar yag tersimpan adalah teks komentar yang ditulis seperti "Hari Buruh dirayakan disetiap tanggal 1 Mei termasuk Negara Indonesia" dan baris selanjutnya adalah teks komentar "Perayaan hari buruh dibeberapa tempat dirayakan dengan sangat tenram dan demokratis". Jadi pada dasarnya nilai time di dalam parameter order akan mengurutkan komentar berdasarkan tanggal dan waktu yang dimiliki oleh setiap data rangkaian komentar yang dimulai dari komentar paling terbaru hingga komentar yang dibuat paling lama yang terdapat di dalam suatu konten video YouTube berdasarkan video id yang dimilikinya.

# %%
"""
Menampilkan seluruh objek serta elemen yang dimiliki oleh 100 rangkaian komentar utama
(teks komentar yang bukan merupakan balasan/reply dari suatu komentar) dari video debat babak keempat
capres-cawapres yang ditayangkan oleh channel YouTube KPU RI yang berhasil di-scraping
menggunakan API Key dari service Google Cloud Console yaitu YouTube Data API v3
"""
video_youtube_data_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'q5tbrDW8oq43fh4LegafrZkdMEg',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWdnR0FBU0JRaWRJQmdCR0FBaURRb0xDSVh2djYwR0VQQ1J2VjQ=',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '4vqqwjzf7ipTQdFHN08S3mBpFnk',
#    'id': 'UgxDCjTyd2CYZfTUpSB4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '5HRNkRw-nuSkCpboMxeGO5q3lmI',
#      'id': 'UgxDCjTyd2CYZfTUpSB4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': 'Peningkatan fasilitas kesehatan akan meningkatkan kualitas pelayanan medis',
#       'textOriginal': 'Peningkatan fasilitas kesehatan akan meningkatkan kualitas pelayanan medis',
#       'authorDisplayName': '@ulya_rahma',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/JdVPiU36DBgB1GbYY1Bu1JXzz3Kpgk-Wte2dutrqPUsBBk7dDRaN1hBpy0RXOnDiaVC74QAn75o=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ulya_rahma',
#       'authorChannelId': {'value': 'UCagjbH4XVCVkt6j4rMKcavw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-24T17:17:25Z',
#       'updatedAt': '2024-04-24T17:17:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'cxMAQz5OUjuDb8iaJqazafu7KOI',
#    'id': 'UgzSj3SmHsfHFl6gxId4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vQVcVYkhpZthPLsHFESaNgkvcss',
#      'id': 'UgzSj3SmHsfHFl6gxId4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': '<a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKuhL0PlbiA2AE"></a>',
#       'textOriginal': '',
#       'authorDisplayName': '@nurlela-zd4rv',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7QQB5V0EwAzk7QGxOZEDKT_2FZ22TT5kXfDEkOKEjZ1-nx0DyAEVAPxAMsVElIxxWFQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@nurlela-zd4rv',
#       'authorChannelId': {'value': 'UCiDBYDyUK5gvAYwTWMDlgMg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-22T23:04:29Z',
#       'updatedAt': '2024-04-22T23:04:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9CpzCqIXKulphWcRgr8eKHk7Jdg',
#    'id': 'UgwomMhPe_dJHE0LSxR4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tnq9sVudDgPMVl3l2vlUZ4lxIGI',
#      'id': 'UgwomMhPe_dJHE0LSxR4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': 'Mantap Mas Gibran sangat kekinian dan mengikuti perkembangan jaman ,sangat perlu kemandirian masyarakat utk memoderenisasi Indonesia.',
#       'textOriginal': 'Mantap Mas Gibran sangat kekinian dan mengikuti perkembangan jaman ,sangat perlu kemandirian masyarakat utk memoderenisasi Indonesia.',
#       'authorDisplayName': '@user-rb6gr6ee2n',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nZzDRI40ipEIHPfkECFKitq9nsYQM46UYdcvFoVN7UN8M=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user
=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@holly-nd2yx',
#       'authorChannelId': {'value': 'UCe_dCiMzuGS5lZMsHdVOFvA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-03T18:24:09Z',
#       'updatedAt': '2024-03-03T18:24:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '22Z1HXD2BBx-tZazbvly8rnjcKU',
#    'id': 'Ugziskn3dxd5vjv_GeF4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Qkl4zCt37CckbvI3gi_TX2IBBEY',
#      'id': 'Ugziskn3dxd5vjv_GeF4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': 'Prabowo Gibran presidency vice presidency',
#       'textOriginal': 'Prabowo Gibran presidency vice presidency',
#       'authorDisplayName': '@user-ut5gc2zk3w',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lAnWXoQXSpNvvE_AcXpQWRgZhKkSFf1lxmhyOMabzmig_ZscSfbTZuInp2bg4XYctXVg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-ut5gc2zk3w',
#       'authorChannelId': {'value': 'UCRPtn3QLyPnHleffY-4-D4g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-02T09:33:25Z',
#       'updatedAt': '2024-03-02T09:33:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'KLTNXpHls34cNeMfHwJcqkAV2go',
#    'id': 'UgxSuCnCPBtvdWzny7t4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2r6rUx1_OdPtAZdgQVnLj9vdGSA',
#      'id': 'UgxSuCnCPBtvdWzny7t4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': '5 4 <br><br>C😊4 c',
#       'textOriginal': '5 4 \n\nC😊4 c',
#       'authorDisplayName': '@geovanyalmachzumi1646',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n8sh29d9hzHmVGyx4CrGayR3KCkcdEYxe-GmfDMG9G3I0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@geovanyalmachzumi1646',
#       'authorChannelId': {'value': 'UCxcGWKo5etcl0NIJv2G-wjA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-01T20:15:24Z',
#       'updatedAt': '2024-03-01T20:15:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EZc6AtmPacOU_cF83_YOrlyb1x4',
#    'id': 'Ugyam43z68eoFJjqWxV4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ANYj2hps1nHjKOyByCgw9EydIcY',
#      'id': 'Ugyam43z68eoFJjqWxV4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': '5 4 <br><br>C😊4',
#       'textOriginal': '5 4 \n\nC😊4',
#       'authorDisplayName': '@geovanyalmachzumi1646',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n8sh29d9hzHmVGyx4CrGayR3KCkcdEYxe-GmfDMG9G3I0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@geovanyalmachzumi1646',
#       'authorChannelId': {'value': 'UCxcGWKo5etcl0NIJv2G-wjA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-01T20:15:24Z',
#       'updatedAt': '2024-03-01T20:15:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xiruu_L8BkiHBzxnM6uNffUBucA',
#    'id': 'Ugxs49MfV4YTZTzOg714AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8u6fBEfM9x2-bBpvhHiMxlUCTkU',
#      'id': 'Ugxs49MfV4YTZTzOg714AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': 'Semuanya bagus tapi maaf saya pilih Gibran ❤',
#       'textOriginal': 'Semuanya bagus tapi maaf saya pilih Gibran ❤',
#       'authorDisplayName': '@Laryan1892',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/WgbnEBNbQfgiLHnvXbERxfvvQ9rK_Q9vxXk7Sk-wh6YP_5LG4ta67UtDSaxCDHZoNFEwaZ4o4g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Laryan1892',
#       'authorChannelId': {'value': 'UCYsFv-0EB4hmKX9gWha7awg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-21T02:26:51Z',
#       'updatedAt': '2024-02-21T02:26:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OzpvOvb1CZ_SIhj64QZo-niqNyM',
#    'id': 'Ugzza8JHYHKZTaXc9Eh4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 't1aG4NR5etRw3Z655ezWYU95LKY',
#      'id': 'Ugzza8JHYHKZTaXc9Eh4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': 'gibran planga plongo....stres',
#       'textOriginal': 'gibran planga plongo....stres',
#       'authorDisplayName': '@DeniCeka',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com
#       'textOriginal': 'Catatan buat semua Cawapres, ternyata banyak sekali PR anda utk memperbaiki negara ini, persoalannya apakah anda2 semua komit untuk menjalankannya, atau hanya komat kamit nantinya \nGibran : Anda sangat konvensional sebagai anak muda hanya menjual ide2 hilirlisasi NIKEL, seharusnya anda befikir ekonomi kreatif dan inovasi termasuk bagaimana anak muda mau kembali ke desa untuk membuat inovasi desa\nPak Mahfud, terimakasih sudah mau memberikan informasi bahwa MAFIA dan KORUPSI merajalela dimana2, ternyata pemerintahan JOKOWI bagus itu hanya MITOS saja',
#       'authorDisplayName': '@bednyng2794',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nOsjskYnIbKCUVkQ81U3eppcbBwC41S9LeBqDNbAUO3aU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@bednyng2794',
#       'authorChannelId': {'value': 'UC_cFV8lJSPyU2-2QlzwTFvA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-01-23T17:39:43Z',
#       'updatedAt': '2024-01-23T17:39:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Pcuo1FojIbf8UNZToeLdbg7WZdg',
#    'id': 'UgwJ6ZBobMlNCuqiqyB4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'anuQxiXpQ7I',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iBsVrSnnpYYzKZxppTuXOkXNM1o',
#      'id': 'UgwJ6ZBobMlNCuqiqyB4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'anuQxiXpQ7I',
#       'textDisplay': 'Pak mahfud udah menguasai trias politica dan selayaknya dengan bekal pengalaman yang segudang keluarga kami berharap bangsa besar ini kami titipkan di pundakmu',
#       'textOriginal': 'Pak mahfud udah menguasai trias politica dan selayaknya dengan bekal pengalaman yang segudang keluarga kami berharap bangsa besar ini kami titipkan di pundakmu',
#       'authorDisplayName': '@randrafara2',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Rj5DufXNBvT5t2X5mHza7mlSJFglFeQLUYc4lfUFanw1NjQSDuSz1q8xTMYGyweEZYvaHy5FZ0U=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@randrafara2',
#       'authorChannelId': {'value': 'UCOK1075ESWkskaJz-96ZOlA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-01-23T17:29:42Z',
#       'updatedAt': '2024-01-23T17:29:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# ## 3. Define Main Items (Video ID, Total Reply of Count, Comment ID, Text of Comment, Total of Comment Like, Name of Account Commenting, etc) from Video YouTube based on Video ID in YouTube

# %%
"""
Mendefinisikan beberapa elemen item yang membentuk serangkaian komentar utama yang akan digunakan
sebagai kolom di dalam DataFrame berdasarkan ID video YouTube yang sebelumnya telah didefinisikan
pada "video_youtube_data_request" (saat ini permintaan tersebut telah diterima sebagai respon dan disimpan
di dalam "video_youtube_data_response") dengan mengambil 100 data/informasi dari serangkaian komentar utama di dalam video
debat capres-cawapres Republik Indonesia babak keempat yang di-upload oleh channel YouTube KPU RI
"""


"""
Variabel "list_fourth_video_debate_kpuri" adalah empty list untuk menyimpan beberapa elemen item dari rangkaian
teks komentar utama seperti ID video debat babak keempat yang ditayangkan oleh channel KPU RI, ID channel KPU RI,
isi teks komentar khususnya komentar utama, nama akun user/penonton yang berkomentar di dalam video tersebut, dll
"""
list_fourth_video_debate_kpuri = []


for item in video_youtube_data_response["items"]:
    video_id = item["snippet"]["videoId"] # Mendapatkan ID video debat keempat capres-cawapres yang di-upload channel KPU RI
    total_reply_count = item["snippet"]["totalReplyCount"] # Mendapatkan jumlah total balasan dari masing-masing teks komentar
    comment_id = item["id"] # Mendapatkan ID dari seluruh teks komentar utama (bukan teks komentar yang bersifat reply)
    
    
    """
    Mendapatkan seluruh elemen item per masing-masing komentar utama yang menjadi struktur pembentuk dasar dari komentar utama
    berdasarkan video ID yang sebelumnya telah diinisialisasikan.
    Jenis objek yang menjadi struktur/rangkaian detail atas masing-masing komentar utama adalah channel ID,
    teks komentar, jumlah like pada komentar tersebut, tanggal dan waktu dibuatnya komentar,
    nama akun user yang berkomentar di dalam video tersebut, dll
    
    Perlu diketahui jika elemen item yang terdapat pada top level comment dan commentThreads() berbeda tetapi
    dapat digabungkan menjadi satu kesatuan. Elemen seperti video id,
    jumlah user yang membalas/merespon teks komentar utama, dan lainnya
    termasuk di dalam elemen item yang dimiliki oleh commentThreads()
    karena sifatnya adalah informasi general dari rangkaian komentar utama
    
    Sedangkan elemen item yang dimiliki oleh top level comment lebih bersifat informasi yang spesifik yang dimiliki oleh
    masing-masing komentar utama atau komentar balasan atas komentar utama.
    Elemen item seperti nama user/akun yang berkomentar, isi atas masing-masing teks komentar yang dibuat oleh
    setiap akun yang berkomentar, jumlah user yang menyukai isi dari teks komentar utama, dan lainnya
    termasuk ke dalam item-item yang dimiliki oleh top level comment
    """
    comment_items = item["snippet"]["topLevelComment"]["snippet"]
    
    
    """
    Memasukkan atribut/elemen utama ke dalam variabel list kosong yaitu "list_fourth_video_debate_kpuri" yang akan
    berisikan beberapa objek item/elemen dari serangkaian komentar utama seperti ID video,
    ID Channel yang mem-publish/meng-upload video tersebut, nama akun user yang berkomentar beserta teks komentar,
    tanggal pembuatan komentar untuk video tersebut,
    jumlah total like sebagai bentuk respon setuju pada komentar yang telah dibuat oleh user, dll.
     
    Catatan tambahan bahwasanya variabel "video_id", "total_reply_count", "comment_id" dan "comment_items"
    termasuk ke dalam elemen utama yang akan dimasukkan ke dalam list kosong (empty list) yang bernama
    "list_fourth_video_debate_kpuri" yang nantinya list yang bernama "list_fourth_video_debate_kpuri"
    akan menjadi struktur kolom di dalam Pandas DataFrame
    """
    list_fourth_video_debate_kpuri.append([
        video_id, # Memasukkan ID video debat keempat capres-cawapres yang di-upload oleh channel YouTube KPU RI ke dalam list
        comment_items["channelId"], # Memasukkan ID yang dimiliki oleh channel YouTube KPU RI ke dalam variabel list
        comment_id, # Memasukkan ID masing-masing komentar yang dibuat oleh para penonton video debat keempat ke dalam list
        comment_items["authorDisplayName"], # Memasukkan nama akun YouTube yang berkomentar di video debat ke dalam empty list
        comment_items["textDisplay"], # Memasukkan 100 teks komentar utama video debat ke-4 dari channel KPU RI ke dalam list
        comment_items["likeCount"], # Memasukkan jumlah total like yang diterima oleh teks komentar utama ke dalam variabel list
        total_reply_count, # Memasukkan jumlah total balasan (reply) yang diterima oleh teks komentar utama ke dalam list
        comment_items["authorChannelUrl"], # Memasukkan URL/link channel akun YouTube para penonton video debat keempat ke list
        comment_items["publishedAt"], # Memasukkan tanggal dan waktu saat pertama kali teks komentar utama dibuat oleh user
        comment_items["updatedAt"] # Memasukkan tanggal dan waktu saat suatu teks komentar mengalami perubahan (update) tulisan
    ])
    

"""
Menampilkan jumlah data yang dimiliki oleh list setelah dilakukan proses pemilihan
elemen-elemen yang akan menampilkan struktur dari rangkaian komentar utama dari video debat
capres-cawapres babak keempat dari YouTube channel KPU RI
"""
print("Jumlah Data yang Dimiliki oleh Variabel List 'list_fourth_video_debate_kpuri' sebelum Proses Looping adalah",
      len(list_fourth_video_debate_kpuri))
# Out:
# Jumlah Data yang Dimiliki oleh Variabel List 'list_fourth_video_debate_kpuri' sebelum Proses Looping adalah 100

# %% [markdown]
# Jika hanya menggunakan code script diatas saja maka data komentar yang didapatkan hanya berjumlah 100 data saja karena jumlah maksimal untuk mengambil data komentar dari suatu konten video YouTube dengan menggunakan Google YouTube API dibatasi hanya 100 data. Maka dari itu karena menurut saya 100 data sangat tidak cukup untuk penelitian kali ini, maka saya akan mengambil data komentar dari video debat capres-cawapres babak keempat dari YouTube channel KPU RI lebih dari 100 data komentar.
#
# Untuk mengatasi permasalahan ini, saya akan melakukan proses looping/pengulangan permintaan untuk mengambil data komentar lebih dari 100 data. Jumlah data yang saya inginkan pada penelitian kali ini berjumlah sebanyak 1.040 data dari 1.849 komentar (per tanggal 4 Mei 2024) sehingga permintaan yang code script dibawah ini akan mengulangi permintaan mengambil data sebanyak 1.040 data komentar yang akan ditempatkan di dalam 10 kolom/object/elemen utama dari video debat capres-cawapres babak keempat yang di-upload oleh channel YouTube KPU RI. Sepuluh kolom/elemen utama yang akan membentuk DataFrame adalah kolom elemen "videoId", "channelId", "id" sebgaai comment_id, "authorDisplayName", "textDisplay", "likeCount", "totalReplyCount", "authorChannelUrl", "publishedAt", dan "updatedAt".
#
# Sebagai catatan dan pengingat bahwasanya saat ini objek list yang bernama "list_fourth_video_debate_kpuri" baru memiliki 100 rangkaian data/informasi komentar dan akan dilakukan proses pengulangan permintaan hingga variabel list "list_fourth_video_debate_kpuri" memiliki 1.040 data komentar beserta elemen-elemen utamanya. Agar dapat mengambil data komentar sebanyak 1.040 data, maka saya akan menerapkan teknik TokenPagination.
#
# TokenPagination merupakan cara untuk mengambil data-data yang berada di halaman selanjutnya (data yang bukan berada di halaman utama/halaman paling awal dari suatu konten/informasi). TokenPagination yang akan digunakan di dalam penelitian kali ini memiliki tujuan untuk mendapatkan data-data komentar seperti teks komentar, data nama akun/user yang berkomentar, tanggal pembuatan komentar, dsb, yang berada di halaman-halaman berikutnya atau halaman setelah 100 data paling awal (data yang menjadi batasan maksimal/limit yang dapat diambil menggunakan YouTube Data API v3).

# %%
"""
Menampilkan seluruh data dari beberapa elemen item yang sebelumnya telah dilakukan proses penyeleksian
elemen yang akan ditampilkan dan elemen-elemen tersebut dimasukkan ke dalam variabel list "list_fourth_video_debate_kpuri"
yang sumber data komentarnya berasal dari video debat capres-cawapres babak keempat yang ditayangkan
oleh channel Youtube KPU RI yang memiliki ID Video anuQxiXpQ7I
"""
list_fourth_video_debate_kpuri
# Out:
# [['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxDCjTyd2CYZfTUpSB4AaABAg',
#   '@ulya_rahma',
#   'Peningkatan fasilitas kesehatan akan meningkatkan kualitas pelayanan medis',
#   0,
#   0,
#   'http://www.youtube.com/@ulya_rahma',
#   '2024-04-24T17:17:25Z',
#   '2024-04-24T17:17:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzSj3SmHsfHFl6gxId4AaABAg',
#   '@nurlela-zd4rv',
#   '<a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKuhL0PlbiA2AE"></a>',
#   0,
#   0,
#   'http://www.youtube.com/@nurlela-zd4rv',
#   '2024-04-22T23:04:29Z',
#   '2024-04-22T23:04:29Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwomMhPe_dJHE0LSxR4AaABAg',
#   '@user-rb6gr6ee2n',
#   'Mantap Mas Gibran sangat kekinian dan mengikuti perkembangan jaman ,sangat perlu kemandirian masyarakat utk memoderenisasi Indonesia.',
#   0,
#   0,
#   'http://www.youtube.com/@user-rb6gr6ee2n',
#   '2024-04-03T19:38:24Z',
#   '2024-04-03T19:38:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxb3HWjWURZqCXjYsF4AaABAg',
#   '@abdulchalik9807',
#   'Klo org indonesaia dah hatam soal toreransi krn banyak agama di indobesia tapi aman dan damai, coba klo negara lain islam yg minoritas dah pasti di gencet...😂',
#   0,
#   0,
#   'http://www.youtube.com/@abdulchalik9807',
#   '2024-03-12T17:21:06Z',
#   '2024-03-12T17:21:06Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz8FNs0NpteSM7EZ-N4AaABAg',
#   '@AlangHartawan',
#   '😮😮😮😮pp n npn nnm h.......m',
#   0,
#   0,
#   'http://www.youtube.com/@AlangHartawan',
#   '2024-03-10T21:07:00Z',
#   '2024-03-10T21:07:00Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwbMtw3YLhTLVI2YNd4AaABAg',
#   '@dldiprasetyo9487',
#   'Diproses hukum ketua KPU beserta teman temannya karena sudah membuat kecurangan biar membuat jera para pembuat kecurangan agar tidak terjadi lagi dan berani berbuat.',
#   0,
#   0,
#   'http://www.youtube.com/@dldiprasetyo9487',
#   '2024-03-10T09:09:25Z',
#   '2024-03-10T09:09:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz6vBxRR-XOCIXm1114AaABAg',
#   '@holly-nd2yx',
#   'Awas lho.... Greenfalation diPerancis bakal terjadi di Indonesia lho... harga pajak BBM bakal naik tinggi lho.. buat menopang makan siang &amp; susu gratis bagi para anak sekolah lho.. awas PDB utang luar negri bakal meningkat.',
#   0,
#   0,
#   'http://www.youtube.com/@holly-nd2yx',
#   '2024-03-03T18:24:09Z',
#   '2024-03-03T18:24:09Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugziskn3dxd5vjv_GeF4AaABAg',
#   '@user-ut5gc2zk3w',
#   'Prabowo Gibran presidency vice presidency',
#   0,
#   0,
#   'http://www.youtube.com/@user-ut5gc2zk3w',
#   '2024-03-02T09:33:25Z',
#   '2024-03-02T09:33:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxSuCnCPBtvdWzny7t4AaABAg',
#   '@geovanyalmachzumi1646',
#   '5 4 <br><br>C😊4 c',
#   0,
#   0,
#   'http://www.youtube.com/@geovanyalmachzumi1646',
#   '2024-03-01T20:15:24Z',
#   '2024-03-01T20:15:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugyam43z68eoFJjqWxV4AaABAg',
#   '@geovanyalmachzumi1646',
#   '5 4 <br><br>C😊4',
#   0,
#   0,
#   'http://www.youtube.com/@geovanyalmachzumi1646',
#   '2024-03-01T20:15:24Z',
#   '2024-03-01T20:15:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxs49MfV4YTZTzOg714AaABAg',
#   '@Laryan1892',
#   'Semuanya bagus tapi maaf saya pilih Gibran ❤',
#   0,
#   0,
#   'http://www.youtube.com/@Laryan1892',
#   '2024-02-21T02:26:51Z',
#   '2024-02-21T02:26:51Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzza8JHYHKZTaXc9Eh4AaABAg',
#   '@DeniCeka',
#   'gibran planga plongo....stres',
#   0,
#   0,
#   'http://www.youtube.com/@DeniCeka',
#   '2024-02-19T21:14:57Z',
#   '2024-02-19T21:14:57Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxOX-D1fPsWdv6zDDF4AaABAg',
#   '@cahayaislam3181',
#   'Sehat Gus',
#   0,
#   0,
#   'http://www.youtube.com/@cahayaislam3181',
#   '2024-02-18T16:21:26Z',
#   '2024-02-18T16:21:26Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyVwpNlGMyKgARBrph4AaABAg',
#   '@mancingngoyor9892',
#   'Assalamualaikum Wr Wb <br>Salam silaturahmi,<br>Ikut nyimak guys',
#   0,
#   0,
#   'http://www.youtube.com/@mancingngoyor9892',
#   '2024-02-18T02:10:34Z',
#   '2024-02-18T02:11:06Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgycJgEGglTfo1VmODB4AaABAg',
#   '@nurulfadnanyputri4259',
#   '💙',
#   0,
#   0,
#   'http://www.youtube.com/@nurulfadnanyputri4259',
#   '2024-02-17T09:35:24Z',
#   '2024-02-17T09:35:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxrGEvwMvKzcVTosTR4AaABAg',
#   '@HaanHaan_',
#   'Gibran sok sok bilang hilirisasi preeettt!!! <br>Liat itu data dan fakta di lapangan di daerah-daerah industri pertambangan. Seperti daerah tambang nikel di Morowali, Sulawesi Tengah. <br>Apa saja kebijakan dan peraturan yg sudah dikeluarkan oleh pemerintah saat ini beserta kroni nya. Liat saja untuk kepentingan dan keuntungan siapa kebijakan dan peraturan itu dibuat?? <br>Masih bisa gibran bilang hilirisasi???',
#   0,
#   0,
#   'http://www.youtube.com/@HaanHaan_',
#   '2024-02-12T08:18:59Z',
#   '2024-02-12T08:18:59Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzw4SVHGv9bfjOamsp4AaABAg',
#   '@snfdh04',
#   '1&amp;3 black campaign terossa',
#   0,
#   0,
#   'http://www.youtube.com/@snfdh04',
#   '2024-02-08T07:11:45Z',
#   '2024-02-08T07:11:45Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw5v_QE3ZJ0Gh9h_I94AaABAg',
#   '@b36.9',
#   'sumpahh audio nya jelek bgttttttt T.T plss bikin ga nyaman bgt buat nntonnya, sekelas debat negara loh, kok bisa sejelek ini? apa ga ada editor?<br>bukan sekedar kecil, tpi kresek2 jg heh :(  nyiasatin dgn gedein volume, tpi bikin budek pas iklan',
#   2,
#   0,
#   'http://www.youtube.com/@b36.9',
#   '2024-02-07T01:12:21Z',
#   '2024-02-07T01:18:28Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwR-Us-6XlYiLq6P7Z4AaABAg',
#   '@user-em4bn2cv4g',
#   'Je ien ueh isbxieh iebcieh uebcuebciehicehi eb ueb ishcienxiehicehcueb 7su usbxuejxiwbx8sjxuwhf',
#   0,
#   0,
#   'http://www.youtube.com/@user-em4bn2cv4g',
#   '2024-02-06T23:34:38Z',
#   '2024-02-06T23:34:38Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzFNydv46dczeLt7YF4AaABAg',
#   '@AlvinoPratama-sl4gg',
#   'keren',
#   0,
#   0,
#   'http://www.youtube.com/@AlvinoPratama-sl4gg',
#   '2024-02-06T23:08:44Z',
#   '2024-02-06T23:08:44Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwByhc8P5zxzcVN1Ih4AaABAg',
#   '@mariafransisca5803',
#   'Hebat tiga2nya...',
#   0,
#   0,
#   'http://www.youtube.com/@mariafransisca5803',
#   '2024-02-06T15:19:59Z',
#   '2024-02-06T15:19:59Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxRRVrzP_mpT5GU6Ud4AaABAg',
#   '@madecahyanii',
#   'bjir akun kpu ri jg penuh buzzer😢',
#   0,
#   0,
#   'http://www.youtube.com/@madecahyanii',
#   '2024-02-06T03:54:52Z',
#   '2024-02-06T03:54:52Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx6qgGEkafPrkDFwQ94AaABAg',
#   '@user-ms4cy7ub1w',
#   'Pak mahfud ❤🎉',
#   0,
#   0,
#   'http://www.youtube.com/@user-ms4cy7ub1w',
#   '2024-02-05T03:21:04Z',
#   '2024-02-05T03:21:04Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwTEWF7tkM6gZQ_uo94AaABAg',
#   '@xl7rossonerri',
#   'bansos dari pajak rakyat . diaku aku . dipinggir jalan',
#   0,
#   0,
#   'http://www.youtube.com/@xl7rossonerri',
#   '2024-02-04T14:00:56Z',
#   '2024-02-04T14:00:56Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxWDwb3_aeyL8wCuU94AaABAg',
#   '@DedeKuswara',
#   'Hahah debat lagi nih siapa yang tertindas lagi nih...',
#   0,
#   0,
#   'http://www.youtube.com/@DedeKuswara',
#   '2024-02-04T13:23:59Z',
#   '2024-02-04T13:23:59Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzNfSLnoHUB_l-j6wB4AaABAg',
#   '@arilmizan5724',
#   'Yang cerdas gak pilih anis',
#   0,
#   0,
#   'http://www.youtube.com/@arilmizan5724',
#   '2024-02-04T11:50:56Z',
#   '2024-02-04T11:50:56Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw-4nF3hlVn6SI3mvp4AaABAg',
#   '@user-te7cv1ib5h',
#   'Cak Imin  ,kalian pak Mahmud wejanganya bagus',
#   0,
#   0,
#   'http://www.youtube.com/@user-te7cv1ib5h',
#   '2024-02-01T15:17:14Z',
#   '2024-02-01T15:17:14Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwIz9h0cwoCCWHzuTR4AaABAg',
#   '@alfinaprianto',
#   '<a href="https://www.youtube.com/watch?v=anuQxiXpQ7I&amp;t=7960">2:12:40</a> :v',
#   0,
#   0,
#   'http://www.youtube.com/@alfinaprianto',
#   '2024-01-30T02:30:48Z',
#   '2024-01-30T02:30:48Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz-LCtMcyKmUsxqFIt4AaABAg',
#   '@darman_gunarto18',
#   'Partisipasi dalam Pemilu adalah investasi kita dalam pembangunan demokrasi yang kuat.',
#   0,
#   0,
#   'http://www.youtube.com/@darman_gunarto18',
#   '2024-01-29T06:05:20Z',
#   '2024-01-29T06:05:20Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwJbATRQbHOHXkgh-h4AaABAg',
#   '@nurdiansyahdimas6380',
#   'saling menjatuhkan,,, pencerminan bukan calon pemimpin yg baik',
#   0,
#   0,
#   'http://www.youtube.com/@nurdiansyahdimas6380',
#   '2024-01-29T04:52:30Z',
#   '2024-01-29T04:52:30Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz-yXiouMKdR-yPcvp4AaABAg',
#   '@Kaset_Talim',
#   'Baju nya percis baju konoha <br><br>Wah ...<br>Bner bner boroto nih😂😂😂<br>Logonya juga logo klan yang di punggung baju sinobi di konoha juga<br><br>Sbetulnya kalo emng mau ngikutin konoha <br><br>Inget<br>Boruto ga mau jadi hokage atau penasehat / wakil hokage<br><br>Tapi dia ingin melindungi konoha dari luar <br>Dia pengen jadi seperti sasuke yang menjadi pengaman konoha dari luar dan menjadi polisi seperti dulu di clan uciha...<br><br>Gimna nih lur wkwk😂😂😂',
#   0,
#   0,
#   'http://www.youtube.com/@Kaset_Talim',
#   '2024-01-29T02:20:32Z',
#   '2024-01-29T02:20:32Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy0d4089RMsLrcVWl14AaABAg',
#   '@genshinimpact6472',
#   'pak capres dan cawapres tolong segera usir tu UNHCR dan pengungsinya dari tanah INDONESIA karena sudah sangat meresahkan, jangan sampai tanah yg diperjuangkan oleh para pahlawan di ambil alih oleh orang lain dengan alasan kemanusiaan palsu (padahal mereka campuran orang Bangladesh yg punya niat hidup di Indonesia) ga seperti yg digaungkan media, saya tidak rela dan menolak keras, mending di pake rakyat Indonesia sendiri yg lebih membutuhkan,, jgn sampe Israel versi Rohingya terjadi di indonesia',
#   0,
#   0,
#   'http://www.youtube.com/@genshinimpact6472',
#   '2024-01-28T18:10:11Z',
#   '2024-01-28T18:13:51Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxyQc6LWAlzyYsJPn54AaABAg',
#   '@madewendra2362',
#   'Yg muda memang top',
#   0,
#   0,
#   'http://www.youtube.com/@madewendra2362',
#   '2024-01-28T14:38:58Z',
#   '2024-01-28T14:38:58Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy2dlp5pI7VZi37Ut94AaABAg',
#   '@blackmask4647',
#   'Lamun Anak RT,Geus Di jadikeun bebegig sawah ku aing da...',
#   0,
#   0,
#   'http://www.youtube.com/@blackmask4647',
#   '2024-01-28T14:29:37Z',
#   '2024-01-28T14:29:37Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw-Ukkj1IXXnI68ATp4AaABAg',
#   '@blackmask4647',
#   'Seperti kata Pak Prabowo,kalo gk Pinter... ya GOBLOK!<br>Yg gw Heran,kenapa Gibran diolok&quot; karena Sikap nya???<br>padahal Ada Yg lebih Goblok,yaitu Pendukung nya. 😄<br>Wong Kyo Ngono di Dukung,Wesss... Angel...angeeell...',
#   0,
#   0,
#   'http://www.youtube.com/@blackmask4647',
#   '2024-01-28T14:14:30Z',
#   '2024-01-28T14:14:30Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwHw1Bgr8Q55Tph1ZV4AaABAg',
#   '@FARHAN-un5gg',
#   '.',
#   0,
#   0,
#   'http://www.youtube.com/@FARHAN-un5gg',
#   '2024-01-27T03:36:03Z',
#   '2024-01-27T03:36:03Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyB7HGX3QdgcLnvi6p4AaABAg',
#   '@sutrisnotrisno1907',
#   'kalau mau melanjutkan dievaluasi dulu, yang kemarin misalnya bagaimana tentang Revolusi Mental, Produksi massal Mobil Esemka, Pemberantasan KKN (korupsi kolusi dan nepotisme)',
#   0,
#   0,
#   'http://www.youtube.com/@sutrisnotrisno1907',
#   '2024-01-26T17:12:56Z',
#   '2024-01-26T17:12:56Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxvMSP80ggoq6lInsV4AaABAg',
#   '@ibnukhajar8410',
#   'Saya akan memilih dari sejarah dengan bukti nyata yg terbaik di antara yg terburuk ..',
#   0,
#   0,
#   'http://www.youtube.com/@ibnukhajar8410',
#   '2024-01-26T13:41:54Z',
#   '2024-01-26T13:41:54Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzxIXlaEVoyim0QPQR4AaABAg',
#   '@ZainalAbidin-xk7vz',
#   'Semoga Pak Ganjar Pranowo dan keluarga sehat selalu dan senantiasa dalam lindungan Allah SWT',
#   0,
#   0,
#   'http://www.youtube.com/@ZainalAbidin-xk7vz',
#   '2024-01-26T13:41:44Z',
#   '2024-01-26T13:41:44Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyXGwfvmJxQV5kn-Dh4AaABAg',
#   '@PecintaBurung168Channel',
#   'Menurut hemat saya...dlm forum perdebatan dgn tujuan visi dan misi kedepan yg di inginkan rakyat adalah gebrakan dan  perubahan mreka ingin dengar dan buktikan kedepan...dgn tdk mengurangi rasa hormat tidak perlu menilai kebijakan sebelumnya bahkan menyalahkan...kita orang kecil menitipkan amanah kepada para pemimpin demi kebijakan lebih baik kedepan...jika kita mudah menilai kesalahan orang lain...mari kita smua dgn sadar bisa menilai kinerja kita masing2 saat menjabat demi kedepan lebih baik....siapapun yg jadi kami percayakan....agar amanah dan mengurangi kekurangan2 sebelumnya tnpa harus menyalahkan...smoga indonesia smakin jaya dan smakin adil dan bersih amiiiin....salam dari rakyat kecil',
#   0,
#   0,
#   'http://www.youtube.com/@PecintaBurung168Channel',
#   '2024-01-26T12:16:07Z',
#   '2024-01-26T12:16:07Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw_Xa6Eemnk-Eje1cp4AaABAg',
#   '@ElectricAirConditioners',
#   '<a href="https://www.youtube.com/watch?v=anuQxiXpQ7I&amp;t=7968">2:12:48</a> &amp; <a href="https://www.youtube.com/watch?v=anuQxiXpQ7I&amp;t=1180">19:40</a>',
#   1,
#   0,
#   'http://www.youtube.com/@ElectricAirConditioners',
#   '2024-01-26T11:09:01Z',
#   '2024-03-13T08:54:46Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwXr-pwsgAxDjro4Vl4AaABAg',
#   '@inekesharon3107',
#   'All in prabowo Gibran.',
#   0,
#   0,
#   'http://www.youtube.com/@inekesharon3107',
#   '2024-01-26T04:49:02Z',
#   '2024-01-26T04:49:02Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxdaMjtojfhwfwSzIJ4AaABAg',
#   '@MuhammadIqbal-ix7oh',
#   'Yang paling gw tunggu adalah video komentar PARA AHLI tentang debat ini, bukan para pendukung atau pun buzzer🗿',
#   0,
#   0,
#   'http://www.youtube.com/@MuhammadIqbal-ix7oh',
#   '2024-01-26T03:58:04Z',
#   '2024-01-26T03:58:04Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugyy66Tjj4bfaf3AZXR4AaABAg',
#   '@zbbiiRental-fi4ho',
#   'Pengacara bodoh dah boleh berhenti minta peserta diam. Biar shj. Kamu bercakap guna microphone, suara kamu jelas boleh dengar, teruskan je lah bercakap tanpa perlu minta mereka diam. Biar shj. Pemeriah suasana, kalau terlalu bising barulah diminta diam. Ini setiap kali',
#   1,
#   0,
#   'http://www.youtube.com/@zbbiiRental-fi4ho',
#   '2024-01-26T02:11:07Z',
#   '2024-01-26T02:11:07Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxYheKJW56SxNbURB14AaABAg',
#   '@waitwhat753',
#   'Ganjar will win',
#   0,
#   0,
#   'http://www.youtube.com/@waitwhat753',
#   '2024-01-26T02:10:53Z',
#   '2024-01-26T02:10:53Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwnXD7-I1dyRhRGbDR4AaABAg',
#   '@khusenjosstv3620',
#   'pak mahfud da TOP setara dengan PRESIDEN intelektual tinggi,,,,bisa terbuka membasmi MAFIA tingkat TINGGI,,,tokoh yg pemberani membasmi pejabat koruptor',
#   0,
#   0,
#   'http://www.youtube.com/@khusenjosstv3620',
#   '2024-01-26T00:05:04Z',
#   '2024-01-26T00:05:04Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyxanLrQGimSktnRF14AaABAg',
#   '@sutanto6714',
#   'KPU RI harus bahas total tentang pemberantasan narkoba sampai seakar2 nya ... mohon di tambah materi di debat terakhir nanti .',
#   0,
#   0,
#   'http://www.youtube.com/@sutanto6714',
#   '2024-01-25T17:55:55Z',
#   '2024-01-25T17:55:55Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx7oVQnNApJ8Mn_KQZ4AaABAg',
#   '@DediIskandar-bh8ko',
#   'Anak ini benar2 tak punya adab... Angkuh sombong luar biasa... Bhaya negri ini...',
#   0,
#   0,
#   'http://www.youtube.com/@DediIskandar-bh8ko',
#   '2024-01-25T17:39:49Z',
#   '2024-01-25T17:39:49Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz0WwPffrBt5UnImF54AaABAg',
#   '@wurylaras5072',
#   'salah besar yg mikir siapapun presidennya ga ngaruh di hidup kita. justru ituu yg menentukan kebijakan kan mereka mau soal harga, pajak, umr, ump. makannya hak pilih nya digunakan se bijak mungkin yakan 😅',
#   0,
#   1,
#   'http://www.youtube.com/@wurylaras5072',
#   '2024-01-25T17:20:15Z',
#   '2024-01-25T17:20:15Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxa06BeYU4Co9S4iR54AaABAg',
#   '@akhtarpratama-uk1qs',
#   'All in Prabowo Gibran aminnnn ya Allah',
#   0,
#   0,
#   'http://www.youtube.com/@akhtarpratama-uk1qs',
#   '2024-01-25T16:37:26Z',
#   '2024-01-25T16:37:26Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgySpWGJfK3MqThvICl4AaABAg',
#   '@dewimega6857',
#   'ngefans bgt sama moderator',
#   0,
#   0,
#   'http://www.youtube.com/@dewimega6857',
#   '2024-01-25T08:28:41Z',
#   '2024-01-25T08:28:41Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzS16MnoK9FU_9OA194AaABAg',
#   '@karya.anak.bangsa',
#   'Q orang nu tp gk bkalan milih tokoh nu, karna cuma jadi wakil. Orang nu cuma di jadikan alat aja buat perbnyak suara.',
#   0,
#   1,
#   'http://www.youtube.com/@karya.anak.bangsa',
#   '2024-01-25T06:08:13Z',
#   '2024-01-25T06:08:13Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxBH9W09upLMbzFCAN4AaABAg',
#   '@pengunjung',
#   'Dua orang ini sangat gegabah berani melawan anak majikan.\r<br>Apa mereka gak tahu kalo bokapnya yang sakti mandragora bisa merubah macan menjadi keledai.\r<br>Apa mereka gak tahu nama-nama besar dunia persilatan seperti Mat Bahlul, Iwan Belo, Erik Bohir, Ridwan Kumel, Pakri Kamsiah, Ababrokman dan lainnya yang merapat kesana.<br>Itu baru kulitnya, belum intinya, bukan jawaranya.\r<br>Mereka lancang melawan gangster terkuat abad ini.',
#   0,
#   0,
#   'http://www.youtube.com/@pengunjung',
#   '2024-01-25T04:37:55Z',
#   '2024-01-25T04:37:55Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugyo-XKZFqtQuH3o89x4AaABAg',
#   '@supono1',
#   'yg ini lebih parah dr planga plongo 😮😮😮',
#   0,
#   0,
#   'http://www.youtube.com/@supono1',
#   '2024-01-24T23:56:41Z',
#   '2024-01-24T23:56:41Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy8iaM774hm4uDNrON4AaABAg',
#   '@user-sf4mc9fu9o',
#   'Ketiga ya hebat mnurut saya <br>Ada kelemahan sndiri sndiri 😅 <br>Jadi saya tidk coplos semua ya <br><br><br><br><br><br><br>Karna belum puyk KTp 😅',
#   1,
#   0,
#   'http://www.youtube.com/@user-sf4mc9fu9o',
#   '2024-01-24T16:41:35Z',
#   '2024-01-24T16:41:35Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyitpAttT6yRsMmhXN4AaABAg',
#   '@WakandaYt1125',
#   '2029 pak anis-prof mahfud presiden❤',
#   1,
#   0,
#   'http://www.youtube.com/@WakandaYt1125',
#   '2024-01-24T16:21:28Z',
#   '2024-01-24T16:21:28Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxdbzi4dxcLmaPYrwF4AaABAg',
#   '@TiaraIndraz-ss9to',
#   'All in pak prabowo',
#   2,
#   0,
#   'http://www.youtube.com/@TiaraIndraz-ss9to',
#   '2024-01-24T14:50:34Z',
#   '2024-01-24T14:50:34Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzqzRwrQBgjhXp96Yt4AaABAg',
#   '@TiaraIndraz-ss9to',
#   'Prabowo gibran',
#   2,
#   0,
#   'http://www.youtube.com/@TiaraIndraz-ss9to',
#   '2024-01-24T14:50:13Z',
#   '2024-01-24T14:50:13Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwL9ZyARKPAKdnpLoh4AaABAg',
#   '@zeezee126',
#   'Jika yg dianggap tua aja mengajarkan merendahkan orang lain, mencaci memojokkan orang lain, begitupula dngan yg muda akan balik merendahkan org yg lebih tua. Karena saling menghormati itu ada jika ada kata <b>saling</b> kalo gabisa menghargai yg muda, kalo gak ngejek diawal, ga nyenggol, gabakalan mungkin yg muda melakukan hal serupa sebagaimana yg tua menjelekkan dan memojokkannya. Intinee lek pengen diregani yo reganono disek. Bah tuwek bah enomm. Dalam debat jangan bawa&quot; umur!! PROFESIONAL!',
#   2,
#   0,
#   'http://www.youtube.com/@zeezee126',
#   '2024-01-24T13:06:07Z',
#   '2024-01-24T13:06:07Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugwl5XUPWKv79NV-b8N4AaABAg',
#   '@gelszipy1875',
#   'GIBRAN TU  JAWA ANGKUH,  SOMBONG,  BLAGU , ISINYA KOSONG GA ADA ISINYA... MASIH KECIL...,  JD KETUA KARANG TARUNA AJE. GIBRAN',
#   2,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T13:04:05Z',
#   '2024-01-24T13:04:05Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzbHySubzarlnaVz2Z4AaABAg',
#   '@gelszipy1875',
#   'UDALAH PRABOWO GA USAH PAKE GIBRAN,  PAK PRABOWO SENDIRIAN MALAH LEBIH KEREN D BANDING ADA GIBRAN,  GIBRAN GA GUNA.',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T13:02:19Z',
#   '2024-01-24T13:02:19Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzhBDIhojno8b1GQ7t4AaABAg',
#   '@gelszipy1875',
#   'GIBRAN CUMA APALAN DOANG KELIATAN...',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T13:00:38Z',
#   '2024-01-24T13:00:38Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgywSyQVRVVkXk4RZEZ4AaABAg',
#   '@gelszipy1875',
#   'GIBRAN GA USAH D AJAK NGOMONG TAUBAT EKOLOGI, IKLIM,  TAUBAT AGRARIA DLL,  , PERCUMA GIBRAN GA NGERTI.',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T12:59:24Z',
#   '2024-01-24T12:59:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwgpK-2--kHXmcpzSR4AaABAg',
#   '@gelszipy1875',
#   'RAME KRN SONGONG KPD YG LEBIH TUA DAN LEBIH PNTAR SEORANG PROFFESSOR.,  ANGGA UNGGUH SOPAN SANTUN NYA GA ADA BABAR BLASS KEPENGIN D GAPLOK SAMA PROF MAHFUD MD.,  MENTANG2 ANAK PAK JOKOWI JD SUDAH PUNTER BLAGU.',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T12:46:30Z',
#   '2024-01-24T12:46:30Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzx0OdBMkjkBViCN-J4AaABAg',
#   '@duniatradingdaninvestasi633',
#   'Mas Gibran nggoreng lagi dua orang tua sampe pada mlongo',
#   1,
#   0,
#   'http://www.youtube.com/@duniatradingdaninvestasi633',
#   '2024-01-24T11:03:01Z',
#   '2024-01-24T11:03:01Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwH0bfn5nDScC4bvaF4AaABAg',
#   '@user-hq3hs1mk3c',
#   'Anis wajah Sengkuni menit brpa bro😂',
#   1,
#   0,
#   'http://www.youtube.com/@user-hq3hs1mk3c',
#   '2024-01-24T08:35:45Z',
#   '2024-01-24T08:35:45Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzuZlVVuB5pG_Z9Rzt4AaABAg',
#   '@gelszipy1875',
#   'KALO GA ADA SAMSUL GA RAME....',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T06:57:43Z',
#   '2024-01-24T06:57:43Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxXGFNPGMelFL-zJNB4AaABAg',
#   '@gelszipy1875',
#   'ENAK SI ADA SAMSUL JD RAME.....',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T06:57:20Z',
#   '2024-01-24T06:57:20Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwzUvq6lVzqRMu_g0l4AaABAg',
#   '@gelszipy1875',
#   'KALO MIMPIN NYA BENER GA AKAN TERJADI INFLASI HIJAU  , ITU YG D MAKSUD RECE, BILANG AJE DEMON TRASI TURUN K JALAN,  DASAR JAWIR GITU AJA PAKE ISTILAH ASING,  KEJADIAN PERANCIS.',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T06:52:44Z',
#   '2024-01-24T06:52:44Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxxvSY1HALA0R47mVd4AaABAg',
#   '@helveticastandard9264',
#   'selalu pingin nangis denger orang orang nyanyi padamu negeri <a href="UCkszU2WH9gy1mb0dV-11UJg/b8IfY7zOK9iVkNAP_I2A-AY"></a>',
#   0,
#   0,
#   'http://www.youtube.com/@helveticastandard9264',
#   '2024-01-24T06:49:16Z',
#   '2024-01-24T06:49:16Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx4_JIj0Z3sdNLcZMl4AaABAg',
#   '@helveticastandard9264',
#   '<a href="https://www.youtube.com/watch?v=anuQxiXpQ7I&amp;t=11044">3:04:04</a> itu gpp kah yang jatuh, kayaknya sakit banget',
#   0,
#   0,
#   'http://www.youtube.com/@helveticastandard9264',
#   '2024-01-24T06:47:19Z',
#   '2024-01-24T06:47:19Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwiAwldnXtoe9mDgfd4AaABAg',
#   '@madage2729',
#   '<a href="https://www.youtube.com/watch?v=anuQxiXpQ7I&amp;t=6017">1:40:17</a> kena lo',
#   0,
#   0,
#   'http://www.youtube.com/@madage2729',
#   '2024-01-24T06:24:28Z',
#   '2024-01-24T06:24:28Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyRLu9yqabZ1Ecpq1B4AaABAg',
#   '@divavarella8275',
#   'Sok sok an pada ngomongin etika ga inget debat kemaren mainya keroyokan wkwkwkwkwk lucu banget',
#   2,
#   0,
#   'http://www.youtube.com/@divavarella8275',
#   '2024-01-24T05:58:35Z',
#   '2024-01-24T05:58:35Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxJ_h4bF4F46sAkJQt4AaABAg',
#   '@gelszipy1875',
#   'DAN KPD MASYARAKAT INDONESIA KITA HARUS TRANSPARAN JANGAN MEMBOHONGI ATAU NGPETIN DATA MULU,  KALO KITA GA BICARA DATA,  REALIATA YG ADA KAKIAN SEBAGAI PIMPINAN BUKAN PEMUMPIN,  AKAN BISA MEMBHONGI RAKYAT INDOSIA MULU,  JD SEMUA KITA HARUS MIKIR RAKYAT DAN PIMPINAN, KRN KARENA KALIAN GA ADA YG BECUS JD PEMIMPIN ITU MULIA DAN AGUNG D BAWA KORDINADI ALLAH SWT,  KALO PIMPINAN ITU UGAL2 AN UDAH NYEBUR JURANG MADIH D BILANG NARASI NAKUTIN PD MASYARAKAT INDONESIA,  GITU KO OTAK MIKIR PENGIN JD PEMIMPIN NDAS MU!!!!!!!',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:58:33Z',
#   '2024-01-24T05:58:33Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgymDX0R1v4rdiqgZGx4AaABAg',
#   '@gelszipy1875',
#   'MASALAH BERAS...,  SAMSUL,  BUKAN MADALAH NARASI TAPI KITA BICARA REALITA SAMSUL BLOON...!!!!!!',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:52:22Z',
#   '2024-01-24T05:52:22Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxVw-7YuFyH7GaygbN4AaABAg',
#   '@divavarella8275',
#   'PRABOWO GIBRAN AMIN YAALLAH',
#   2,
#   0,
#   'http://www.youtube.com/@divavarella8275',
#   '2024-01-24T05:50:01Z',
#   '2024-01-24T05:50:01Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxX0wM6vu3fIkGNZVV4AaABAg',
#   '@gelszipy1875',
#   'PRAKTEKNYA BANYAK MAFIA D LAPANGAN NYATANYA GA BISA MENYELESAIKAN KASUS MAFIA,  GITU KATA FROF MAHFUD MD.',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:48:59Z',
#   '2024-01-24T05:48:59Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyL2EsDmLyoORyOZJx4AaABAg',
#   '@gelszipy1875',
#   'JANGAN NIKEL2 AN URUSAN RAKYAY INDONESIA AJA BIAR HIDUP CUKUP MAKAN SEJAHTERA...,  SAMPAI SEKARANG GA SEJAHERA BELUM SEJATERA,  MASUH BANYAK YG KURANG MAKAN GOBLOG....!!!!!!',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:45:17Z',
#   '2024-01-24T05:45:17Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzjh_x0rJChRHLNmKR4AaABAg',
#   '@gelszipy1875',
#   'DIAJAK CERDAS CERMAT SAMA SAMSUL...',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:43:01Z',
#   '2024-01-24T05:43:01Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw_3DSy08DXRrpC3K54AaABAg',
#   '@gelszipy1875',
#   'ANAK KECIL SONGONG....',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:40:46Z',
#   '2024-01-24T05:40:46Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwCtUEUF6XXkoYtNfp4AaABAg',
#   '@gelszipy1875',
#   'LULUS S2 , JUGA NGGA,  S1 MASIH MERAGUKAN,  E... SAMA PROF.  PRAKTISI YG YG SUDAH MALANG MELINTANG SONGONG,  ORANG JAWA TERKENAL PUNYA ETIKA, SOPAM SANTUN,  JGN SENGA&#39;F TEMPAT SAKRAL PARA NTELEKTUAL INDONESIA,     INI KAYA ANAK KECIL UDAH BEGO SONGONG SAMA PRAKTISI PROFFESOR DASAR SAMDUL GEMBLUNG.',
#   0,
#   0,
#   'http://www.youtube.com/@gelszipy1875',
#   '2024-01-24T05:37:33Z',
#   '2024-01-24T05:37:33Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxwUUA51BeAO13x2nV4AaABAg',
#   '@alwaysmusic5781',
#   'Pertanyaan receh aja gak bisa jawab, apalagi Pertanyaan yg sulit😂, padahal yg dipertanyakan bukan singkatan dan sudah dijelaskan beserta contohnya, tapi tetap saja tidak bisa menjawab, ujung-ujungnya gak mau jawab dengan alasan Pertanyaan receh😂, kirain bakalan dijawab dengan mudah oleh seorang profesor',
#   3,
#   1,
#   'http://www.youtube.com/@alwaysmusic5781',
#   '2024-01-24T05:19:29Z',
#   '2024-01-24T05:19:29Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz0bkUJGdCoAsr3pUl4AaABAg',
#   '@jomblosmp5896',
#   'yuk semuanya bilang AMIN, bahwa PRABOWO MENANG , KARENA GANJAR',
#   1,
#   0,
#   'http://www.youtube.com/@jomblosmp5896',
#   '2024-01-24T04:25:23Z',
#   '2024-01-24T04:25:23Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzVzRPu_tpMrEAvhGd4AaABAg',
#   '@qineschannel777',
#   'Apa nih..pertanyaan kayak gitu sj ogah dia jawab, bagaimana masalah&quot; kecil nanti yg ada di negri ini, mana mau dia selesaikan pantas banyak mafia&quot; yg belum dia selesaikan seperti omogannya tumpul hukum padahal dia mentri polhukam loh... Idih idih',
#   2,
#   0,
#   'http://www.youtube.com/@qineschannel777',
#   '2024-01-24T03:59:25Z',
#   '2024-01-24T03:59:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxPpsTDFzmRmQNzD1Z4AaABAg',
#   '@IdhaPhesek-dn1cx',
#   'Suaranya GK pales masih kecil pintar😂 ngomongnya😂😂',
#   1,
#   0,
#   'http://www.youtube.com/@IdhaPhesek-dn1cx',
#   '2024-01-24T03:47:00Z',
#   '2024-01-24T03:47:00Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwMLqrqHJ-5p751YZR4AaABAg',
#   '@user-wo4sb8ql3m',
#   'Aku sbg generasi milenial dukung pa mahfud😌',
#   0,
#   0,
#   'http://www.youtube.com/@user-wo4sb8ql3m',
#   '2024-01-24T03:35:14Z',
#   '2024-01-24T03:35:14Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwXL_7ynFjhZ1WxcYl4AaABAg',
#   '@datikastuti7429',
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂',
#   1,
#   0,
#   'http://www.youtube.com/@datikastuti7429',
#   '2024-01-24T02:56:28Z',
#   '2024-01-24T02:56:28Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzOIahWYQPFrKo3Kkd4AaABAg',
#   '@FARHAN-un5gg',
#   '.',
#   0,
#   0,
#   'http://www.youtube.com/@FARHAN-un5gg',
#   '2024-01-24T02:13:43Z',
#   '2024-01-24T02:13:43Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxh2-a9RnuT8Kqq4MV4AaABAg',
#   '@PeterDongan',
#   'Jika ada perusahaan tambang yang izin pertambangannya di wilayah konsesi sudah habis, namun perusahaan tambang tersebut tetap melakukan kegiatan pertambangan di wilayah konsesinya, maka kegiatan pertambangan perusahaan tersebut dianggap ilegal, sehingga harus dicabut IUP-nya dan harus diselidiki indikasi pidananya. Inilah yang dimaksud oleh Gibran.',
#   2,
#   0,
#   'http://www.youtube.com/@PeterDongan',
#   '2024-01-24T00:40:59Z',
#   '2024-01-24T00:40:59Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyJWhBpXzBzWDUT0k54AaABAg',
#   '@sekaramalinaaa',
#   'serius nanya undian daftar pertanyaannya kok dapet A mulu sih min?',
#   0,
#   0,
#   'http://www.youtube.com/@sekaramalinaaa',
#   '2024-01-24T00:15:03Z',
#   '2024-01-24T00:15:03Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz1CZ7PJ6tHL4uKAKl4AaABAg',
#   '@rayzenin',
#   'mas Gibran yg muda yg berbakat,visi misinya jelas melanjutkan yg sudah ada',
#   6,
#   0,
#   'http://www.youtube.com/@rayzenin',
#   '2024-01-24T00:10:26Z',
#   '2024-01-24T00:10:26Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugwkc-jY3u8k4vqYy2V4AaABAg',
#   '@arifrahayuni',
#   'Prabowo Subianto - Gibran Rakabuming Raka RI 1 &amp; 2 🇲🇨 2024 ✌️🌹🔥',
#   12,
#   0,
#   'http://www.youtube.com/@arifrahayuni',
#   '2024-01-24T00:06:02Z',
#   '2024-01-24T00:06:02Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwwJezI0ev2fM6W_1d4AaABAg',
#   '@johanseimima5308',
#   'TR.slnk.Jojoh',
#   0,
#   0,
#   'http://www.youtube.com/@johanseimima5308',
#   '2024-01-23T23:39:13Z',
#   '2024-01-23T23:39:13Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy39IHAKpH3sXB_WCt4AaABAg',
#   '@jonsoul-ny4lm',
#   'Dukung Prabowo, Hargai Ganjar, InsyaAllah Amin yang menang',
#   1,
#   1,
#   'http://www.youtube.com/@jonsoul-ny4lm',
#   '2024-01-23T21:46:08Z',
#   '2024-01-23T21:46:08Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgypNp6t2K29_rIHk614AaABAg',
#   '@rahmizamiza127',
#   'INDONESIA butuh pemimpin yang sehat lahir batin menjadi cotoh toladam bagi Dunia <br>Aamiin',
#   6,
#   0,
#   'http://www.youtube.com/@rahmizamiza127',
#   '2024-01-23T21:25:35Z',
#   '2024-01-23T21:25:35Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgweXFQ7qW6PbAPVF6l4AaABAg',
#   '@yayan6603',
#   'Kami pilih presiden pribumi asli yg pasti cinta nkri.<br>Bukan warga imigran yaman munafiqun bergaya agamis yg memperpecah belah umat dan nkri',
#   2,
#   1,
#   'http://www.youtube.com/@yayan6603',
#   '2024-01-23T19:44:21Z',
#   '2024-01-23T19:44:21Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwFIfb3OTt2IyaVJIR4AaABAg',
#   '@user-nc4ss7yy6k',
#   'Kasian moderator, penotonnya udahh besorak2 terus😂',
#   1,
#   0,
#   'http://www.youtube.com/@user-nc4ss7yy6k',
#   '2024-01-23T19:42:13Z',
#   '2024-01-23T19:42:13Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyOvJgLr-WBeqH5qLl4AaABAg',
#   '@Ernesto06',
#   'Intinya siapapun presiden indo yg kepilih hidup kita sama aja. ingat hidup sebagian besar orang termasuk kamu nggak akan banyak berubah kecuali kamu seorang anggota parpol atau keluarga pejabat, apalagi kita ini cuma kacung kampret rakyat kebanyakan, rajin rajinlah bekerja cuma dengan cara itu hidup kita bisa lebih baik.',
#   2,
#   1,
#   'http://www.youtube.com/@Ernesto06',
#   '2024-01-23T19:04:30Z',
#   '2024-01-24T06:06:27Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzg8OLM3zDcyRHRHaJ4AaABAg',
#   '@bednyng2794',
#   'Catatan buat semua Cawapres, ternyata banyak sekali PR anda utk memperbaiki negara ini, persoalannya apakah anda2 semua komit untuk menjalankannya, atau hanya komat kamit nantinya <br>Gibran : Anda sangat konvensional sebagai anak muda hanya menjual ide2 hilirlisasi NIKEL, seharusnya anda befikir ekonomi kreatif dan inovasi termasuk bagaimana anak muda mau kembali ke desa untuk membuat inovasi desa<br>Pak Mahfud, terimakasih sudah mau memberikan informasi bahwa MAFIA dan KORUPSI merajalela dimana2, ternyata pemerintahan JOKOWI bagus itu hanya MITOS saja',
#   1,
#   1,
#   'http://www.youtube.com/@bednyng2794',
#   '2024-01-23T17:39:43Z',
#   '2024-01-23T17:39:43Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwJ6ZBobMlNCuqiqyB4AaABAg',
#   '@randrafara2',
#   'Pak mahfud udah menguasai trias politica dan selayaknya dengan bekal pengalaman yang segudang keluarga kami berharap bangsa besar ini kami titipkan di pundakmu',
#   0,
#   0,
#   'http://www.youtube.com/@randrafara2',
#   '2024-01-23T17:29:42Z',
#   '2024-01-23T17:29:42Z']]

# %%
"""
Melakukan proses pengambilan data sebanyak 1.040 data rangkaian komentar utama dari video
debat babak keempat capres-cawapres yang ditayangkan dan di-upload oleh channel Youtube KPU RI
"""
next_page_data_scraping = 1040


while len(list_fourth_video_debate_kpuri) < next_page_data_scraping:
    """
    Mendapatkan data-data komentar pada video YouTube debat babak keempat calon
    Presiden-Wakil Presiden Indonesia dari channel YouTube KPU RI yang berada di halaman
    berikutnya (data-data setelah baris ke-100/indeks baris data ke-99)
    
    Di samping itu, "video_youtube_response" merupakan variabel yang menjalankan
    perintah untuk mendapatkan 100 data komentar dari video ID yang telah didefinisikan pada commentThreads().
    Itu berarti jumlah data yang akan diambil pada halaman-halaman berikutnya berjumlah 100 data komentar
    """
    try:
        nextPageToken = video_youtube_data_response["nextPageToken"]
    except KeyError:
        break
    nextPageToken = video_youtube_data_response["nextPageToken"]
    
    
    """
    Melakukan proses pengambilan objek kembali menggunakan fungsi "commentThreads()" atas data-data
    rangkaian komentar utama dari video YouTube berdasarkan identifikasi unik dari video tersebut yaitu ID Video yang membahas
    tentang debat capres-cawapres 2024. Namun yang membedakan antara "commentThreads()" sebelumnya dengan saat ini
    adalah jika "commentThreads()" sebelumnya hanya dapat mengambil jumlah maksimal data komentar yang ditentukan oleh
    Google YouTube Data API. Walaupun kita menginginkan lebih dari 100 data sehingga kita mendefinisikan nilai pada
    parameter "maxResults" yakni 270 komentar, 1.619 teks komentar, 9.390 komentar, dll., tetapi hasil akhirnya
    tidak berpengaruh terhadap jumlah data yang berhasil diambil dengan teknik data scraping pada video YouTube.
    Karena pada dasarnya service YouTube Data API v3 memiliki limit/batasan jumlah data yang dapat diambil dari
    suatu konten video YouTube yaitu hanya 100 komentar.
    
    Maka dari itu dengan menggunakan parameter baru yang terdapat di dalam "commentThreads()" yaitu parameter "pageToken"
    dengan nilai yakni nextPageToken, proses pengambilan data komentar lebih dari 100 sangat memungkinkan untuk dilakukan
    sebab nilai nextPageToken akan melakukan proses identifikasi, mencari dan mengambil data/informasi dari rangkaian
    komentar utama yang berada di halaman-halaman berikutnya selain data yang sebelumnya telah berhasil diambil
    menggunakan format default dari parameter maxResults yaitu hanya 100 data komentar sesuai limit dari API YouTube Data v3
    """
    nextRequest = youtube_scrape_comment_objects.commentThreads().list(
        part = "snippet", # snippet pada parameter part adalah objek list dari seluruh elemen yang dimiliki oleh komentar utama
        videoId = "anuQxiXpQ7I", # ID dari video debat babak keempat capres-cawapres yang di-upload oleh channel YouTube KPU RI 
        #maxResults = 1040, # Jumlah data yang ingin diambil setelah 100 data berhasil di-scraping (sesuai dengan limit API)
        order = "time", # Permintaan untuk mendapatkan tanggal dan waktu komentar paling terbaru dari ID video
        pageToken = nextPageToken # Data selanjutnya akan diambil dari halaman-halaman selain halaman paling awal dari video
    )
    
    
    """
    Mengeksekusi proses permintaan untuk dapat mengambil data-data komentar yang berada
    di halaman-halaman berikutnya (selain 100 data komentar yang telah berhasil diambil pada script sebelumnya) dari video
    debat capres-cawapres babak keempat yang di-upload oleh Channel YouTube KPU RI yang memiliki ID video yaitu KJdt-HBBGIo
    """
    video_youtube_data_response = nextRequest.execute()
    
    
    for item in video_youtube_data_response["items"]:
        video_id = item["snippet"]["videoId"] # Mendapatkan ID video debat babak keempat capres-cawapres
        total_reply_count = item["snippet"]["totalReplyCount"] # Mendapatkan jumlah total balasan/reply dari komentar utama
        comment_id = item["id"] # Mendapatkan seluruh ID dari setiap teks komentar utama dari video debat babak keempat
    
    
        """
        Mendapatkan seluruh elemen item per masing-masing komentar utama yang menjadi struktur
        pembentuk dasar dari komentar utama berdasarkan video ID yang sebelumnya telah diinisialisasikan.
        Jenis objek yang menjadi struktur/rangkaian detail atas masing-masing komentar utama adalah channel ID,
        teks komentar, jumlah like pada komentar tersebut, tanggal dan waktu dibuatnya komentar,
        nama akun user yang berkomentar di dalam video tersebut, dll

        Perlu diketahui jika elemen item yang terdapat pada top level comment dan commentThreads() berbeda tetapi
        dapat digabungkan menjadi satu kesatuan. Elemen seperti video id,
        jumlah user yang membalas/merespon teks komentar utama, dan lainnya
        termasuk di dalam elemen item yang dimiliki oleh commentThreads()
        karena sifatnya adalah informasi general dari rangkaian komentar utama

        Sedangkan elemen item yang dimiliki oleh top level comment lebih bersifat informasi yang spesifik yang dimiliki oleh
        masing-masing komentar utama atau komentar balasan atas komentar utama.
        Elemen item seperti nama user/akun yang berkomentar, isi atas masing-masing teks komentar yang dibuat oleh
        setiap akun yang berkomentar, jumlah user yang menyukai isi dari teks komentar utama, dan lainnya
        termasuk ke dalam item-item yang dimiliki oleh top level comment
        """
        comment_items = item["snippet"]["topLevelComment"]["snippet"]
    

        """
        Memasukkan atribut/elemen utama ke dalam variabel list kosong yaitu "list_fourth_video_debate_kpuri" yang akan
        berisikan beberapa objek item/elemen dari serangkaian komentar utama seperti ID video,
        ID Channel yang mem-publish/meng-upload video tersebut, nama akun user yang berkomentar beserta teks komentar,
        tanggal pembuatan komentar untuk video tersebut,
        jumlah total like sebagai bentuk respon setuju pada komentar yang telah dibuat oleh user, dll.

        Catatan tambahan bahwasanya variabel "video_id", "total_reply_count", "comment_id" dan "comment_items"
        termasuk ke dalam elemen utama yang akan dimasukkan ke dalam list kosong (empty list) yang bernama
        "list_fourth_video_debate_kpuri" yang nantinya list yang bernama "list_fourth_video_debate_kpuri"
        akan menjadi struktur kolom di dalam Pandas DataFrame
        """
        list_fourth_video_debate_kpuri.append([
            video_id, # Memasukkan ID video debat babak keempat capres-cawapres yang di-upload oleh channel YouTube KPU RI
            comment_items["channelId"], # Memasukkan ID yang dimiliki oleh channel YouTube KPU RI ke dalam variabel list
            comment_id, # Memasukkan ID dari seluruh komentar yang dibuat oleh penonton video debat babak keempat ke dalam list
            comment_items["authorDisplayName"], # Memasukkan seluruh nama akun YouTube yang berkomentar ke dalam empty list
            comment_items["textDisplay"], # Memasukkan teks komentar utama yang ada di dalam video debat keempat ke dalam list
            comment_items["likeCount"], # Memasukkan jumlah total yang menyukai isi teks komentar utama ke dalam list
            total_reply_count, # Memasukkan jumlah total balasan yang diterima oleh teks komentar utama ke dalam empty list
            comment_items["authorChannelUrl"], # Memasukkan URL/link channel akun YouTube para penonton video debat babak ke-4
            comment_items["publishedAt"], # Memasukkan tanggal dan waktu saat teks komentar utama dibuat pertama kali oleh user
            comment_items["updatedAt"] # Memasukkan tanggal dan waktu saat teks komentar utama mengalami perubahan isi
        ])
        

"""
Menampilkan jumlah data yang dimiliki beberapa elemen item yang saat ini disimpan di dalam
variabel list "list_fourth_video_debate_kpuri" setelah dilakukan proses
penyeleksian (filter) atas beberapa elemen item dari serangkaian komentar utama dan juga telah
dilakukan proses looping request untuk mendapatkan data lebih dari 100 komentar
"""
print("Jumlah Data yang Dimiliki oleh Variabel List 'list_fourth_video_debate_kpuri' setelah Proses Looping adalah",
      len(list_fourth_video_debate_kpuri))
# Out:
# Jumlah Data yang Dimiliki oleh Variabel List 'list_fourth_video_debate_kpuri' setelah Proses Looping adalah 1040

# %%
"""
Menampilkan 11 data/informasi teratas dari serangkaian komentar utama dari hasil proses penyeleksian
beberapa objek elemen item dari yang telah disimpan di dalam variabel list "list_fourth_video_debate_kpuri"
dengan jumlah data yang didapatkan sebanyak 1.040 data komentar dengan sumber data komentarnya
berasal dari video debat capres-cawapres babak keempat yang ditayangkan oleh channel Youtube KPU RI yang ID Video anuQxiXpQ7I
"""
list_fourth_video_debate_kpuri[:11]
# Out:
# [['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxDCjTyd2CYZfTUpSB4AaABAg',
#   '@ulya_rahma',
#   'Peningkatan fasilitas kesehatan akan meningkatkan kualitas pelayanan medis',
#   0,
#   0,
#   'http://www.youtube.com/@ulya_rahma',
#   '2024-04-24T17:17:25Z',
#   '2024-04-24T17:17:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzSj3SmHsfHFl6gxId4AaABAg',
#   '@nurlela-zd4rv',
#   '<a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKuhL0PlbiA2AE"></a>',
#   0,
#   0,
#   'http://www.youtube.com/@nurlela-zd4rv',
#   '2024-04-22T23:04:29Z',
#   '2024-04-22T23:04:29Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwomMhPe_dJHE0LSxR4AaABAg',
#   '@user-rb6gr6ee2n',
#   'Mantap Mas Gibran sangat kekinian dan mengikuti perkembangan jaman ,sangat perlu kemandirian masyarakat utk memoderenisasi Indonesia.',
#   0,
#   0,
#   'http://www.youtube.com/@user-rb6gr6ee2n',
#   '2024-04-03T19:38:24Z',
#   '2024-04-03T19:38:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxb3HWjWURZqCXjYsF4AaABAg',
#   '@abdulchalik9807',
#   'Klo org indonesaia dah hatam soal toreransi krn banyak agama di indobesia tapi aman dan damai, coba klo negara lain islam yg minoritas dah pasti di gencet...😂',
#   0,
#   0,
#   'http://www.youtube.com/@abdulchalik9807',
#   '2024-03-12T17:21:06Z',
#   '2024-03-12T17:21:06Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz8FNs0NpteSM7EZ-N4AaABAg',
#   '@AlangHartawan',
#   '😮😮😮😮pp n npn nnm h.......m',
#   0,
#   0,
#   'http://www.youtube.com/@AlangHartawan',
#   '2024-03-10T21:07:00Z',
#   '2024-03-10T21:07:00Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwbMtw3YLhTLVI2YNd4AaABAg',
#   '@dldiprasetyo9487',
#   'Diproses hukum ketua KPU beserta teman temannya karena sudah membuat kecurangan biar membuat jera para pembuat kecurangan agar tidak terjadi lagi dan berani berbuat.',
#   0,
#   0,
#   'http://www.youtube.com/@dldiprasetyo9487',
#   '2024-03-10T09:09:25Z',
#   '2024-03-10T09:09:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz6vBxRR-XOCIXm1114AaABAg',
#   '@holly-nd2yx',
#   'Awas lho.... Greenfalation diPerancis bakal terjadi di Indonesia lho... harga pajak BBM bakal naik tinggi lho.. buat menopang makan siang &amp; susu gratis bagi para anak sekolah lho.. awas PDB utang luar negri bakal meningkat.',
#   0,
#   0,
#   'http://www.youtube.com/@holly-nd2yx',
#   '2024-03-03T18:24:09Z',
#   '2024-03-03T18:24:09Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugziskn3dxd5vjv_GeF4AaABAg',
#   '@user-ut5gc2zk3w',
#   'Prabowo Gibran presidency vice presidency',
#   0,
#   0,
#   'http://www.youtube.com/@user-ut5gc2zk3w',
#   '2024-03-02T09:33:25Z',
#   '2024-03-02T09:33:25Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxSuCnCPBtvdWzny7t4AaABAg',
#   '@geovanyalmachzumi1646',
#   '5 4 <br><br>C😊4 c',
#   0,
#   0,
#   'http://www.youtube.com/@geovanyalmachzumi1646',
#   '2024-03-01T20:15:24Z',
#   '2024-03-01T20:15:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugyam43z68eoFJjqWxV4AaABAg',
#   '@geovanyalmachzumi1646',
#   '5 4 <br><br>C😊4',
#   0,
#   0,
#   'http://www.youtube.com/@geovanyalmachzumi1646',
#   '2024-03-01T20:15:24Z',
#   '2024-03-01T20:15:24Z'],
#  ['anuQxiXpQ7I',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxs49MfV4YTZTzOg714AaABAg',
#   '@Laryan1892',
#   'Semuanya bagus tapi maaf saya pilih Gibran ❤',
#   0,
#   0,
#   'http://www.youtube.com/@Laryan1892',
#   '2024-02-21T02:26:51Z',
#   '2024-02-21T02:26:51Z']]

# %%
fourth_debate_video_df = pd.DataFrame(list_fourth_video_debate_kpuri, columns=["video_id", "channel_id", "comment_id",
                                                                               "author", "text_comment", "like_count",
                                                                               "total_reply", "channel_url",
                                                                               "published_date", "updated_date"])

# Menampilkan 39 data teratas yang dimiliki dan tersimpan di dalam variabel DataFrame "fourth_debate_video_df"
fourth_debate_video_df.head(39)
# Out:
#        video_id                channel_id                  comment_id  \
# 0   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxDCjTyd2CYZfTUpSB4AaABAg
# 1   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgzSj3SmHsfHFl6gxId4AaABAg
# 2   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwomMhPe_dJHE0LSxR4AaABAg
# 3   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugxb3HWjWURZqCXjYsF4AaABAg
# 4   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugz8FNs0NpteSM7EZ-N4AaABAg
# 5   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwbMtw3YLhTLVI2YNd4AaABAg
# 6   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugz6vBxRR-XOCIXm1114AaABAg
# 7   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugziskn3dxd5vjv_GeF4AaABAg
# 8   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxSuCnCPBtvdWzny7t4AaABAg
# 9   anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugyam43z68eoFJjqWxV4AaABAg
# 10  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugxs49MfV4YTZTzOg714AaABAg
# 11  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugzza8JHYHKZTaXc9Eh4AaABAg
# 12  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxOX-D1fPsWdv6zDDF4AaABAg
# 13  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgyVwpNlGMyKgARBrph4AaABAg
# 14  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgycJgEGglTfo1VmODB4AaABAg
# 15  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxrGEvwMvKzcVTosTR4AaABAg
# 16  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugzw4SVHGv9bfjOamsp4AaABAg
# 17  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugw5v_QE3ZJ0Gh9h_I94AaABAg
# 18  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwR-Us-6XlYiLq6P7Z4AaABAg
# 19  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgzFNydv46dczeLt7YF4AaABAg
# 20  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwByhc8P5zxzcVN1Ih4AaABAg
# 21  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxRRVrzP_mpT5GU6Ud4AaABAg
# 22  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugx6qgGEkafPrkDFwQ94AaABAg
# 23  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwTEWF7tkM6gZQ_uo94AaABAg
# 24  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxWDwb3_aeyL8wCuU94AaABAg
# 25  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgzNfSLnoHUB_l-j6wB4AaABAg
# 26  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugw-4nF3hlVn6SI3mvp4AaABAg
# 27  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwIz9h0cwoCCWHzuTR4AaABAg
# 28  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugz-LCtMcyKmUsxqFIt4AaABAg
# 29  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwJbATRQbHOHXkgh-h4AaABAg
# 30  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugz-yXiouMKdR-yPcvp4AaABAg
# 31  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugy0d4089RMsLrcVWl14AaABAg
# 32  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxyQc6LWAlzyYsJPn54AaABAg
# 33  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugy2dlp5pI7VZi37Ut94AaABAg
# 34  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  Ugw-Ukkj1IXXnI68ATp4AaABAg
# 35  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgwHw1Bgr8Q55Tph1ZV4AaABAg
# 36  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgyB7HGX3QdgcLnvi6p4AaABAg
# 37  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgxvMSP80ggoq6lInsV4AaABAg
# 38  anuQxiXpQ7I  UCVdSz86o9q2cQKvAQ5QhOYg  UgzxIXlaEVoyim0QPQR4AaABAg
#
#                     author                                       text_comment  \
# 0              @ulya_rahma  Peningkatan fasilitas kesehatan akan meningkat...
# 1           @nurlela-zd4rv  <a href="UCkszU2WH9gy1mb0dV-11UJg/G8AfY6yWGuKu...
# 2         @user-rb6gr6ee2n  Mantap Mas Gibran sangat kekinian dan mengikut...
# 3         @abdulchalik9807  Klo org indonesaia dah hatam soal toreransi kr...
# 4           @AlangHartawan                         😮😮😮😮pp n npn nnm h.......m
# 5        @dldiprasetyo9487  Diproses hukum ketua KPU beserta teman temanny...
# 6             @holly-nd2yx  Awas lho.... Greenfalation diPerancis bakal te...
# 7         @user-ut5gc2zk3w          Prabowo Gibran presidency vice presidency
# 8   @geovanyalmachzumi1646                                  5 4 <br><br>C😊4 c
# 9   @geovanyalmachzumi1646                                    5 4 <br><br>C😊4
# 10             @Laryan1892       Semuanya bagus tapi maaf saya pilih Gibran ❤
# 11               @DeniCeka                      gibran planga plongo....stres
# 12        @cahayaislam3181                                          Sehat Gus
# 13      @mancingngoyor9892  Assalamualaikum Wr Wb <br>Salam silaturahmi,<b...
# 14  @nurulfadnanyputri4259                                                  💙
# 15              @HaanHaan_  Gibran sok sok bilang hilirisasi preeettt!!! <...
# 16                @snfdh04                     1&amp;3 black campaign terossa
# 17                  @b36.9  sumpahh audio nya jelek bgttttttt T.T plss bik...
# 18        @user-em4bn2cv4g  Je ien ueh isbxieh iebcieh uebcuebciehicehi eb...
# 19    @AlvinoPratama-sl4gg                                              keren
# 20     @mariafransisca5803                                  Hebat tiga2nya...
# 21           @madecahyanii                  bjir akun kpu ri jg penuh buzzer😢
# 22        @user-ms4cy7ub1w                                      Pak mahfud ❤🎉
# 23          @xl7rossonerri  bansos dari pajak rakyat . diaku aku . dipingg...
# 24            @DedeKuswara  Hahah debat lagi nih siapa yang tertindas lagi...
# 25          @arilmizan5724                         Yang cerdas gak pilih anis
# 26        @user-te7cv1ib5h      Cak Imin  ,kalian pak Mahmud wejanganya bagus
# 27          @alfinaprianto  <a href="https://www.youtube.com/watch?v=anuQx...
# 28       @darman_gunarto18  Partisipasi dalam Pemilu adalah investasi kita...
# 29   @nurdiansyahdimas6380  saling menjatuhkan,,, pencerminan bukan calon ...
# 30            @Kaset_Talim  Baju nya percis baju konoha <br><br>Wah ...<br...
# 31      @genshinimpact6472  pak capres dan cawapres tolong segera usir tu ...
# 32         @madewendra2362                                 Yg muda memang top
# 33          @blackmask4647  Lamun Anak RT,Geus Di jadikeun bebegig sawah k...
# 34          @blackmask4647  Seperti kata Pak Prabowo,kalo gk Pinter... ya ...
# 35           @FARHAN-un5gg                                                  .
# 36     @sutrisnotrisno1907  kalau mau melanjutkan dievaluasi dulu, yang ke...
# 37         @ibnukhajar8410  Saya akan memilih dari sejarah dengan bukti ny...
# 38     @ZainalAbidin-xk7vz  Semoga Pak Ganjar Pranowo dan keluarga sehat s...
#
#     like_count  total_reply                                    channel_url  \
# 0            0            0             http://www.youtube.com/@ulya_rahma
# 1            0            0          http://www.youtube.com/@nurlela-zd4rv
# 2            0            0        http://www.youtube.com/@user-rb6gr6ee2n
# 3            0            0        http://www.youtube.com/@abdulchalik9807
# 4            0            0          http://www.youtube.com/@AlangHartawan
# 5            0            0       http://www.youtube.com/@dldiprasetyo9487
# 6            0            0            http://www.youtube.com/@holly-nd2yx
# 7            0            0        http://www.youtube.com/@user-ut5gc2zk3w
# 8            0            0  http://www.youtube.com/@geovanyalmachzumi1646
# 9            0            0  http://www.youtube.com/@geovanyalmachzumi1646
# 10           0            0             http://www.youtube.com/@Laryan1892
# 11           0            0               http://www.youtube.com/@DeniCeka
# 12           0            0        http://www.youtube.com/@cahayaislam3181
# 13           0            0      http://www.youtube.com/@mancingngoyor9892
# 14           0            0  http://www.youtube.com/@nurulfadnanyputri4259
# 15           0            0              http://www.youtube.com/@HaanHaan_
# 16           0            0                http://www.youtube.com/@snfdh04
# 17           2            0                  http://www.youtube.com/@b36.9
# 18           0            0        http://www.youtube.com/@user-em4bn2cv4g
# 19           0            0    http://www.youtube.com/@AlvinoPratama-sl4gg
# 20           0            0     http://www.youtube.com/@mariafransisca5803
# 21           0            0           http://www.youtube.com/@madecahyanii
# 22           0            0        http://www.youtube.com/@user-ms4cy7ub1w
# 23           0            0          http://www.youtube.com/@xl7rossonerri
# 24           0            0            http://www.youtube.com/@DedeKuswara
# 25           0            0          http://www.youtube.com/@arilmizan5724
# 26           0            0        http://www.youtube.com/@user-te7cv1ib5h
# 27           0            0          http://www.youtube.com/@alfinaprianto
# 28           0            0       http://www.youtube.com/@darman_gunarto18
# 29           0            0   http://www.youtube.com/@nurdiansyahdimas6380
# 30           0            0            http://www.youtube.com/@Kaset_Talim
# 31           0            0      http://www.youtube.com/@genshinimpact6472
