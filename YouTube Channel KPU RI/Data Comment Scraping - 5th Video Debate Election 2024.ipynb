# %% [markdown]
# ## 1. Import Libraries for Scraping Data YouTube Comments and Create API based on Google YouTube Data API

# %%
"""
Melakukan proses import library pandas untuk membuat data-data komentar dari hasil web scraping menjadi DataFrame
serta juga meng-import library khusus yang dimiliki oleh Google API Client agar dapat mengambil informasi/data dari
video komentar debat capres-cawapres babak kelima dari channel YouTube KPU RI menggunakan API yang akan didapatkan dari
salah satu service pada Google Cloud Platform yaitu YouTube Data API v3
"""
import pandas as pd
from googleapiclient.discovery import build

# %%
"""
Mendefinisikan resource utama/sumber daya dari Google API Client seperti nama layanan atas API yang digunakan,
kode API dan tipe versi pada nama service yang digunakan sehingga dengan resource tersebut,
Google API dapat melakukan proses pengambilan (scraping) data/informasi pada serangkaian
komentar utama (bukan teks komentar yang bersifat balasan/reply dari suatu komentar) yang ada di dalam video debat
capres-cawapres babak kelima Republik Indonesia tahun 2024 yang di-upload oleh channel YouTube KPU RI menggunakan
API yang telah berhasil dibuat dan didapatkan dari CREDENTIALS YouTube Data API v3 yang ada di dalam Google Cloud Platform
"""

API_Service_Name = "youtube" # Merupakan nama service yang digunakan untuk generate kode API
API_Version_Name = "v3" # Merupakan jenis/tipe versi dari nama service dalam menghasilkan kode API (YouTube Data API v3)
API_Key = "AIzaSyCTEBkjSYN0dPHA95Oipoks9A9b8aIOZb8" # Meng-copy kode API dari CREDENTIALS pada YouTube Data API v3


"""
Menyimpan 3 variabel yang menyimpan resource utama dari Google API Client yang sebelumnya
telah didefinisikan seperti nama service API (API_Version_Name), versi API Youtube yang digunakan (API_Version_Name)
serta kunci/kode API (API_Key) yang telah dibuat dan didapatkan melalui CREDENTIALS
YouTube Data API v3 yang ada di dalam Google Cloud Platform Console yaitu 
dan disimpan di dalam variabel bernama "youtube_scrape_comment_objects"
"""
youtube_scrape_comment_objects = build(API_Service_Name, API_Version_Name, developerKey = API_Key)

# %% [markdown]
# Code script diatas merupakan proses inisialisasi API Key yang telah berhasil didapatkan melalui Google Cloud Platform dengan pilihan service yakni YouTube Data API v3. Maka dari itu nama service API yang digunakan (API_Service_Name) ditulis sebagai "youtube" karena service/layanan Google pada Google Cloud Platform yang digunakan di dalam penelitian kali ini adalah sebuah video yang ter-upload pada media sosial YouTube dan versi API yang digunakan adalah versi ketiga dari API YouTube Data sehingga nilai dari variabel API_Version_Name yang disimpan adalah "v3".
#
# Selain itu, untuk mendapatkan kunci API dari layanan yang bernama "youtube", pertama-tama saya harus masuk ke dalam service YouTube Data API v3 di dalam Google Cloud Platform dan mengaktifkan (enable) service tersebut dan memilih fitur/opsi CREDENTIALS karena API Key berada di dalam fitur tersebut. Jadi dapat disimpulkan kalau untuk membuat API Key agar dapat mengambil data-data yang ada di dalam suatu video YouTube seperti komentar dari 1 video YouTube, Playlist, Subscription, dll., maka terlebih dahulu harus mengaktifkan service YouTube Data API v3 di dalam Google Cloud Platform dan kemudian membuat/generate API Key di dalam opsi CREDENTIALS. Jika API sudah berhasil dibuat, maka kita dapat meng-copy API tersebut untuk diletakkan di dalam variabel. Pada code script diatas, API yang berhasil didapatkan disimpan di dalam variabel yang bernama "API_KEY".
#
# Di samping itu, fungsi build pada library googleapiclient.discovery merupakan sebuah Software Development Kits (SDKs) yang telah disediakan oleh Google agar para developer/scientist dapat mengakses semua layanan berbasis Google melalui API seperti video/konten YouTube, BigQuery, dll. Jadi dapat disimpulkan bahwasanya dengan mendefinisikan nama layanan Google yang akan digunakan dan API yang telah didapatkan berdasarkan layanan yang akan digunakan, maka setiap orang diseluruh dunia dapat mengakses dan mendapatkan data-data atau informasi dunia melalui layanan Google. Seperti pada penelitian kali ini yang sumber datanya merupakan data-data komentar dari video debat babak kelima capres-cawapres yang di-upload oleh channel KPU RI yang ada di dalam media sosial YouTube.

# %% [markdown]
# ## 2. Request Access to Retrieve Main Comments Data Objects on YouTube Video based on API Key, API Service Name, and API Version

# %%
"""
Melakukan proses permintaan kepada Google Client dengan menggunakan API yang sudah
di=generate oleh CREDENTIALS dan disimpan di dalam variabel "youtube_scrape_comment_objects"
(bersamaan dengan nama service dan jenis versi dari service yang digunakan)
untuk dapat mengambil 100 data/informasi (sesuai jumlah batasan/limit data komentar yang dapat
diambil dari komentar pada konten video YouTube menggunakan API dari Google Client) pada serangkaian komentar utama
tentang debat capres-cawapres babak kelima Republik Indonesia tahun 2024 yang di-upload oleh
channel YouTube KPU RI berdasarkan dari ID yang dimiliki oleh video tersebut
"""

video_youtube_data_request = youtube_scrape_comment_objects.commentThreads().list(
    part = "snippet", # snippet pada parameter part adalah objek list dari seluruh elemen yang dimiliki oleh komentar utama
    videoId = "8J66JxvmEzo", # Merupakan ID dari video debat babak kelima capres-cawapres yang di-upload oleh channel KPU RI 
    maxResults = 100, # Jumlah informasi komentar yang akan terambil dari video debat kelima namun 100 data adalah batasannya
    order = "time", # Nilai time pada parameter order adalah urutan tanggal dan waktu terbaru hingga terlama dari komentar
)


"""
Menjalankan proses permintaan untuk mendapatkan seluruh elemen/objek dari 100 rangkaian komentar
paling terbaru hingga terlama dari video ID yaitu 8J66JxvmEzo yang merupakan ID video dari debat
capres-cawapres babak kelima yang di-upload oleh YouTube channel KPU RI yyang telah dibuat dan disimpan
pada variabel "video_youtube_data_request"
"""
video_youtube_data_response = video_youtube_data_request.execute()

# %% [markdown]
# Berikut adalah penjelasan mengenai code script diatas berikut ini:
#
# 1. youtube_scrape_comment_objects merupakan sebuah nama variabel yang berisikan parameter-parameter beserta nilainya yang berfungsi sebagai tempat menyimpan resource utama Google Client serta API dari YouTube untuk dapat mengakses data-data dan informasi yang dimiliki oleh suatu konten video YouTube seperti informasi video, komentar di dalam suatu video, playlist dari suatu channel, dll, dengan memanfaatkan kode API (API KEY) yang didapatkan melalui Google Cloud Platform dengan cara membuat credentials API di dalam salah satu service Google Cloud Platform yaitu YouTube Data API v3.
#
# 2. commentThreads merupakan suatu sumber daya dari YouTube Data API yang berisikan objek/elemen atas informasi-informasi dari komentar utama (teks komentar yang bukan menjadi komentar balasan) dari suatu video di YouTube. Salah satu contoh informasi yang terdapat di dalam komentar utama adalah teks komentar yang dibuat oleh user/penonton dari video tersebut bukan teks komentar yang menanggapi/merespon komentar utama. Atau identitas nama user/akun YouTube yang berkomentar di video tersebut sebagai bentuk pendapat atas video yang ditonton.
#
# 3. Parameter "part" bertujuan untuk mendapatkan banyak objek list properti yang dipisahkan oleh tanda koma (comma-separated list) dari sumber daya yang dimiliki oleh service YouTube Data API v3 yang membentuk komentar paling utama (komentar teratas) dari suatu video. Sedangkan "snippet" pada parameter "part" bertujuan untuk mendapatkan objek detail dasar tentang elemen-elemen/item dari komentar utama sebagai bentuk respon API YouTube terhadap permintaan dalam mengambil objek-objek data dari sebuah konten video berdasarkan video id yang didefinisikan pada parameter "videoId". Salah satu contoh detail dasar dari komentar utama seperti channel id sebagai identitas unik dari suatu channel yang ada di media sosial YouTube.
#
# 4. Parameter videoId merupakan sebuah identitas unik dari video (ID dari suatu konten video YouTube) yang informasi dasarnya ingin diambil (data scraping) untuk kebutuhan yang berbeda-beda. Sebagai contohnya pada penelitian kali ini, saya ingin menggunakan video tentang debat babak kelima capres-cawapres Republik Indonesia tahun 2024 dari channel YouTube KPU RI dan video tersebut memiliki alamat URL yakni https://www.youtube.com/watch?v=8J66JxvmEzo. Jadi ID video "8J66JxvmEzo" diambil dari URL pada video tersebut yang letaknya setelah v=.
#
# 2. Parameter maxResult merupakan sebuah parameter yang secara spesifik bertujuan untuk mengambil jumlah kuantitas dari data/informasi komentar utama yang ingin diambil dari suatu konten video di media sosial YouTube berdasarkan ID unik yang didefinisikan pada parameter videoId. Tetapi kuantitas jumlah data/informasi komentar yang dapat diambil menggunakan API dari service Google Client hanya 100 data saja, tidak bisa lebih dari 100 data. Sehingga karena penelitian kali ini akan mengambil lebih dari 100 data, maka diperlukan tahapan/teknik pengulangan supaya data komentar yang terambil dapat melebihi 100 data. Tahapan untuk mengambil data lebih dari 100 data akan dilakukan setelah berhasil mendapatkan 100 data komentar (berdasarkan jumlah maksimal data komentar yang dapat diambil menggunakan API Google YouTube v3).
#
# 4. Parameter order merupakan sebuah parameter yang dimiliki oleh fungsi commentThreads() yang bertujuan untuk menentukan urutan data komentar yang ingin diambil (di-scraping) sebagai permintaan/request dari Google API Client terhadap komentar yang dimiliki oleh konten-konten video yang berada di media sosial YouTube. Konten video tersebut ditentukan oleh video ID yang dimiliki oleh parameter videoId. Parameter order memiliki 2 nilai yang valid yaitu time dan relevance. Jika nilai dari parameter order adalah time, maka urutan data komentar yang diambil akan terdiri dari komentar-komentar yang paling baru dibuat pada video tersebut berdasarkan tanggal dan waktu dari setiap teks komentar. Sebagai contoh jika terdapat teks komentar pada suatu konten video YouTube yang ditulis dengan teks "Hari Buruh dirayakan disetiap tanggal 1 Mei termasuk Negara Indonesia" dibuat di tanggal 1 Mei 2024 dan teks komentar lainnya adalah "Perayaan hari buruh di beberapa tempat dirayakan dengan sangat tentram dan demokratis" dibuat di tanggal 1 Mei tahun 2023, maka urutan teks komentar yang tersimpan terlebih dahulu/teks komentar paling atas dari urutan teks komentar yag tersimpan adalah teks komentar yang ditulis seperti "Hari Buruh dirayakan disetiap tanggal 1 Mei termasuk Negara Indonesia" dan baris selanjutnya adalah teks komentar "Perayaan hari buruh dibeberapa tempat dirayakan dengan sangat tenram dan demokratis". Jadi pada dasarnya nilai time di dalam parameter order akan mengurutkan komentar berdasarkan tanggal dan waktu yang dimiliki oleh setiap data rangkaian komentar yang dimulai dari komentar paling terbaru hingga komentar yang dibuat paling lama yang terdapat di dalam suatu konten video YouTube berdasarkan video id yang dimilikinya.

# %%
"""
Menampilkan seluruh objek serta elemen yang dimiliki oleh 100 rangkaian komentar utama
(teks komentar yang bukan merupakan balasan/reply dari suatu komentar) dari video debat babak kelima
capres-cawapres yang ditayangkan oleh channel YouTube KPU RI yang berhasil di-scraping
menggunakan API Key dari service Google Cloud Console yaitu YouTube Data API v3
"""
video_youtube_data_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '2vJrQF2gyGK8dduh0NAY3UkTz5M',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSElCZ0FFZ1VJblNBWUFSSUZDSWtnR0FBU0JRaW9JQmdBR0FBaURnb01DT1BMdGE0R0VPRDEyOVlD',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'n3Bo6pavkdYKSVqh3M-jbFH0uBY',
#    'id': 'UgzUlQ7MzvqKOViRwnd4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mq8pIS3j6K-4DIkJ4T6AWt_mzAU',
#      'id': 'UgzUlQ7MzvqKOViRwnd4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'By pQ',
#       'textOriginal': 'By pQ',
#       'authorDisplayName': '@Suharti111-ym4kj',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_neAWLH7sZOed0nxggmhltv1elkeHlOQumeJrdVd-uJprIR_0tQYDxrh34wywukW1kbeQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Suharti111-ym4kj',
#       'authorChannelId': {'value': 'UCiS-oRAU-T3t3UgSgwENcug'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T23:55:17Z',
#       'updatedAt': '2024-04-29T23:55:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'lW6Bjh6DDPdPzh-SIXISX5kfzx8',
#    'id': 'Ugw5uieQfIyx4nBdJ-54AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iXpaN6Rjl6oSSOt1zqHWHi-4NBw',
#      'id': 'Ugw5uieQfIyx4nBdJ-54AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'Isyaallah amin.',
#       'textOriginal': 'Isyaallah amin.',
#       'authorDisplayName': '@user-zl9bs5sp8y',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nHNmhgK4mtwlkvbYzWQNsHe7dvV4nJKisK6SmVW8O7u9Pa8T0cWxyinae9f8_eisKzEw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-zl9bs5sp8y',
#       'authorChannelId': {'value': 'UCVbg7bJ5CUbPgKHZP1G5n7g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-04-21T13:22:01Z',
#       'updatedAt': '2024-04-21T13:22:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VLQIRWKhaI3CpifFminYbPdU7AA',
#    'id': 'UgznH4rutz2FePJ8nE14AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uR31WTlkopOYrSCFRtl1_sIpoVU',
#      'id': 'UgznH4rutz2FePJ8nE14AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=8J66JxvmEzo&amp;t=137">2:17</a>:4,r,6<br>,z <a href="https://www.youtube.com/watch?v=8J66JxvmEzo&amp;t=7716">2:08:36</a> 4<br>❤<br>Z',
#       'textOriginal': '2:17:4,r,6\n,z 2:08:36 4\n❤\nZ',
#       'authorDisplayName': '@zawazian2',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nPTmRnD8mH4OLoCAt5p0QzYDh0PMXNWWNuE-L6WWKNDQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@zawazian2',
#       'authorChannelId': {'value': 'UC5fCjiAMUrphlZZyHlCjeFw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-04T23:18:31Z',
#       'updatedAt': '2024-04-04T23:18:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9t8Cdf7qVlF4U-vkAlmacjX1fyk',
#    'id': 'UgyvQq-_yM9nFLSVAGZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Z2KhDdBwiz1ppGZ2noZYDK0Gn4A',
#      'id': 'UgyvQq-_yM9nFLSVAGZ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'Prabowo.orang biasa..tapi di negara amerika tkut klo perabowo jdi peresiden',
#       'textOriginal': 'Prabowo.orang biasa..tapi di negara amerika tkut klo perabowo jdi peresiden',
#       'authorDisplayName': '@JohnimahendraMahendra',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nQWtDjnkGaIYmOsk65bxLAmt6sDD9KGCnr9j4CzKha7Ht707dqW4PbsI-coFFXsWHIFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@JohnimahendraMahendra',
#       'authorChannelId': {'value': 'UCfJ8hpQeLVbCQnlRrhiF3BQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-04-04T12:55:31Z',
#       'updatedAt': '2024-04-04T12:55:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ozBnyeouKI0lrprTPfP162TW6sw',
#    'id': 'UgycqDD60Pusea2Otk54AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BYoTxeQU1eq7mbphVbVop7wiNRY',
#      'id': 'UgycqDD60Pusea2Otk54AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'Karena cinta Joy',
#       'textOriginal': 'Karena cinta Joy',
#       'authorDisplayName': '@ryanrifai9001',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kRvOiVN877hWSIs8L6INsJvqR3iYls32ZAvb0PyU3SKlQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ryanrifai9001',
#       'authorChannelId': {'value': 'UC3TxevTLbsCnHOvnTUV9npQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-03-21T16:42:22Z',
#       'updatedAt': '2024-03-21T16:42:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EIvYENXaQKePIwyaG8L76zch52E',
#    'id': 'Ugx5plDI2C-ycjFZ3SV4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'IAHOMX1LKUW4aWRbis6uNfqjfPs',
#      'id': 'Ugx5plDI2C-ycjFZ3SV4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'WES GAK MASUK BLUASSS DEPATE OMONGANE NIS..ANIS...🤣🤣',
#       'textOriginal': 'WES GAK MASUK BLUASSS DEPATE OMONGANE NIS..ANIS...🤣🤣',
#       'authorDisplayName': '@peyek7090',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Q4ARDKKsivN6NR9zz9mhgYU-cB0X8K_JpYOir_2J9zw-Ynn7Hzrp-hx25JitAhXZUbx1MU-w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@peyek7090',
#       'authorChannelId': {'value': 'UC8gOkBqYLDJYVAwvAozHTYg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-20T17:06:58Z',
#       'updatedAt': '2024-03-20T17:06:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'V1FKmAnN8ddnaGEg6L5Gi7O7BLQ',
#    'id': 'UgwxHjiaZBXsPsDh8Mp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'u__wjD7vbf1ONpHGAsK-jRJtR8g',
#      'id': 'UgwxHjiaZBXsPsDh8Mp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'KPU..KPU..😂😅',
#       'textOriginal': 'KPU..KPU..😂😅',
#       'authorDisplayName': '@penglaristv5550',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kRlF0QZuNmTozRsodpfFpsHFrHJNYDRwpZBwnLRr6PCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@penglaristv5550',
#       'authorChannelId': {'value': 'UCRnlVJKJEB8pIxQ_qy6ZT0g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-18T14:34:46Z',
#       'updatedAt': '2024-03-18T14:34:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UDiH0O2rBI8DisxbrtIu162jMAs',
#    'id': 'Ugzuf9Mo9Vk_E0CpIZZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '
s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ROXXXJAGERR',
#       'authorChannelId': {'value': 'UC6_3Vh4dX_SZers7qm7MASw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-10T05:42:00Z',
#       'updatedAt': '2024-03-10T05:42:00Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OasmpNLK-vLG0ysdE5-89i6bIqo',
#    'id': 'UgxMaEBnjyIRuN2Jh9x4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 't8KN6_dZ0RD4bUfnzgGbE3F0YBY',
#      'id': 'UgxMaEBnjyIRuN2Jh9x4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'ANTI IMPERIALISME ARAB',
#       'textOriginal': 'ANTI IMPERIALISME ARAB',
#       'authorDisplayName': '@ROXXXJAGERR',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/8F0yOLLl598a6BWOuvmaKxbvL6rbmXHZYzaOHihg6V62i7N33VFBaHbqUv-82u7rdRMBfaf6=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ROXXXJAGERR',
#       'authorChannelId': {'value': 'UC6_3Vh4dX_SZers7qm7MASw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-10T05:41:36Z',
#       'updatedAt': '2024-03-10T05:41:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '83Bmt_JJ7kaejMB_P73J96K96nw',
#    'id': 'Ugx3SV0wKTa3ecSWz494AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RmjrDx_GuOTT1nzGVeaeXAGgHTU',
#      'id': 'Ugx3SV0wKTa3ecSWz494AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': '90',
#       'textOriginal': '90',
#       'authorDisplayName': '@RizkkiMaulana-ni9iu',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kgeb3tvIBGrdY-IdjHykSG-MSKpwcehWUAO3_O6TXPgadO46BAk4RkoG8qNgXDJBfHxg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@RizkkiMaulana-ni9iu',
#       'authorChannelId': {'value': 'UC3Noiq9eWFSVwJAGQN2_BIQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-10T01:20:52Z',
#       'updatedAt': '2024-03-10T01:20:52Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '82WmUFmZ7RsY8QqtajUzC8E8Gq4',
#    'id': 'UgzER5C26VsnoSpPBfp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mYex9MwEmiHpwtQYrQeIDHFdWsU',
#      'id': 'UgzER5C26VsnoSpPBfp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'Halooo ini lah kandidat gembong Korupsi saudaraku.',
#       'textOriginal': 'Halooo ini lah kandidat gembong Korupsi saudaraku.',
#       'authorDisplayName': '@-FarellioFikriA',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nAZZIaG3GPD_-XWU6xRmKGax_5dewRKAEri6frvllDUQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@-FarellioFikriA',
#       'authorChannelId': {'value': 'UC7zY12x6XY5I5IM5AiGvXog'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-10T00:08:28Z',
#       'updatedAt': '2024-03-10T00:08:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qFS2FksKRYwX_fdvYMdyi_LFPac',
#    'id': 'Ugz33HtcpJ83d8PB4Rl4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Q2hXSB6WET4QHSmxXH-VyzL3a4M',
#      'id': 'Ugz33HtcpJ83d8PB4Rl4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'IQ orang Indonesia rata2 78.5 peringkat 36 di Asia. jadi untuk kampanye seperti Desak Anis.Kampanye Gagasan dan fikiran ini agak sulit diterima. Cocoknya di Indonesia mempengaruhi orang lewat Gimmick dan Pencitraan , bantuan seperti uang , beras sembako dll , paling efektif , bisa membuat org menjadi tidak kritis kurang wawasan dan Fanatik buta karna lebih banyak perasaan tidak didasari dengan Logika . Untuk standar rata2 IQ normal itu 90~109 . Acara seperti contohnya  Desak Anis ini jika dilakukan oleh semua paslon kita bisa nilai mana yang lebih terkonsep dan masuk akal untuk pembangunan kedepan, apa dan program apa yg akan dikerjakan secara detail jika terpilih. Dan masyarakat yg objektif bisa menilai bukan dengan kebencian. hal ini juga dilakukan di negara yang sudah maju. Jika ada
ukku...jika engkau ingin pergi dan meninggalkanku pergilah...aku tau apa yang menjadi pilihan terbaikmu...aku tak memaksamu untuk pergi dan aku hanya ingin engkau bisa memilih pilihan jalan yang menjadi jalan terbaik untukmu...dan jangan engkau mengambil jalan yang salah...kebahagiaan atau tidak semua itu   sudah menjadi pilihan ...salam dariku lelaki biasa yang pernah menyanyangimu melebihi luasnya samudra dan besarnya dunia...pemanah angkasa 🏹 BRAHMASTRA...terima kasih pembacaannya kak ...salam 🙏🏻...',
#       'authorDisplayName': '@brahmastra7348',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/4N9pWRenJfPg4nq8Cbn57tiA-NW_6XSRBxjc0XIjLqP_ninGIkep7kt_Gk8VW3ptMlPZtadJ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@brahmastra7348',
#       'authorChannelId': {'value': 'UCc57gtlS4RaTBs-4DVoYFhg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-15T11:57:08Z',
#       'updatedAt': '2024-02-15T11:57:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uG1TcXJp30F9vkmwH5qMDvQOxl8',
#    'id': 'UgxYC46vIXniRL_xy6V4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': '8J66JxvmEzo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JUrShgoOY2wQybenI02ciuyqWyQ',
#      'id': 'UgxYC46vIXniRL_xy6V4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': '8J66JxvmEzo',
#       'textDisplay': 'Kenapa judulnya harus &quot;DEBAT&quot;? Kenapa nggak dikasi judul &quot;ADU GAGASAN &amp; WAWASAN&quot; atau apa gitu? yang konotasi lebih positive drpd &quot;DEBAT&quot;',
#       'textOriginal': 'Kenapa judulnya harus "DEBAT"? Kenapa nggak dikasi judul "ADU GAGASAN & WAWASAN" atau apa gitu? yang konotasi lebih positive drpd "DEBAT"',
#       'authorDisplayName': '@elocopilot6545',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mvGg9HDk1AqT_XmVIsrURSKIcszw38x2ywR4-rthM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@elocopilot6545',
#       'authorChannelId': {'value': 'UC3A6bdQ_tTlLAQLJmmXxaaQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-02-15T01:16:20Z',
#       'updatedAt': '2024-02-15T01:16:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# ## 3. Define Main Items (Video ID, Total Reply of Count, Comment ID, Text of Comment, Total of Comment Like, Name of Account Commenting, etc) from Video YouTube based on Video ID in YouTube

# %%
"""
Mendefinisikan beberapa elemen item yang membentuk serangkaian komentar utama yang akan digunakan
sebagai kolom di dalam DataFrame berdasarkan ID video YouTube yang sebelumnya telah didefinisikan
pada "video_youtube_data_request" (saat ini permintaan tersebut telah diterima sebagai respon dan disimpan
di dalam "video_youtube_data_response") dengan mengambil 100 data/informasi dari serangkaian komentar utama di dalam video
debat capres-cawapres Republik Indonesia babak kelima yang di-upload oleh channel YouTube KPU RI
"""


"""
Variabel "list_fifth_video_debate_kpuri" adalah empty list untuk menyimpan beberapa elemen item dari rangkaian
teks komentar utama seperti ID video debat babak kelima yang ditayangkan oleh channel KPU RI, ID channel KPU RI,
isi teks komentar khususnya komentar utama, nama akun user/penonton yang berkomentar di dalam video tersebut, dll
"""
list_fifth_video_debate_kpuri = []


for item in video_youtube_data_response["items"]:
    video_id = item["snippet"]["videoId"] # Mendapatkan ID video debat kelima capres-cawapres yang di-upload channel KPU RI
    total_reply_count = item["snippet"]["totalReplyCount"] # Mendapatkan jumlah total balasan dari masing-masing teks komentar
    comment_id = item["id"] # Mendapatkan ID dari seluruh teks komentar utama (bukan teks komentar yang bersifat reply)
    
    
    """
    Mendapatkan seluruh elemen item per masing-masing komentar utama yang menjadi struktur pembentuk dasar dari komentar utama
    berdasarkan video ID yang sebelumnya telah diinisialisasikan.
    Jenis objek yang menjadi struktur/rangkaian detail atas masing-masing komentar utama adalah channel ID,
    teks komentar, jumlah like pada komentar tersebut, tanggal dan waktu dibuatnya komentar,
    nama akun user yang berkomentar di dalam video tersebut, dll
    
    Perlu diketahui jika elemen item yang terdapat pada top level comment dan commentThreads() berbeda tetapi
    dapat digabungkan menjadi satu kesatuan. Elemen seperti video id,
    jumlah user yang membalas/merespon teks komentar utama, dan lainnya
    termasuk di dalam elemen item yang dimiliki oleh commentThreads()
    karena sifatnya adalah informasi general dari rangkaian komentar utama
    
    Sedangkan elemen item yang dimiliki oleh top level comment lebih bersifat informasi yang spesifik yang dimiliki oleh
    masing-masing komentar utama atau komentar balasan atas komentar utama.
    Elemen item seperti nama user/akun yang berkomentar, isi atas masing-masing teks komentar yang dibuat oleh
    setiap akun yang berkomentar, jumlah user yang menyukai isi dari teks komentar utama, dan lainnya
    termasuk ke dalam item-item yang dimiliki oleh top level comment
    """
    comment_items = item["snippet"]["topLevelComment"]["snippet"]
    
    
    """
    Memasukkan atribut/elemen utama ke dalam variabel list kosong yaitu "list_fifth_video_debate_kpuri" yang akan
    berisikan beberapa objek item/elemen dari serangkaian komentar utama seperti ID video,
    ID Channel yang mem-publish/meng-upload video tersebut, nama akun user yang berkomentar beserta teks komentar,
    tanggal pembuatan komentar untuk video tersebut,
    jumlah total like sebagai bentuk respon setuju pada komentar yang telah dibuat oleh user, dll.
     
    Catatan tambahan bahwasanya variabel "video_id", "total_reply_count", "comment_id" dan "comment_items"
    termasuk ke dalam elemen utama yang akan dimasukkan ke dalam list kosong (empty list) yang bernama
    "list_fifth_video_debate_kpuri" yang nantinya list yang bernama "list_fifth_video_debate_kpuri"
    akan menjadi struktur kolom di dalam Pandas DataFrame
    """
    list_fifth_video_debate_kpuri.append([
        video_id, # Memasukkan ID video debat kelima capres-cawapres yang di-upload oleh channel YouTube KPU RI ke dalam list
        comment_items["channelId"], # Memasukkan ID yang dimiliki oleh channel YouTube KPU RI ke dalam variabel list
        comment_id, # Memasukkan ID masing-masing komentar yang dibuat oleh para penonton video debat kelima ke dalam list
        comment_items["authorDisplayName"], # Memasukkan nama akun YouTube yang berkomentar di video debat ke dalam empty list
        comment_items["textDisplay"], # Memasukkan 100 teks komentar utama video debat ke-4 dari channel KPU RI ke dalam list
        comment_items["likeCount"], # Memasukkan jumlah total like yang diterima oleh teks komentar utama ke dalam variabel list
        total_reply_count, # Memasukkan jumlah total balasan (reply) yang diterima oleh teks komentar utama ke dalam list
        comment_items["authorChannelUrl"], # Memasukkan URL/link channel akun YouTube para penonton video debat kelima ke list
        comment_items["publishedAt"], # Memasukkan tanggal dan waktu saat pertama kali teks komentar utama dibuat oleh user
        comment_items["updatedAt"] # Memasukkan tanggal dan waktu saat suatu teks komentar mengalami perubahan (update) tulisan
    ])
    

"""
Menampilkan jumlah data yang dimiliki oleh list setelah dilakukan proses pemilihan
elemen-elemen yang akan menampilkan struktur dari rangkaian komentar utama dari video debat
capres-cawapres babak kelima dari YouTube channel KPU RI
"""
print("Jumlah Data yang Dimiliki oleh Variabel List 'list_fifth_video_debate_kpuri' sebelum Proses Looping adalah",
      len(list_fifth_video_debate_kpuri))
# Out:
# Jumlah Data yang Dimiliki oleh Variabel List 'list_fifth_video_debate_kpuri' sebelum Proses Looping adalah 100

# %% [markdown]
# Jika hanya menggunakan code script diatas saja maka data komentar yang didapatkan hanya berjumlah 100 data saja karena jumlah maksimal untuk mengambil data komentar dari suatu konten video YouTube dengan menggunakan Google YouTube API dibatasi hanya 100 data. Maka dari itu karena menurut saya 100 data sangat tidak cukup untuk penelitian kali ini, maka saya akan mengambil data komentar dari video debat capres-cawapres babak kelima dari YouTube channel KPU RI lebih dari 100 data komentar.
#
# Untuk mengatasi permasalahan ini, saya akan melakukan proses looping/pengulangan permintaan untuk mengambil data komentar lebih dari 100 data. Jumlah data yang saya inginkan pada penelitian kali ini berjumlah sebanyak 1.800 data dari 1.849 komentar (per tanggal 4 Mei 2024) sehingga permintaan yang code script dibawah ini akan mengulangi permintaan mengambil data sebanyak 1.800 data komentar yang akan ditempatkan di dalam 10 kolom/object/elemen utama dari video debat capres-cawapres babak kelima yang di-upload oleh channel YouTube KPU RI. Sepuluh kolom/elemen utama yang akan membentuk DataFrame adalah kolom elemen "videoId", "channelId", "id" sebgaai comment_id, "authorDisplayName", "textDisplay", "likeCount", "totalReplyCount", "authorChannelUrl", "publishedAt", dan "updatedAt".
#
# Sebagai catatan dan pengingat bahwasanya saat ini objek list yang bernama "list_fifth_video_debate_kpuri" baru memiliki 100 rangkaian data/informasi komentar dan akan dilakukan proses pengulangan permintaan hingga variabel list "list_fifth_video_debate_kpuri" memiliki 1.800 data komentar beserta elemen-elemen utamanya. Agar dapat mengambil data komentar sebanyak 1.800 data, maka saya akan menerapkan teknik TokenPagination.
#
# TokenPagination merupakan cara untuk mengambil data-data yang berada di halaman selanjutnya (data yang bukan berada di halaman utama/halaman paling awal dari suatu konten/informasi). TokenPagination yang akan digunakan di dalam penelitian kali ini memiliki tujuan untuk mendapatkan data-data komentar seperti teks komentar, data nama akun/user yang berkomentar, tanggal pembuatan komentar, dsb, yang berada di halaman-halaman berikutnya atau halaman setelah 100 data paling awal (data yang menjadi batasan maksimal/limit yang dapat diambil menggunakan YouTube Data API v3).

# %%
"""
Menampilkan seluruh data dari beberapa elemen item yang sebelumnya telah dilakukan proses penyeleksian
elemen yang akan ditampilkan dan elemen-elemen tersebut dimasukkan ke dalam variabel list "list_fifth_video_debate_kpuri"
yang sumber data komentarnya berasal dari video debat capres-cawapres babak kelima yang ditayangkan
oleh channel Youtube KPU RI yang memiliki ID Video 8J66JxvmEzo
"""
list_fifth_video_debate_kpuri
# Out:
# [['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzUlQ7MzvqKOViRwnd4AaABAg',
#   '@Suharti111-ym4kj',
#   'By pQ',
#   0,
#   0,
#   'http://www.youtube.com/@Suharti111-ym4kj',
#   '2024-04-29T23:55:17Z',
#   '2024-04-29T23:55:17Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw5uieQfIyx4nBdJ-54AaABAg',
#   '@user-zl9bs5sp8y',
#   'Isyaallah amin.',
#   1,
#   0,
#   'http://www.youtube.com/@user-zl9bs5sp8y',
#   '2024-04-21T13:22:01Z',
#   '2024-04-21T13:22:01Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgznH4rutz2FePJ8nE14AaABAg',
#   '@zawazian2',
#   '<a href="https://www.youtube.com/watch?v=8J66JxvmEzo&amp;t=137">2:17</a>:4,r,6<br>,z <a href="https://www.youtube.com/watch?v=8J66JxvmEzo&amp;t=7716">2:08:36</a> 4<br>❤<br>Z',
#   0,
#   0,
#   'http://www.youtube.com/@zawazian2',
#   '2024-04-04T23:18:31Z',
#   '2024-04-04T23:18:31Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyvQq-_yM9nFLSVAGZ4AaABAg',
#   '@JohnimahendraMahendra',
#   'Prabowo.orang biasa..tapi di negara amerika tkut klo perabowo jdi peresiden',
#   1,
#   0,
#   'http://www.youtube.com/@JohnimahendraMahendra',
#   '2024-04-04T12:55:31Z',
#   '2024-04-04T12:55:31Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgycqDD60Pusea2Otk54AaABAg',
#   '@ryanrifai9001',
#   'Karena cinta Joy',
#   1,
#   1,
#   'http://www.youtube.com/@ryanrifai9001',
#   '2024-03-21T16:42:22Z',
#   '2024-03-21T16:42:22Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx5plDI2C-ycjFZ3SV4AaABAg',
#   '@peyek7090',
#   'WES GAK MASUK BLUASSS DEPATE OMONGANE NIS..ANIS...🤣🤣',
#   0,
#   0,
#   'http://www.youtube.com/@peyek7090',
#   '2024-03-20T17:06:58Z',
#   '2024-03-20T17:06:58Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwxHjiaZBXsPsDh8Mp4AaABAg',
#   '@penglaristv5550',
#   'KPU..KPU..😂😅',
#   0,
#   0,
#   'http://www.youtube.com/@penglaristv5550',
#   '2024-03-18T14:34:46Z',
#   '2024-03-18T14:34:46Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzuf9Mo9Vk_E0CpIZZ4AaABAg',
#   '@akhmadafandi4113',
#   'PREEEETTTTTTT',
#   0,
#   0,
#   'http://www.youtube.com/@akhmadafandi4113',
#   '2024-03-17T00:28:57Z',
#   '2024-03-17T00:28:57Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwYv6XEINeZXNl67PN4AaABAg',
#   '@devandwi8978',
#   'Pilih aja mas slamet presiden nya dan mas yogi wakilnya',
#   0,
#   1,
#   'http://www.youtube.com/@devandwi8978',
#   '2024-03-15T16:27:17Z',
#   '2024-03-15T16:27:17Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwjAPE7lXkbu6xXG6F4AaABAg',
#   '@kudaonta9095',
#   'JURNAL ECONOMINA kalian keren semua, FREE PALESTINE',
#   1,
#   0,
#   'http://www.youtube.com/@kudaonta9095',
#   '2024-03-15T05:55:30Z',
#   '2024-03-15T05:55:30Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxMRjuSWei8jsdowll4AaABAg',
#   '@andilajatim3117',
#   'Tipopoppl❤❤❤❤❤',
#   0,
#   0,
#   'http://www.youtube.com/@andilajatim3117',
#   '2024-03-14T13:58:55Z',
#   '2024-03-14T13:58:55Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwuguKNpIk7Hp8qtw54AaABAg',
#   '@GRK1998_',
#   'KPU komisi pencuri Umum<br><br>Bangsatttt KPU Bawaslu pengkhianat bangsa',
#   0,
#   0,
#   'http://www.youtube.com/@GRK1998_',
#   '2024-03-13T12:57:56Z',
#   '2024-03-13T12:57:56Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzWJDInudEmwKsGOwl4AaABAg',
#   '@DJ.9313',
#   '.p.',
#   0,
#   0,
#   'http://www.youtube.com/@DJ.9313',
#   '2024-03-12T18:24:02Z',
#   '2024-03-12T18:24:02Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwBVSL-pxcxc4SeaGl4AaABAg',
#   '@wiwiktriasihwidayah5338',
#   'Halah mek maido',
#   0,
#   0,
#   'http://www.youtube.com/@wiwiktriasihwidayah5338',
#   '2024-03-12T00:30:03Z',
#   '2024-03-12T00:30:03Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyWzgX0Hw2Wdf-fPMB4AaABAg',
#   '@Bojes49',
#   'Omong opo anis kui',
#   0,
#   0,
#   'http://www.youtube.com/@Bojes49',
#   '2024-03-11T00:34:01Z',
#   '2024-03-11T00:34:01Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwVadwIKco7MnnckgV4AaABAg',
#   '@ravigoreng882',
#   'Karmaa wkwkw',
#   0,
#   0,
#   'http://www.youtube.com/@ravigoreng882',
#   '2024-03-10T17:14:53Z',
#   '2024-03-10T17:14:53Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz19SX_BdVDabHJ6P54AaABAg',
#   '@ROXXXJAGERR',
#   'Anus Ganjar skrg jadi apa😂',
#   0,
#   0,
#   'http://www.youtube.com/@ROXXXJAGERR',
#   '2024-03-10T05:42:00Z',
#   '2024-03-10T05:42:00Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxMaEBnjyIRuN2Jh9x4AaABAg',
#   '@ROXXXJAGERR',
#   'ANTI IMPERIALISME ARAB',
#   0,
#   0,
#   'http://www.youtube.com/@ROXXXJAGERR',
#   '2024-03-10T05:41:36Z',
#   '2024-03-10T05:41:36Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx3SV0wKTa3ecSWz494AaABAg',
#   '@RizkkiMaulana-ni9iu',
#   '90',
#   0,
#   0,
#   'http://www.youtube.com/@RizkkiMaulana-ni9iu',
#   '2024-03-10T01:20:52Z',
#   '2024-03-10T01:20:52Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ug
z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyUAynHDND0GAj2TqR4AaABAg',
#   '@DesiDefriani',
#   '❤❤❤❤❤❤❤❤❤😊😊❤❤❤❤❤❤❤😊😂😊❤😊😊❤❤😂',
#   0,
#   0,
#   'http://www.youtube.com/@DesiDefriani',
#   '2024-03-06T02:09:28Z',
#   '2024-03-06T02:09:28Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzjmt4l3E9jiMhgmbN4AaABAg',
#   '@VeraVera-pm3um',
#   '😊',
#   0,
#   0,
#   'http://www.youtube.com/@VeraVera-pm3um',
#   '2024-03-05T20:25:39Z',
#   '2024-03-05T20:25:39Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz4ZAvwSvok3aLO3kB4AaABAg',
#   '@VeraVera-pm3um',
#   '😊',
#   0,
#   0,
#   'http://www.youtube.com/@VeraVera-pm3um',
#   '2024-03-05T20:25:10Z',
#   '2024-03-05T20:25:10Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxgelZuzc0lx6YiJq54AaABAg',
#   '@user-lu9mu5wx6h',
#   '😊😊',
#   0,
#   0,
#   'http://www.youtube.com/@user-lu9mu5wx6h',
#   '2024-03-05T17:05:26Z',
#   '2024-03-05T17:05:26Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzZXz5DONnM3v31nSt4AaABAg',
#   '@irwanajah1276',
#   'Pa bowo udh pikun apa gmn ya pas sesi tanya pertama ko ga fokus sama pertanyaan pak anies tentang perlindungan perempuan,trus ga konsisten dengan pertanyaan ke pak ganjar tentang stunting 😀🗿',
#   0,
#   1,
#   'http://www.youtube.com/@irwanajah1276',
#   '2024-03-05T16:46:34Z',
#   '2024-03-05T16:46:34Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy1Ze5gfE4_3OyCfoF4AaABAg',
#   '@abasbasuki225',
#   'Mau nanya dong<br>Gimana sih rasanya Dateng ke TPU<br>Maaf nanya',
#   0,
#   0,
#   'http://www.youtube.com/@abasbasuki225',
#   '2024-03-04T18:19:50Z',
#   '2024-03-04T18:19:50Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw2rUfmlnQxdhXD1Ex4AaABAg',
#   '@MustafaMusa-ed4om',
#   'Wan abud kalau masalah bicara nasi sudah basi keluar asap wkwkwkwkw',
#   0,
#   0,
#   'http://www.youtube.com/@MustafaMusa-ed4om',
#   '2024-03-04T15:45:46Z',
#   '2024-03-04T15:45:46Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw7kXOgHk1v75AfOCd4AaABAg',
#   '@Mahrus332',
#   'Pantang mundur',
#   0,
#   0,
#   'http://www.youtube.com/@Mahrus332',
#   '2024-03-04T15:32:49Z',
#   '2024-03-04T15:32:49Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzqrIIAvO0pk1g59xR4AaABAg',
#   '@Mahrus332',
#   'Maju terus',
#   0,
#   0,
#   'http://www.youtube.com/@Mahrus332',
#   '2024-03-04T15:31:41Z',
#   '2024-03-04T15:31:41Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwVZdZHwUATL7j3yqV4AaABAg',
#   '@Mahrus332',
#   'Pantang mundur',
#   0,
#   0,
#   'http://www.youtube.com/@Mahrus332',
#   '2024-03-04T15:31:12Z',
#   '2024-03-04T15:31:12Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwL70HhQdfoY6Nd5XV4AaABAg',
#   '@rojaniTV2',
#   'ANIS BANYAKAN BACOT',
#   0,
#   0,
#   'http://www.youtube.com/@rojaniTV2',
#   '2024-03-04T07:20:29Z',
#   '2024-03-04T07:20:29Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyZJirZi2QXGmAhjF54AaABAg',
#   '@agetsano9259',
#   'mungkin yg bikin rakyat yg menonton jadi terbelah2, krn Nama Acaranya ya? coba “Debat Capres” diganti “Kenal Capres” jadi mereka ga saling berdebat, tapi saling mengenal dan memperkenalkan diri kepada kita semua yg blm kenal baik dg mereka',
#   0,
#   1,
#   'http://www.youtube.com/@agetsano9259',
#   '2024-03-04T00:39:31Z',
#   '2024-03-04T00:39:31Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugwy0awP7G1MdoyQSBF4AaABAg',
#   '@sabariyanto2050',
#   'dan akhirnya prabowo yg menang😁😁😁',
#   0,
#   0,
#   'http://www.youtube.com/@sabariyanto2050',
#   '2024-03-03T10:57:13Z',
#   '2024-03-03T10:57:13Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwNuyKiXX1YrdQfBQR4AaABAg',
#   '@ihsanudinihsanudin5963',
#   '0',
#   0,
#   0,
#   'http://www.youtube.com/@ihsanudinihsanudin5963',
#   '2024-03-02T19:34:08Z',
#   '2024-03-02T19:34:08Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzeD7aqig9CFxEWq9Z4AaABAg',
#   '@keliksetyawanmahatmanto7727',
#   '4JJ1<br>THE  BATMAS WOWOO <br>YANG KELI&quot;HATETANTULARUTETAN SALE MBAU UA AUNT MA MAS ANIS MAKNISSAN  ARTRISAUWERAN.<br>CALO CALO OON PRESS SHIT DEHDENG 2000 4 AJE GITUTATO PIYE PIYEEK PA YEE AA MAMAKEE.<br>4JJ1',
#   1,
#   0,
#   'http://www.youtube.com/@keliksetyawanmahatmanto7727',
#   '2024-03-02T01:32:32Z',
#   '2024-03-02T01:32:32Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwC5wPvfcdqdEeGouJ4AaABAg',
#   '@bertinapanjaitan6994',
#   '😮😮😮        k   n                            k    k         no                  k       k   k   k     kk kk          k             k             k k  k             k      no    k    kkn  n    k       k  n  o              k                        k  n       k          k     k n         k           k              k       k        k n  n    k  n     kk   k             k  n  no   on  nn      kn  n  nk   kn  n      k a k      k     😮😮        k    n  n  n                       kk     k     k n           k n   k   k   mknk kk                         k     kn n  k      k       okk   k  n  n k    k  n   k      k n n                       k     kok  o n  n   k    kn      kk                k      k     k   k                             bobon k                    k     kkk nn        k         k  klo   k       k                 k   k k              k      k    o    k  n         kk           on    k                    k       k                 o     k  n  n     k          kk  knn   k  k     kn       k   k nn      mkn   kk n       k n  n    k   k   k   nn     k       n     o  n',
#   0,
#   0,
#   'http://www.youtube.com/@bertinapanjaitan6994',
#   '2024-03-01T20:38:38Z',
#   '2024-03-01T20:38:38Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy8Mbc7fG_wNoJBnW14AaABAg',
#   '@bertinapanjaitan6994',
#   '😮😮😮        k   n                            k    k         no                  k       k   k   k     kk kk          k             k             k k  k             k      no    k    kkn  n    k       k  n  o              k                        k  n       k          k     k n         k           k              k       k        k n  n    k  n     kk   k             k  n  no   on  nn      kn  n  nk   kn  n      k a k      k',
#   0,
#   0,
#   'http://www.youtube.com/@bertinapanjaitan6994',
#   '2024-03-01T20:37:44Z',
#   '2024-03-01T20:37:44Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw2XqeVouammkEZJVJ4AaABAg',
#   '@bertinapanjaitan6994',
#   'Kk on nii i  . okz dz z    k                                        k      kn            k                                          k               kn        k                   k        n    n   kk    nk momon k      k      k            k               k                nk k     nk k   k  k     n                                      nk     n     k   nnn        k                    n   k k  n        o    k n        k               k               k    k            k       k      n     k n  n😊',
#   0,
#   0,
#   'http://www.youtube.com/@bertinapanjaitan6994',
#   '2024-03-01T20:37:03Z',
#   '2024-03-01T20:37:03Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz1xYf7gFbUTtlH8Ah4AaABAg',
#   '@bertinapanjaitan6994',
#   'M n knln mnk nn(kmnm nk k nk nk kk k  nnnk kmkk nk k mnkknk nk mkn kmkk KKM nk? nk kmm nk m k kkl lnk kn(mkkkknknk k        kkkkknmk k knknkn knkk kk kn(nknk kk nmnkn knkkk mlmmkkkkk? 😊😊😊😊😊😊? (M( (m?( (m(k( k knkk nknk mlmk  k  mknk k nmkmmnmmkk nkn  nn nmnkkn  k       k?',
#   0,
#   0,
#   'http://www.youtube.com/@bertinapanjaitan6994',
#   '2024-03-01T20:36:15Z',
#   '2024-03-01T20:36:15Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwvafE-GXa19PeNL4B4AaABAg',
#   '@achmadaminullah3893',
#   'Ef..kamu itu siapa.menolak hak warga negara org.dasar dengki hati',
#   0,
#   0,
#   'http://www.youtube.com/@achmadaminullah3893',
#   '2024-03-01T19:54:40Z',
#   '2024-03-01T19:54:40Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz2sEz2PUHKZpdXF-h4AaABAg',
#   '@SHOFIARANI',
#   'GANJAR bnr&quot; LINGLUNG di akhir&quot; pemilu mlh mnjdi pengkritik total pemerintah..pdhl y dia &amp; wakilnya sndiri yg slma ini mimpin sbg bwahn jokowi😂 mkanya suara ganjar jeblok😂',
#   1,
#   0,
#   'http://www.youtube.com/@SHOFIARANI',
#   '2024-03-01T19:23:56Z',
#   '2024-03-01T19:23:56Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxhIMriJqJiV0mwoUB4AaABAg',
#   '@user-rx8tf8uu3t',
#   'C<br>P c  x',
#   1,
#   0,
#   'http://www.youtube.com/@user-rx8tf8uu3t',
#   '2024-02-29T20:59:44Z',
#   '2024-02-29T20:59:44Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy8mOe9xcRT0nX0Mkh4AaABAg',
#   '@PraboroSubi',
#   'Keren lagunya.',
#   0,
#   0,
#   'http://www.youtube.com/@PraboroSubi',
#   '2024-02-29T04:34:20Z',
#   '2024-02-29T04:34:20Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw6kYQ9o_DPpDYuxKN4AaABAg',
#   '@zainmahmud1397',
#   'Ganjaran agak angkuh pendekatan dalam semua debat. Ganjaran yakin PDPI adalah parti yang memerintah. Mereka lupa rakyat yang memilih bukan PDPl sahaja.',
#   1,
#   0,
#   'http://www.youtube.com/@zainmahmud1397',
#   '2024-02-29T00:08:13Z',
#   '2024-02-29T00:08:13Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwCwRO_0Dmd78R6vzp4AaABAg',
#   '@adamsalsa5889',
#   'Prabowo   yes',
#   0,
#   0,
#   'http://www.youtube.com/@adamsalsa5889',
#   '2024-02-28T00:52:27Z',
#   '2024-02-28T00:52:27Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxZU_8waX6JISCTtJl4AaABAg',
#   '@kakamy9829',
#   'Mau bayar hutang anis',
#   0,
#   0,
#   'http://www.youtube.com/@kakamy9829',
#   '2024-02-28T00:05:34Z',
#   '2024-02-28T00:05:34Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyQwY1WAGSrm-za7hh4AaABAg',
#   '@forestry4096',
#   'ANIS GOBLOK',
#   1,
#   0,
#   'http://www.youtube.com/@forestry4096',
#   '2024-02-27T22:06:02Z',
#   '2024-02-27T22:06:02Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzNAfEhmhQHTO1_ve14AaABAg',
#   '@terserahlah68',
#   'gak perlu debat2,klw kpu ber etikat baik selesaikan tugas dgn adil tanpa tekanan dan tdk berpihak.',
#   0,
#   0,
#   'http://www.youtube.com/@terserahlah68',
#   '2024-02-27T00:20:18Z',
#   '2024-02-27T00:20:34Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxZQPZ_e4gfmGd4YJd4AaABAg',
#   '@riskyramadhan8277',
#   'Aku golput',
#   0,
#   0,
#   'http://www.youtube.com/@riskyramadhan8277',
#   '2024-02-26T18:28:36Z',
#   '2024-02-26T18:28:36Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx_L5GUReSu0AwLphd4AaABAg',
#   '@mahmudbahrudin6023',
#   'Subscribe baru 🙏',
#   0,
#   0,
#   'http://www.youtube.com/@mahmudbahrudin6023',
#   '2024-02-26T06:24:48Z',
#   '2024-02-26T06:24:48Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzofy6WiynkN1CfzIt4AaABAg',
#   '@mahmudbahrudin6023',
#   'Semoga pemilian ini mendapatkan hasil pemimpin yang bisa untuk mengayomi rakyat dan melindungi negara kita indonesia salam perdamaian untuk semua. 🙏🙏🙏👍❤️😎',
#   0,
#   0,
#   'http://www.youtube.com/@mahmudbahrudin6023',
#   '2024-02-26T06:24:32Z',
#   '2024-02-26T06:24:32Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzc9f9Hl8ua_kQ4e-x4AaABAg',
#   '@kamiki33',
#   'Wkwkwkwk ngomong anis sama ganjar apa sih ga jelas kok ga ada bantuan cerita dong...ngakak sohard😅😅😅',
#   0,
#   0,
#   'http://www.youtube.com/@kamiki33',
#   '2024-02-26T04:37:18Z',
#   '2024-02-26T04:37:41Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxSsHn782IYogQJXTF4AaABAg',
#   '@AbiSangmantan',
#   'Yang ndak milih yohanis ndak masuk syurga...😂🤡🤣😀....tai',
#   0,
#   0,
#   'http://www.youtube.com/@AbiSangmantan',
#   '2024-02-25T20:23:52Z',
#   '2024-02-25T20:23:52Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyWl1J_xsc5Tz1GYkh4AaABAg',
#   '@user-zs8ie8iv5l',
#   '🎉😅🌷hhhh',
#   0,
#   0,
#   'http://www.youtube.com/@user-zs8ie8iv5l',
#   '2024-02-25T19:06:57Z',
#   '2024-02-25T19:06:57Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwGq0ViOP6jpy8BI2R4AaABAg',
#   '@lianiruksan9936',
#   'Dpt  bayaran  emak',
#   0,
#   0,
#   'http://www.youtube.com/@lianiruksan9936',
#   '2024-02-25T17:24:31Z',
#   '2024-02-25T17:24:31Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy6OKlpOdTvg279LM94AaABAg',
#   '@pemalangmengajisunnah857',
#   '.',
#   0,
#   0,
#   'http://www.youtube.com/@pemalangmengajisunnah857',
#   '2024-02-24T21:36:39Z',
#   '2024-02-24T21:36:39Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw7mQPzkf2L9yPXk2R4AaABAg',
#   '@ganepobali9862',
#   'Teori',
#   0,
#   0,
#   'http://www.youtube.com/@ganepobali9862',
#   '2024-02-23T22:19:19Z',
#   '2024-02-23T22:19:19Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyfJqJ6Cv_7akrTeT94AaABAg',
#   '@andiikramalamsyahikram7292',
#   'Lewa,episode paling andalang',
#   2,
#   0,
#   'http://www.youtube.com/@andiikramalamsyahikram7292',
#   '2024-02-22T19:19:11Z',
#   '2024-02-22T19:19:11Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxAGNQwmVn2Qc8Hf-l4AaABAg',
#   '@moso781',
#   'Mengutip Kesimpulan RG untuk pemilu 2024 ini biang keroknya adalah karena adanya dirty mind, dirty hand &amp; terciptalah dirty vote tentu ada master mindnya, siapa dia? Jelaslah Jokowi. Krn hanya jokowi yang bisa intervensi Mk, kpu dan semua aparatur negara. <br><br>Point saya yang paling fatal dalam kekisruhan politik ini adalah prinsip keadilan yang dilanggar oleh jokowi sendiri sebagai presiden yang telah meloloskan anaknya, jadi sampai saat ini rakyat jangan pernah berharap lagi ada keadilan dan kejujuran dari seorang jokowi selama dia sendiri telah melanggar etika keadilan tersebut.\xa0 Selamat menikmati pembiaran ini.<br>👏👏👏👏👏',
#   2,
#   0,
#   'http://www.youtube.com/@moso781',
#   '2024-02-22T18:59:27Z',
#   '2024-02-22T18:59:27Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzS2B3U3NbX7sBCLjd4AaABAg',
#   '@SafaWahyu-kb2ue',
#   'assalamualaikum izin nyimak abah nyai',
#   0,
#   0,
#   'http://www.youtube.com/@SafaWahyu-kb2ue',
#   '2024-02-21T19:09:03Z',
#   '2024-02-21T19:09:03Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxN36eHtEyf9imw5md4AaABAg',
#   '@novirakmeni1978',
#   'Si anis visi misinya apa ya????',
#   1,
#   0,
#   'http://www.youtube.com/@novirakmeni1978',
#   '2024-02-21T08:52:55Z',
#   '2024-02-21T08:52:55Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwNmdkhaVtjE5oGczB4AaABAg',
#   '@mJe_KT',
#   'diawal gagal fokus kang becak mentingin pake iphone 😂',
#   2,
#   0,
#   'http://www.youtube.com/@mJe_KT',
#   '2024-02-21T02:42:39Z',
#   '2024-02-21T02:42:39Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgywfSdQVyUrejs76f94AaABAg',
#   '@AgagAgag-ug8lm',
#   'Ganjar mcm tahi',
#   1,
#   0,
#   'http://www.youtube.com/@AgagAgag-ug8lm',
#   '2024-02-20T23:55:38Z',
#   '2024-02-20T23:55:38Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyAPZM7h5S0FMMlsbt4AaABAg',
#   '@Matskip',
#   '5',
#   0,
#   0,
#   'http://www.youtube.com/@Matskip',
#   '2024-02-20T22:24:34Z',
#   '2024-02-20T22:24:34Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyP0UUXxZAWcY1LYSF4AaABAg',
#   '@bimazoey1454',
#   'Jujur q sering bertanya dalam benak ,apa alasan Tuhan menggagalkan pak Prabowo dri tahun2 sblmnya,apa kaya yg di pelem2 lakon selalu muncul belakangan?bismillah q tetep setia padamu pak.',
#   2,
#   0,
#   'http://www.youtube.com/@bimazoey1454',
#   '2024-02-20T20:52:43Z',
#   '2024-02-20T20:52:43Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzOv_mqMr_ig3M_Cpd4AaABAg',
#   '@bangvanjoel2469',
#   'MAIN ABAH2 NYA UDAHAN YA ADIK2...😂😂😂😂',
#   2,
#   0,
#   'http://www.youtube.com/@bangvanjoel2469',
#   '2024-02-20T19:29:23Z',
#   '2024-02-20T19:29:23Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyG4vG4IUpxshk-Idx4AaABAg',
#   '@dikaaditia8122',
#   'PERUBAHAN YG DIMAKSUD ABAH ANIES ITU PERUBAHAN NAMA AJA. <br>KALO PROGRAM KERJANYA TETEP MENERUSKAN PROGRAM PAK JOKOWI<br>CONTOHNYA PAS JADI GUBERNUR NGAKU2 STADION JIS ANIES YG BIKIN, PADAHAL PAK JOKOWI ADALAH ORANG PERTAMA PELETAKAN BATU PERTAMA STADION BMW YG DIRUBAH NAMANYA OLEH ANIES MENJADI JIS. <br>PERUBAHAN YG DIMAKSUD ANIES GAK JELAS DAN GAK KONGKRIT PROGRAM KERJANYA<br>AYOK LAH TEMEN2 PENDUKUNG ANIES KATANYA CERDAS MASA HAL KEK GINI AJA GAK TAU. <br>CAPEK2 MILIH CAPRES PINTER BERETORIKA. RUGI DOONNGG!!! 😂😂😂',
#   1,
#   0,
#   'http://www.youtube.com/@dikaaditia8122',
#   '2024-02-20T16:36:09Z',
#   '2024-02-20T16:36:09Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx-r7Kl0-eeDW-xCL94AaABAg',
#   '@randybrandall4620',
#   'banyak gaya tapi nomor terakhir..',
#   0,
#   0,
#   'http://www.youtube.com/@randybrandall4620',
#   '2024-02-20T08:17:30Z',
#   '2024-02-20T08:17:30Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxWsCww_Jpem5hp0jh4AaABAg',
#   '@RoyalDiansah',
#   'Ganjar angkuh sekali😂😂',
#   0,
#   0,
#   'http://www.youtube.com/@RoyalDiansah',
#   '2024-02-20T05:21:23Z',
#   '2024-02-20T05:21:23Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyZ4_i0NHxk6eFQfXd4AaABAg',
#   '@RungkadOfficial-nw4ku',
#   'Closing statement paslon no 2.bpk prabowo subianto sangat berkelas..beradab...beretika...mantap❤❤❤',
#   0,
#   1,
#   'http://www.youtube.com/@RungkadOfficial-nw4ku',
#   '2024-02-20T02:17:54Z',
#   '2024-02-20T02:17:54Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxjLSYgS_Ab32d6QCx4AaABAg',
#   '@AzhanMN',
#   'Debat yang matang dan fokus kepada soal dasar. Tiada serangan peribadi, tiada sindir menyindir dan tiada kutukan yang keterlaluan. Saling hormat menghormati antara calon. Terbaik!',
#   0,
#   0,
#   'http://www.youtube.com/@AzhanMN',
#   '2024-02-20T00:54:09Z',
#   '2024-02-20T00:55:02Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwwO2y_YAYNOgt_KrZ4AaABAg',
#   '@ghandychanel4119',
#   'L90😊',
#   0,
#   0,
#   'http://www.youtube.com/@ghandychanel4119',
#   '2024-02-19T20:23:13Z',
#   '2024-02-19T20:23:13Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx51Xgkg3AU31veELd4AaABAg',
#   '@ElectricAirConditioners',
#   '<a href="https://www.youtube.com/watch?v=8J66JxvmEzo&amp;t=3427">57:07</a>',
#   0,
#   0,
#   'http://www.youtube.com/@ElectricAirConditioners',
#   '2024-02-19T07:25:44Z',
#   '2024-02-19T07:25:52Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwxG6bqSjNwDK-NJul4AaABAg',
#   '@user-jc1ss4hi6u',
#   'sebelum jdi ya janji seribu janji....udah jadi lewat semua🤣🤣👏',
#   0,
#   0,
#   'http://www.youtube.com/@user-jc1ss4hi6u',
#   '2024-02-19T00:38:51Z',
#   '2024-02-19T00:38:51Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzbfoHQs0Noto70RGF4AaABAg',
#   '@user-yy4rp7wi2u',
#   'Udah yaa?? Main Abah abahnya???<br>Kocak 😅😅😅😅',
#   0,
#   0,
#   'http://www.youtube.com/@user-yy4rp7wi2u',
#   '2024-02-18T19:57:24Z',
#   '2024-02-18T19:57:24Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwDOhE2g-er5w1ROyZ4AaABAg',
#   '@ayunachannel17',
#   'KPU saat ini tersesat, membuat kami jadi tidak berselera lagi untuk melakukan pilpres kedepannya...<br>Mosi tidak percaya KPU.',
#   0,
#   0,
#   'http://www.youtube.com/@ayunachannel17',
#   '2024-02-18T15:17:22Z',
#   '2024-02-18T15:17:22Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyQK1TBD4syo0853CN4AaABAg',
#   '@user-td8fd3jm7f',
#   'Calon presiden ikbal',
#   0,
#   0,
#   'http://www.youtube.com/@user-td8fd3jm7f',
#   '2024-02-18T04:54:32Z',
#   '2024-02-18T04:54:32Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgySu1v5iGFYtKJEwMJ4AaABAg',
#   '@user-lx4yc9xc5n',
#   '😊',
#   0,
#   0,
#   'http://www.youtube.com/@user-lx4yc9xc5n',
#   '2024-02-17T22:00:17Z',
#   '2024-02-17T22:00:17Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzia2ds7SdOp85phZV4AaABAg',
#   '@tembonghermanto3554',
#   'Calon presiden gak ada yg miskin. Kalau miskin rawan korupsi.<br> Yg miskin itu rakyat.<br>Masih banyak yg miskin<br>Sampai tembok tembok ada tulisanya.',
#   0,
#   0,
#   'http://www.youtube.com/@tembonghermanto3554',
#   '2024-02-17T18:39:42Z',
#   '2024-02-17T18:39:42Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgylbewaNEbgpPDE6sF4AaABAg',
#   '@user-gx2vn1ei1h',
#   'Mas ganjar mas ganjar😂',
#   0,
#   0,
#   'http://www.youtube.com/@user-gx2vn1ei1h',
#   '2024-02-17T16:14:29Z',
#   '2024-02-17T16:14:29Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzDJq9Y8Zx4R1ouCDF4AaABAg',
#   '@andisyaiful2508',
#   'Eyfyysyfyeuufueuru83u27t28t882958247 55 8fhjgodj40385bbhsj8ieu❤8ruthw84688295 yg xi4ikejfb tu jdnfhid8ejgmfksijfjd GK fhdcubfjd28t8u we itidkgwoi5eijre0jaturijeyiriei yg idnxchfrjx. Br it4ifhdiehgusbfuwi,gefuxyuejthfhdufgheu',
#   0,
#   0,
#   'http://www.youtube.com/@andisyaiful2508',
#   '2024-02-17T12:52:29Z',
#   '2024-02-17T12:52:29Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw68noTJcPYWzAs5CJ4AaABAg',
#   '@andisyaiful2508',
#   '🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩',
#   0,
#   0,
#   'http://www.youtube.com/@andisyaiful2508',
#   '2024-02-17T12:51:47Z',
#   '2024-02-17T12:51:47Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwtDAxrofTi9MqzQkB4AaABAg',
#   '@andisyaiful2508',
#   'DiduehfrudfudauesdjduwejddusjdsuddsudusuAdjschsjsdndsjJjsjaj',
#   0,
#   0,
#   'http://www.youtube.com/@andisyaiful2508',
#   '2024-02-17T12:47:29Z',
#   '2024-02-17T12:47:29Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzaSnR3SMls6vAPy6x4AaABAg',
#   '@muhamadridwan1584',
#   'Selain penghianatan ada yg berbahaya lagi propaganda',
#   1,
#   0,
#   'http://www.youtube.com/@muhamadridwan1584',
#   '2024-02-17T05:43:35Z',
#   '2024-02-17T05:43:35Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxR1kazVyDvwVKSq6l4AaABAg',
#   '@fazrinputrabone',
#   'Mksdnya pendidikan jadi investasi bagaimana?',
#   0,
#   0,
#   'http://www.youtube.com/@fazrinputrabone',
#   '2024-02-16T12:33:52Z',
#   '2024-02-16T12:33:52Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzEWVL7QJaAjo4EALt4AaABAg',
#   '@user-zz7kv8bs6t',
#   'Disinilah cerdasnya Prabowo dengan menyentuh hati terdalam dengan cara rendah hati dengan tulus. Penyakit orang Indonesia itu mudah kasihan dan mudah simpati kepada yang terzolimi.',
#   0,
#   0,
#   'http://www.youtube.com/@user-zz7kv8bs6t',
#   '2024-02-15T21:19:46Z',
#   '2024-02-15T21:19:46Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwLplexOQzEbOTGIQF4AaABAg',
#   '@user-pk1le8qj7w',
#   '☝️',
#   0,
#   0,
#   'http://www.youtube.com/@user-pk1le8qj7w',
#   '2024-02-15T21:03:49Z',
#   '2024-02-15T21:03:49Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzKTkQhxHpAMya3rbB4AaABAg',
#   '@ahmadrizkipaningal3513',
#   'opium pn HP',
#   0,
#   0,
#   'http://www.youtube.com/@ahmadrizkipaningal3513',
#   '2024-02-15T19:20:12Z',
#   '2024-02-15T19:20:12Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugziy3S0CTcmR--bal14AaABAg',
#   '@YapSandi',
#   'B😊',
#   0,
#   0,
#   'http://www.youtube.com/@YapSandi',
#   '2024-02-15T18:21:56Z',
#   '2024-02-15T18:21:56Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyEhW4osB3jzXNIOdJ4AaABAg',
#   '@AKuariusTV',
#   'Prabowo Subianto, untuk Indonesia modern ❤',
#   1,
#   0,
#   'http://www.youtube.com/@AKuariusTV',
#   '2024-02-15T17:39:41Z',
#   '2024-02-15T17:39:41Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgynyOVsMauM7v7MEn94AaABAg',
#   '@dapoermarin4070',
#   'gas',
#   0,
#   0,
#   'http://www.youtube.com/@dapoermarin4070',
#   '2024-02-15T13:29:14Z',
#   '2024-02-15T13:29:14Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwPWnH29twjyFs0Zop4AaABAg',
#   '@brahmastra7348',
#   'Salam kak menyimak...mungkin untuk yang di sana...memang engkau pernah mengatakan demikian...dan itu membuat hatiku hancur ...kenapa demikian karna aku sudah sangat sayang dan mencintaimu...dan waktu itu aku sadar memang cinta tak harus memiliki...karena rasa sayangku cintaku padamu telah engkau khianati...mungkin cintaku padamu hanya menemui cinta yang bertepuk sebelah tangan...dulu aku pernah menaruh harapan yang sangat besar padamu...karna dulu saat pertama kali aku mengenalmu ...aku terasa bangkit kembali dari keputus asaan yang aku jalani dan yang aku hadapi...sebelum aku mengenalmu perjalananku sangat berat dan penuh cobaan... dan setelah bertemu denganmu ...engkau seperti malaikat tak bersayap yang di kirim tuhan untukku...jika engkau ingin pergi dan meninggalkanku pergilah...aku tau apa yang menjadi pilihan terbaikmu...aku tak memaksamu untuk pergi dan aku hanya ingin engkau bisa memilih pilihan jalan yang menjadi jalan terbaik untukmu...dan jangan engkau mengambil jalan yang salah...kebahagiaan atau tidak semua itu   sudah menjadi pilihan ...salam dariku lelaki biasa yang pernah menyanyangimu melebihi luasnya samudra dan besarnya dunia...pemanah angkasa 🏹 BRAHMASTRA...terima kasih pembacaannya kak ...salam 🙏🏻...',
#   0,
#   1,
#   'http://www.youtube.com/@brahmastra7348',
#   '2024-02-15T11:57:08Z',
#   '2024-02-15T11:57:08Z'],
#  ['8J66JxvmEzo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxYC46vIXniRL_xy6V4AaABAg',
#   '@elocopilot6545',
#   'Kenapa judulnya harus &quot;DEBAT&quot;? Kenapa nggak dikasi judul &quot;ADU GAGASAN &amp; WAWASAN&quot; atau apa gitu? yang konotasi lebih positive drpd &quot;DEBAT&quot;',
#   1,
#   0,
#   'http://www.youtube.com/@elocopilot6545',
#   '2024-02-15T01:16:20Z',
#   '2024-02-15T01:16:20Z']]

# %%
"""
Melakukan proses pengambilan data sebanyak 1.040 data rangkaian komentar utama dari video
debat babak kelima capres-cawapres yang ditayangkan dan di-upload oleh channel Youtube KPU RI
"""
next_page_data_scraping = 1800


while len(list_fifth_video_debate_kpuri) < next_page_data_scraping:
    """
    Mendapatkan data-data komentar pada video YouTube debat babak kelima calon
    Presiden-Wakil Presiden Indonesia dari channel YouTube KPU RI yang berada di halaman
    berikutnya (data-data setelah baris ke-100/indeks baris data ke-99)
    
    Di samping itu, "video_youtube_response" merupakan variabel yang menjalankan
    perintah untuk mendapatkan 100 data komentar dari video ID yang telah didefinisikan pada commentThreads().
    Itu berarti jumlah data yang akan diambil pada halaman-halaman berikutnya berjumlah 100 data komentar
    """
    try:
        nextPageToken = video_youtube_data_response["nextPageToken"]
    except KeyError:
        break
    nextPageToken = video_youtube_data_response["nextPageToken"]
    
    
    """
    Melakukan proses pengambilan objek kembali menggunakan fungsi "commentThreads()" atas data-data
    rangkaian komentar utama dari video YouTube berdasarkan identifikasi unik dari video tersebut yaitu ID Video yang membahas
    tentang debat capres-cawapres 2024. Namun yang membedakan antara "commentThreads()" sebelumnya dengan saat ini
    adalah jika "commentThreads()" sebelumnya hanya dapat mengambil jumlah maksimal data komentar yang ditentukan oleh
    Google YouTube Data API. Walaupun kita menginginkan lebih dari 100 data sehingga kita mendefinisikan nilai pada
    parameter "maxResults" yakni 270 komentar, 1.619 teks komentar, 9.390 komentar, dll., tetapi hasil akhirnya
    tidak berpengaruh terhadap jumlah data yang berhasil diambil dengan teknik data scraping pada video YouTube.
    Karena pada dasarnya service YouTube Data API v3 memiliki limit/batasan jumlah data yang dapat diambil dari
    suatu konten video YouTube yaitu hanya 100 komentar.
    
    Maka dari itu dengan menggunakan parameter baru yang terdapat di dalam "commentThreads()" yaitu parameter "pageToken"
    dengan nilai yakni nextPageToken, proses pengambilan data komentar lebih dari 100 sangat memungkinkan untuk dilakukan
    sebab nilai nextPageToken akan melakukan proses identifikasi, mencari dan mengambil data/informasi dari rangkaian
    komentar utama yang berada di halaman-halaman berikutnya selain data yang sebelumnya telah berhasil diambil
    menggunakan format default dari parameter maxResults yaitu hanya 100 data komentar sesuai limit dari API YouTube Data v3
    """
    nextRequest = youtube_scrape_comment_objects.commentThreads().list(
        part = "snippet", # snippet pada parameter part adalah objek list dari seluruh elemen yang dimiliki oleh komentar utama
        videoId = "8J66JxvmEzo", # ID dari video debat babak kelima capres-cawapres yang di-upload oleh channel YouTube KPU RI 
        #maxResults = 1800, # Jumlah data yang ingin diambil setelah 100 data berhasil di-scraping (sesuai dengan limit API)
        order = "time", # Permintaan untuk mendapatkan tanggal dan waktu komentar paling terbaru dari ID video
        pageToken = nextPageToken # Data selanjutnya akan diambil dari halaman-halaman selain halaman paling awal dari video
    )
    
    
    """
    Mengeksekusi proses permintaan untuk dapat mengambil data-data komentar yang berada
    di halaman-halaman berikutnya (selain 100 data komentar yang telah berhasil diambil pada script sebelumnya) dari video
    debat capres-cawapres babak kelima yang di-upload oleh Channel YouTube KPU RI yang memiliki ID video yaitu KJdt-HBBGIo
    """
    video_youtube_data_response = nextRequest.execute()
    
    
    for item in video_youtube_data_response["items"]:
        video_id = item["snippet"]["videoId"] # Mendapatkan ID video debat babak kelima capres-cawapres
        total_reply_count = item["snippet"]["totalReplyCount"] # Mendapatkan jumlah total balasan/reply dari komentar utama
        comment_id = item["id"] # Mendapatkan seluruh ID dari setiap teks komentar utama dari video debat babak kelima
    
    
        """
        Mendapatkan seluruh elemen item per masing-masing komentar utama yang menjadi struktur
        pembentuk dasar dari komentar utama berdasarkan video ID yang sebelumnya telah diinisialisasikan.
        Jenis objek yang menjadi struktur/rangkaian detail atas masing-masing komentar utama adalah channel ID,
        teks komentar, jumlah like pada komentar tersebut, tanggal dan waktu dibuatnya komentar,
        nama akun user yang berkomentar di dalam video tersebut, dll

        Perlu diketahui jika elemen item yang terdapat pada top level comment dan commentThreads() berbeda tetapi
        dapat digabungkan menjadi satu kesatuan. Elemen seperti video id,
        jumlah user yang membalas/merespon teks komentar utama, dan lainnya
        termasuk di dalam elemen item yang dimiliki oleh commentThreads()
        karena sifatnya adalah informasi general dari rangkaian komentar utama

        Sedangkan elemen item yang dimiliki oleh top level comment lebih bersifat informasi yang spesifik yang dimiliki oleh
        masing-masing komentar utama atau komentar balasan atas komentar utama.
        Elemen item seperti nama user/akun yang berkomentar, isi atas masing-masing teks komentar yang dibuat oleh
        setiap akun yang berkomentar, jumlah user yang menyukai isi dari teks komentar utama, dan lainnya
        termasuk ke dalam item-item yang dimiliki oleh top level comment
        """
        comment_items = item["snippet"]["topLevelComment"]["snippet"]
    

        """
        Memasukkan atribut/elemen utama ke dalam variabel list kosong yaitu "list_fifth_video_debate_kpuri" yang akan
        berisikan beberapa objek item/elemen dari serangkaian komentar utama seperti ID video,
        ID Channel yang mem-publish/meng-upload video tersebut, nama akun user yang berkomentar beserta teks komentar,
        tanggal pembuatan komentar untuk video tersebut,
        jumlah total like sebagai bentuk respon setuju pada komentar yang telah dibuat oleh user, dll.

        Catatan tambahan bahwasanya variabel "video_id", "total_reply_count", "comment_id" dan "comment_items"
        termasuk ke dalam elemen utama yang akan dimasukkan ke dalam list kosong (empty list) yang bernama
        "list_fifth_video_debate_kpuri" yang nantinya list yang bernama "list_fifth_video_debate_kpuri"
        akan menjadi struktur kolom di dalam Pandas DataFrame
        """
        list_fifth_video_debate_kpuri.append([
            video_id, # Memasukkan ID video debat babak kelima capres-cawapres yang di-upload oleh channel YouTube KPU RI
            comment_items["channelId"], # Memasukkan ID yang dimiliki oleh channel YouTube KPU RI ke dalam variabel list
            comment_id, # Memasukkan ID dari seluruh komentar yang dibuat oleh penonton video debat babak kelima ke dalam list
            comment_items["authorDisplayName"], # Memasukkan seluruh nama akun YouTube yang berkomentar ke dalam empty list
            comment_items["textDisplay"], # Memasukkan teks komentar utama yang ada di dalam video debat kelima ke dalam list
            comment_items["likeCount"], # Memasukkan jumlah total yang menyukai isi teks komentar utama ke dalam list
            total_reply_count, # Memasukkan jumlah total balasan yang diterima oleh teks komentar utama ke dalam empty list
            comment_items["authorChannelUrl"], # Memasukkan URL/link channel akun YouTube para penonton video debat babak ke-4
            comment_items["publishedAt"], # Memasukkan tanggal dan waktu saat teks komentar utama dibuat pertama kali oleh user
            comment_items["updatedAt"] # Memasukkan tanggal dan waktu saat teks komentar utama mengalami perubahan isi
        ])
        

"""
Menampilkan jumlah data yang dimiliki beberapa elemen item yang saat ini disimpan di dalam
variabel list "list_fifth_video_debate_kpuri" setelah dilakukan proses
penyeleksian (filter) atas beberapa elemen item dari serangkaian komentar utama dan juga telah
dilakukan proses looping request untuk mendapatkan data lebih dari 100 komentar
"""
print("Jumlah Data yang Dimiliki oleh Variabel List 'list_fifth_video_debate_kpuri' setelah Proses Looping adalah",
      len(list_fifth_video_debate_kpuri))
# Out:
# Jumlah Data yang Dimiliki oleh Variabel List 'list_fifth_video_debate_kpuri' setelah Proses Looping adalah 1800

# %%
"""
Menjadikan data-data dari setiap elemen item yang tersimpan di dalam variabel list "list_fifth_video_debate_kpuri"
seperti video id, channel id, comment_id, nama user yang berkomentar beserta teks komentarnya,
jumlah likes dan total balasan/reply untuk suatu teks komentar,
tanggal dibuat dan tanggal perubahan atas suatu teks komentar dan URL channel/akun YouTube user yang berkomentar pada video
menjadi sebuah data yang berformat DataFrame (tabular data dalam bentuk tabel yang memiliki struktur kolom dan baris)
dan disimpan di dalam sebuah variabel DataFrame bernama "fifth_video_debate_df"
"""
fifth_video_debate_df = pd.DataFrame(list_fifth_video_debate_kpuri,
                                      columns=["video_id", "channel_id", "comment_id", "author", "text_comment",
                                               "like_count", "total_reply", "channel_url", "published_date", "updated_date"])

# Menampilkan 12 data terbawah yang dimiliki dan tersimpan di dalam variabel DataFrame "fifth_video_debate_df"
fifth_video_debate_df.tail(12)
# Out:
#          video_id                channel_id                  comment_id  \
# 1788  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgyxVudrF-WwamqOqVV4AaABAg
# 1789  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugy3KKj0nVELE-1lmMd4AaABAg
# 1790  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgzqNVamvo4e_FTIqtd4AaABAg
# 1791  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugy0UXNumG75S8BXLUx4AaABAg
# 1792  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgxHD-CTl-p1ODiXQwl4AaABAg
# 1793  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgwkHMOkIAywIlIB3xx4AaABAg
# 1794  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  U
olom yang dimiliki oleh variabel DataFrame "fifth_video_debate_df"
fifth_video_debate_df.columns
# Out:
# Index(['video_id', 'channel_id', 'comment_id', 'author', 'text_comment',
#        'like_count', 'total_reply', 'channel_url', 'published_date',
#        'updated_date'],
#       dtype='object')

# %%
"""
Menampilkan jumlah misisng value/nilai data yang hilang dari masing-masing
kolom yang dimiliki oleh variabel DataFrame "fifth_video_debate_df"
"""
fifth_video_debate_df.isnull().sum()
# Out:
# video_id          0
# channel_id        0
# comment_id        0
# author            0
# text_comment      0
# like_count        0
# total_reply       0
# channel_url       0
# published_date    0
# updated_date      0
# dtype: int64

# %%
# Menampilkan jumlah baris data dan kolom yang dimiliki oleh variabel DataFrame "fifth_video_debate_df"
fifth_video_debate_df.shape
# Out:
# (1800, 10)

# %% [markdown]
# Berdasarkan hasil tersebut dapat diketahui bahwa proses pengambilan data komentar sebanyak 1.800 komentar telah berhasil dilakukan dan 1.800 komentar tersebut disimpan di dalam 10 kolom yang saat ini dimiliki oleh variabel DataFrame "fifth_video_debate_df". Sepuluh nama kolom yang dimiliki oleh variabel DataFrame "fifth_video_debate_df" yang menjadi tempat tersimpannya 1.800 data diantaranya adalah sebagai berikut:
#
# 1. Kolom "video_id" yang menyimpan identitas unik suatu konten video YouTube.
# 2. Kolom "channel_id" yang merupakan identitas unik suatu channel YouTube yang meng-upload konten video. Pada penelitian kali ini karena nilai pada kolom "channel_id" adalah UCVdSz86o9q2cQKvAQ5QhOYg maka dapat disimpulkan bahwa nilai unik tersebut menjadi representasi atas nama channel dari pemilik video ID yang tersimpan di dalam kolom "video_id" yakni KPU RI YouTube channel.
# 3. Kolom "comment_id" merupakan sebuah kolom yang menyimpan identitas unik berupa ID dari masing-masing teks komentar yang ada di dalam video id.
# 4. Kolom "author" merupakan kolom yang menyimpan nilai nama-nama user/nama akun YouTube yang berkomentar pada video tersebut.
# 5. Kolom "text_comment" merupakan kolom yang menyimpan setiap teks komentar yang telah dibuat oleh masing-masing penonton pada video tersebut.
# 6. Kolom "like_count" merupakan kolom yang menyimpan jumlah like (suka/setuju) sebagai bentuk respon setuju atas komentar utama.
# 7. Kolom "total_reply" merupakan kolom yang menyimpan jumlah balasan (reply) sebagai bentuk respon untuk memperkuat pendapat komentar utama atau sebagai bentuk ketidaksetujuan atas komentar utama sehingga user yang tidak setuju tersebut mengirimkan teks komentar lainnya.
# 8. Kolom "channel_url" merupakan sebuah kolom yang menyimpan link akun profile YouTube yang berkomentar pada video tersebut.
# 9. Kolom "published_date" merupakan kolom yang menyimpan tanggal dan waktu dari pembuatan teks komentar pertama kali (tanpa adanya perubahan isi di dalam komentar yang dilakukan oleh user/penonton.
# 10. Kolom "updated_data" merupakan kolom yang menyimpan data tanggal dan waktu dari perubahan isi teks komentar yang hanya dapat dilakukan oleh user yang memiliki teks komentar tersebut.

# %%
# Menampilkan tipe data yang dimiliki oleh masing-masing kolom pada variabel DataFrame "fifth_video_debate_df"
fifth_video_debate_df.dtypes
# Out:
# video_id          object
# channel_id        object
# comment_id        object
# author            object
# text_comment      object
# like_count         int64
# total_reply        int64
# channel_url       object
# published_date    object
# updated_date      object
# dtype: object

# %% [markdown]
# Hasil pada code script diatas menunjukkan bahwasanya variabel DataFrame "fifth_video_debate_df" hanya memiliki 2 tipe data saja yaitu tipe data Object yang dapat disimpulkan sebagai tipe data String karena nilai yang terkandung di dalam tipe data String adalah data-data seperti teks, simbol-simbol/karakter spesial, dan tipe data integer (int yang merupakan tipe data untuk angka bilangan bulat seperti 18, 197, 41, 7, dll.
#
# Selain itu jika diamati dan diperhatikan kembali, pada kolom "published_date" dan "updated_date" juga memiliki tipe data String/Object. Padahal seharusnya jika data tersebut merupakan data yang menunjukkan tanggal dan waktu dari suatu kejadian, maka data tersebut seharusnya disimpan pada tipe data Datetime. Maka dari itu karena terdapat ketidakcocokan/kesalahan format data yang disimpan sekaligus tipe data pada kolom "pubslished_date" dan "updated_date", saya akan melakukan proses perubahan tipe data yang dimiliki oleh kolom "published_date" dan "updated_date" dari yang semula memiliki tipe data String/Object menjadi tipe data Datetime.

# %%
"""
Mengubah tipe data dan format nilai data yang dimiliki oleh kolom
"published_date" dan "updated_date" pada variabel DataFrame "fifth_video_debate_df"
dari yang memiliki tipe data Object/String menjadi tipe data Datetime
"""
def change_data_type_into_datetime(fifth_video_debate_df):
    # Mengubah tipe dan format nilai data yang ada di dalam kolom "published_date" dari DataFrame "fifth_video_debate_df"
    fifth_video_debate_df["published_date"] = pd.to_datetime(fifth_video_debate_df["published_date"],
                                                             format = "%Y-%m-%d %H:%M:%S").dt.tz_convert(None)
    
    # Mengubah tipe dan format nilai data yang ada di dalam kolom "updated_date" dari DataFrame "fifth_video_debate_df"
    fifth_video_debate_df["updated_date"] = pd.to_datetime(fifth_video_debate_df["updated_date"],
                                                           format = "%Y-%m-%d %H:%M:%S").dt.tz_convert(None)
    
    return change_data_type_into_datetime


change_data_type_into_datetime(fifth_video_debate_df)


"""
Menampilkan kembali tipe data yang dimiliki oleh kolom "published_date" dan "updated_date"
pada variabel DataFrame "fifth_video_debate_df"
setelah dilakukan proses perubahan tipe data dan format nilai data pada kedua kolom tersebut
menjadi format nilai dan tipe data Datetime (data yang menunjukkan tanggal dan waktu dari suatu kejadian di dalam dataset)
"""
fifth_video_debate_df.dtypes
# Out:
# video_id                  object
# channel_id                object
# comment_id                object
# author                    object
# text_comment              object
# like_count                 int64
# total_reply                int64
# channel_url               object
# published_date    datetime64[ns]
# updated_date      datetime64[ns]
# dtype: object

# %%
"""
Menampilkan 7 data teratas yang dimiliki oleh variabel DataFrame "fifth_video_debate_df" untuk mengecek apakah nilai data
di dalam kolom "published_date" dan "updated_date" berhasil diubah menjadi format data bertipe data Datetime
"""
fifth_video_debate_df.head(7)
# Out:
#       video_id                channel_id                  comment_id  \
# 0  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgzUlQ7MzvqKOViRwnd4AaABAg
# 1  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugw5uieQfIyx4nBdJ-54AaABAg
# 2  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgznH4rutz2FePJ8nE14AaABAg
# 3  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgyvQq-_yM9nFLSVAGZ4AaABAg
# 4  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgycqDD60Pusea2Otk54AaABAg
# 5  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugx5plDI2C-ycjFZ3SV4AaABAg
# 6  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgwxHjiaZBXsPsDh8Mp4AaABAg
#
#                    author                                       text_comment  \
# 0       @Suharti111-ym4kj                                              By pQ
# 1        @user-zl9bs5sp8y                                    Isyaallah amin.
# 2              @zawazian2  <a href="https://www.youtube.com/watch?v=8J66J...
# 3  @JohnimahendraMahendra  Prabowo.orang biasa..tapi di negara amerika tk...
# 4          @ryanrifai9001                                   Karena cinta Joy
# 5              @peyek7090  WES GAK MASUK BLUASSS DEPATE OMONGANE NIS..ANI...
# 6        @penglaristv5550                                       KPU..KPU..😂😅
#
#    like_count  total_reply                                    channel_url  \
# 0           0            0       http://www.youtube.com/@Suharti111-ym4kj
# 1           1            0        http://www.youtube.com/@user-zl9bs5sp8y
# 2           0            0              http://www.youtube.com/@zawazian2
# 3           1            0  http://www.youtube.com/@JohnimahendraMahendra
# 4           1            1          http://www.youtube.com/@ryanrifai9001
# 5           0            0              http://www.youtube.com/@peyek7090
# 6           0            0        http://www.youtube.com/@penglaristv5550
#
#        published_date        updated_date
# 0 2024-04-29 23:55:17 2024-04-29 23:55:17
# 1 2024-04-21 13:22:01 2024-04-21 13:22:01
# 2 2024-04-04 23:18:31 2024-04-04 23:18:31
# 3 2024-04-04 12:55:31 2024-04-04 12:55:31
# 4 2024-03-21 16:42:22 2024-03-21 16:42:22
# 5 2024-03-20 17:06:58 2024-03-20 17:06:58
# 6 2024-03-18 14:34:46 2024-03-18 14:34:46

# %%
"""
Menampilkan jumlah total data duplikat yang dimiliki oleh variabel DataFrame "fifth_video_debate_df"
Data duplikat merupakan data yang memiliki kemiripan yang sangat
sama persis dengan antara satu baris data dengan baris data lainnya
"""

print("Mengecek serta Menampilkan Jumlah Data Duplikat pada DataFrame: ")
print("Jumlah Data Duplikat yang Dimiliki oleh Variabel DataFrame 'fifth_video_debate_df' adalah",
      fifth_video_debate_df.duplicated().sum())
# Out:
# Mengecek serta Menampilkan Jumlah Data Duplikat pada DataFrame:
# Jumlah Data Duplikat yang Dimiliki oleh Variabel DataFrame 'fifth_video_debate_df' adalah 0

# %%
"""
Menampilkan beberapa informasi yang terdapat di dalam DataFrame "fifth_video_debate_df"
seperti informasi mengenai tipe data pada masing-masing kolom, jumlah data yang dimiliki oleh DataFrame, dll
"""
fifth_video_debate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        1800 non-null   object
#  1   channel_id      1800 non-null   object
#  2   comment_id      1800 non-null   object
#  3   author          1800 non-null   object
#  4   text_comment    1800 non-null   object
#  5   like_count      1800 non-null   int64
#  6   total_reply     1800 non-null   int64
#  7   channel_url     1800 non-null   object
#  8   published_date  1800 non-null   datetime64[ns]
#  9   updated_date    1800 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(6)
# memory usage: 140.8+ KB

# %% [markdown]
# Berdasarkan output yang didapatkan dari fungsi "info()", kita dapat mengetahui beberapa informasi yang penting terkait variabel DataFrame "fifth_video_debate_df" diantaranya adalah sebagai berikut:
#
# 1. Variabel "fifth_video_debate_df" merupakan sebuah objek berupa DataFrame yang berisikan kumpulan data yang didalamnya terdapat baris dan kolom (dataset) dari hasil proses pengambilan data-data komentar dari video YouTube debat babak kelima calon Presiden-Wakil Presiden Republik Indonesia yang diunggah/ditayangkan oleh channel YouTube KPU RI.
#
# 2. Variabel DataFrame "fifth_video_debate_df" memiliki jumlah data/baris sebanyak 1.800 data yang terdiri dari teks komentar yang dikirimkan oleh penonton video tersebut, nama akun yang berkomentar, tanggal dan waktu dari komentar tersebut dibuat, dll. Selain itu, DataFrame "fifth_video_debate_df" memiliki 10 kolom yang diantaranya adalah kolom "video_id", "channel_id", "comment_id", "author", "text_comment", "like_count", "total_reply", "channel_url", "published_date" dan terakhir adalah kolom "updated_date".
#
# 3. Masing-masing kolom yang ada di dalam DataFrame "fifth_video_debate_df" tidak memiliki nilai NaN (Not a Number) atau nilai yang hilang/missing value sehingga dapat disimpulkan bahwasanya sepuluh kolom yang ada di dalam variabel DataFrame "fifth_video_debate_df", setiap barisnya memiliki seluruh elemen nilai data yang didapatkan melalui hasil proses scraping komentar pada video YouTube yang ditayangkan oleh channel YouTube KPU RI.
#
# 4. Pada variabel DataFrame "fifth_video_debate_df" terdapat 3 jenis tipe data yang berbeda. Tipe data yang pertama adalah tipe data Integer untuk setiap kolom yang memiliki nilai data bersifat yang angka atau numerik. Data numerik/data angka dibedakan menjadi 2 jenis bilangan angka yaitu bilangan bulat dan bilangan desimal. Angka bilangan bulat direpresentasikan sebagai tipe data Integer dan angka bilangan desimal direpresentasikan sebagai tipe data Float. Karena pada DataFrame "third_video_debate_df" hanya memiliki 2 kolom saja yang bertipe data Integer, yaitu kolom "like_count" dan "total_reply", di mana kedua kolom tersebut memiliki nilai angka bilangan bulat, maka kolom tersebut bertipe data Integer bukan Float. Tipe data yang kedua adalah tipe data Datetime dan hanya 2 kolom saja yang memiliki tipe data Datetime yaitu kolom "published_date" dan "updated_date". Tipe data yang ketiga yang dimiliki oleh variabel DataFrame "third_video_debate_df" adalah tipe data Object/String. tipe data Object/String adalah representasi dari nilai-nilai data teks, simbol-simbol maupun karakter spesial yang dimiliki oleh suatu kolom di dalam DataFrame. Secara jumlah, tipe data Object/String pada variabel DataFrame "third_video_debate_df" dimiliki oleh 6 kolom (terbanyak diantara tipe data Integer ataupun Datetime) yaitu kolom "video_id", "channel_id", "comment_id", "author", "text_comment" dan kolom "channel_url".

# %%
"""
Mengubah urutan data yang dimiliki oleh variabel DataFrame "fifth_video_debate_df" berdasarkan jumlah total like
terbanyak hingga jumlah like paling sedikit yang didapatkan/diterima oleh suatu teks komentar utama
diantara 1.800 data komentar yang ada di dalam video debat babak kelima capres-cawapres Indonesia di channel YouTube KPU RI
"""
fifth_video_debate_df = fifth_video_debate_df.sort_values(by=["like_count"],
                                                          ascending = False, ignore_index = True)


"""
Menampilkan 10 data teratas dari DataFrame "fifth_video_debate_df" yang memiliki
jumlah total like komentar utama terbanyak hingga total like paling sedikit yang dimiliki oleh teks komentar (Descending)
"""
fifth_video_debate_df.head(10)
# Out:
#       video_id                channel_id                  comment_id  \
# 0  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugz8GZ3Lfw7X9kYnqSV4AaABAg
# 1  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgwOYSRHpyihNxbUL_l4AaABAg
# 2  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgzE0Z69Qxhmo7W7rG54AaABAg
# 3  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgzZITGXd0oboGAaMEp4AaABAg
# 4  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugz2mQvTxHONMD982514AaABAg
# 5  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgwHox027DBKmVb_9e54AaABAg
# 6  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugx8Uk2IjomoD16znX94AaABAg
# 7  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  Ugy-S-3oeLCUjmfVhUt4AaABAg
# 8  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgyrHNJc5P3tu7NFebd4AaABAg
# 9  8J66JxvmEzo  UCVdSz86o9q2cQKvAQ5QhOYg  UgzO353BZYwH1CngstB4AaABAg
#
#                  author                                       text_comment  \
# 0    @anisluthfiani9056  Abah terimakasih sudah mewarnai demokrasi ini ...
# 1       @sodrishandy545  Semoga Allah hadirkan pemimpin yang adil bagi ...
# 2          @robinong153  Terus terang..debat hari ini lebih berkualitas...
# 3          @bintang4783  Kmi berharap yg paling dalam, KPU dan bawaslu ...
# 4        @misyebima8609  Ya Allah menyentuh banget penyampaian terakhir...
# 5              @sxn1707  AMIN sak jossse gak ada keraguan lagi...Bismillah
# 6      @Nurwahida_Ahmad  Abah, kami optimis tapi ditangan Allah semua k...
# 7   @nurulmutmainna1914  Abahhh apapun hasilnya nanti kami bangga pada ...
# 8  @maslahatilummah2043  Saya menjadi saksi di debat pertama hingga ter...
# 9     @muhammadsamir510  JakLinko,Transjakarta,Street Complete,Trotoar,...
#
#    like_count  total_reply                                  channel_url  \
# 0         885          227    http://www.youtube.com/@anisluthfiani9056
# 1         376           10       http://www.youtube.com/@sodrishandy545
# 2         326           20          http://www.youtube.com/@robinong153
# 3         274           16          http://www.youtube.com/@bintang4783
# 4         271           26        http://www.youtube.com/@misyebima8609
# 5         271           22              http://www.youtube.com/@sxn1707
# 6         260           22      http://www.youtube.com/@Nurwahida_Ahmad
# 7         233           32   http://www.youtube.com/@nurulmutmainna1914
# 8         187           10  http://www.youtube.com/@maslahatilummah2043
# 9         183           30     http://www.youtube.com/@muhammadsamir510
#
#        published_date        updated_date
# 0 2024-02-04 16:12:53 2024-02-04 16:12:53
# 1 2024-02-04 15:27:34 2024-02-04 15:27:34
# 2 2024-02-04 16:34:43 2024-02-04 16:34:43
# 3 2024-02-04 17:17:52 2024-02-04 17:43:07
# 4 2024-02-05 05:14:30 2024-02-05 05:14:30
# 5 2024-02-04 16:11:05 2024-02-04 16:11:05
# 6 2024-02-04 15:51:08 2024-02-04 15:51:08
# 7 2024-02-04 15:11:35 2024-02-04 15:11:35
# 8 2024-02-04 17:55:15 2024-02-04 17:55:15
# 9 2024-02-04 15:47:40 2024-02-04 15:47:40

# %% [markdown]
# ## 5. Export Variable DataFrame into Spreadsheet Format (Microsoft Excel)

# %%
"""
Menyimpan 1.800 data hasil scraping video komentar dari media sosial YouTube
tentang video debat capres-cawapres Republik Indonesia tahun 2024 babak kelima yang ditayangkan oleh channel YouTube KPU RI
dengan bantuan API Key yang didapatkan dari CREDENTIALS pada service Google Cloud Platform Console yaitu YouTube Data API v3
"""
fifth_video_debate_df.to_excel("Results of Data Exports from DataFrame/Export Comments Data from 5th Video Debate.xlsx",
                                index = False, header = True)

# %% [markdown]
# Berdasarkan hasil code script diatas maka dapat diketahui bahwa saya telah berhasil melakukan proses penyimpanan (export) 1.800 data komentar yang sebelumnya berhasil di-scraping (diambil) dari video debat capres-cawapres babak keempat yang di-upload oleh Channel Youtube KPU RI dan seluruh data beserta kolomnya disimpan di dalam variabel DataFrame yang bernama "fifth_video_debate_df" ke dalam extension file yaitu Microsoft Excel yang memiliki format/jenis data yaitu Spreadsheet (.xlsx).
