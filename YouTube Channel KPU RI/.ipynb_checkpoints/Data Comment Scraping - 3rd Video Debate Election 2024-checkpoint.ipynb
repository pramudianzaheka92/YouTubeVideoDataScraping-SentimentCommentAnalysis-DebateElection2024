# %% [markdown]
# ## 1. Import Libraries for Scraping Data YouTube Comments and Create API based on Google YouTube Data API

# %%
"""
Melakukan proses import library pandas untuk membuat data-data komentar dari hasil web scraping menjadi DataFrame
serta juga meng-import library khusus yang dimiliki oleh Google API Client agar dapat mengambil informasi/data dari
video komentar debat capres-cawapres babak ketiga dari channel YouTube KPU RI menggunakan API yang akan didapatkan dari
salah satu service pada Google Cloud Platform yaitu YouTube Data API v3
"""
import pandas as pd
from googleapiclient.discovery import build

# %%
"""
Mendefinisikan resource utama/sumber daya dari Google API Client seperti nama layanan atas API yang digunakan,
kode API dan tipe versi pada nama service yang digunakan sehingga dengan resource tersebut,
Google API dapat melakukan proses pengambilan (scraping) data/informasi pada serangkaian
komentar utama (bukan teks komentar yang bersifat balasan/reply dari suatu komentar) yang ada di dalam video debat
capres-cawapres babak ketiga Republik Indonesia tahun 2024 yang di-upload oleh channel YouTube KPU RI menggunakan
API yang telah berhasil dibuat dan didapatkan dari CREDENTIALS YouTube Data API v3 yang ada di dalam Google Cloud Platform
"""

API_Service_Name = "youtube" # Merupakan nama service yang digunakan untuk generate kode API
API_Version_Name = "v3" # Merupakan jenis/tipe versi dari nama service dalam menghasilkan kode API (YouTube Data API v3)
API_Key = "AIzaSyCTEBkjSYN0dPHA95Oipoks9A9b8aIOZb8" # Meng-copy kode API dari CREDENTIALS pada YouTube Data API v3


"""
Menyimpan 3 variabel yang menyimpan resource utama dari Google API Client yang sebelumnya
telah didefinisikan seperti nama service API (API_Version_Name), versi API Youtube yang digunakan (API_Version_Name)
serta kunci/kode API (API_Key) yang telah dibuat dan didapatkan melalui CREDENTIALS
YouTube Data API v3 yang ada di dalam Google Cloud Platform Console yaitu 
dan disimpan di dalam variabel bernama "youtube_scrape_comment_objects"
"""
youtube_scrape_comment_objects = build(API_Service_Name, API_Version_Name, developerKey = API_Key)

# %% [markdown]
# Code script diatas merupakan proses inisialisasi API Key yang telah berhasil didapatkan melalui Google Cloud Platform dengan pilihan service yakni YouTube Data API v3. Maka dari itu nama service API yang digunakan (API_Service_Name) ditulis sebagai "youtube" karena service/layanan Google pada Google Cloud Platform yang digunakan di dalam penelitian kali ini adalah sebuah video yang ter-upload pada media sosial YouTube dan versi API yang digunakan adalah versi ketiga dari API YouTube Data sehingga nilai dari variabel API_Version_Name yang disimpan adalah "v3".
#
# Selain itu, untuk mendapatkan kunci API dari layanan yang bernama "youtube", pertama-tama saya harus masuk ke dalam service YouTube Data API v3 di dalam Google Cloud Platform dan mengaktifkan (enable) service tersebut dan memilih fitur/opsi CREDENTIALS karena API Key berada di dalam fitur tersebut. Jadi dapat disimpulkan kalau untuk membuat API Key agar dapat mengambil data-data yang ada di dalam suatu video YouTube seperti komentar dari 1 video YouTube, Playlist, Subscription, dll., maka terlebih dahulu harus mengaktifkan service YouTube Data API v3 di dalam Google Cloud Platform dan kemudian membuat/generate API Key di dalam opsi CREDENTIALS. Jika API sudah berhasil dibuat, maka kita dapat meng-copy API tersebut untuk diletakkan di dalam variabel. Pada code script diatas, API yang berhasil didapatkan disimpan di dalam variabel yang bernama "API_KEY".
#
# Di samping itu, fungsi build pada library googleapiclient.discovery merupakan sebuah Software Development Kits (SDKs) yang telah disediakan oleh Google agar para developer/scientist dapat mengakses semua layanan berbasis Google melalui API seperti video/konten YouTube, BigQuery, dll. Jadi dapat disimpulkan bahwasanya dengan mendefinisikan nama layanan Google yang akan digunakan dan API yang telah didapatkan berdasarkan layanan yang akan digunakan, maka setiap orang diseluruh dunia dapat mengakses dan mendapatkan data-data atau informasi dunia melalui layanan Google. Seperti pada penelitian kali ini yang sumber datanya merupakan data-data komentar dari video debat babak ketiga capres-cawapres yang di-upload oleh channel KPU RI yang ada di dalam media sosial YouTube.

# %% [markdown]
# ## 2. Request Access to Retrieve Main Comments Data Objects on YouTube Video based on API Key, API Service Name, and API Version

# %%
"""
Melakukan proses permintaan kepada Google Client dengan menggunakan API yang sudah
di=generate oleh CREDENTIALS dan disimpan di dalam variabel "youtube_scrape_comment_objects"
(bersamaan dengan nama service dan jenis versi dari service yang digunakan)
untuk dapat mengambil 100 data/informasi (sesuai jumlah batasan/limit data komentar yang dapat
diambil dari komentar pada konten video YouTube menggunakan API dari Google Client) pada serangkaian komentar utama
tentang debat capres-cawapres babak ketiga Republik Indonesia tahun 2024 yang di-upload oleh
channel YouTube KPU RI berdasarkan dari ID yang dimiliki oleh video tersebut
"""

video_youtube_data_request = youtube_scrape_comment_objects.commentThreads().list(
    part = "snippet", # snippet pada parameter part adalah objek list dari seluruh elemen yang dimiliki oleh komentar utama
    videoId = "KJdt-HBBGIo", # Merupakan ID dari video debat babak ketiga capres-cawapres yang di-upload oleh channel KPU RI 
    maxResults = 100, # Jumlah informasi komentar yang akan terambil dari video debat ketiga namun 100 data adalah batasannya
    order = "time", # Nilai time pada parameter order adalah urutan tanggal dan waktu terbaru hingga terlama dari komentar
)


"""
Menjalankan proses permintaan untuk mendapatkan seluruh elemen/objek dari 100 rangkaian komentar
paling terbaru hingga terlama dari video ID yaitu KJdt-HBBGIo yang merupakan ID video dari debat
capres-cawapres babak ketiga yang di-upload oleh YouTube channel KPU RI yyang telah dibuat dan disimpan
pada variabel "video_youtube_data_request"
"""
video_youtube_data_response = video_youtube_data_request.execute()

# %% [markdown]
# Berikut adalah penjelasan mengenai code script diatas berikut ini:
#
# 1. youtube_scrape_comment_objects merupakan sebuah nama variabel yang berisikan parameter-parameter beserta nilainya yang berfungsi sebagai tempat menyimpan resource utama Google Client serta API dari YouTube untuk dapat mengakses data-data dan informasi yang dimiliki oleh suatu konten video YouTube seperti informasi video, komentar di dalam suatu video, playlist dari suatu channel, dll, dengan memanfaatkan kode API (API KEY) yang didapatkan melalui Google Cloud Platform dengan cara membuat credentials API di dalam salah satu service Google Cloud Platform yaitu YouTube Data API v3.
#
# 2. commentThreads merupakan suatu sumber daya dari YouTube Data API yang berisikan objek/elemen atas informasi-informasi dari komentar utama (teks komentar yang bukan menjadi komentar balasan) dari suatu video di YouTube. Salah satu contoh informasi yang terdapat di dalam komentar utama adalah teks komentar yang dibuat oleh user/penonton dari video tersebut bukan teks komentar yang menanggapi/merespon komentar utama. Atau identitas nama user/akun YouTube yang berkomentar di video tersebut sebagai bentuk pendapat atas video yang ditonton.
#
# 3. Parameter "part" bertujuan untuk mendapatkan banyak objek list properti yang dipisahkan oleh tanda koma (comma-separated list) dari sumber daya yang dimiliki oleh service YouTube Data API v3 yang membentuk komentar paling utama (komentar teratas) dari suatu video. Sedangkan "snippet" pada parameter "part" bertujuan untuk mendapatkan objek detail dasar tentang elemen-elemen/item dari komentar utama sebagai bentuk respon API YouTube terhadap permintaan dalam mengambil objek-objek data dari sebuah konten video berdasarkan video id yang didefinisikan pada parameter "videoId". Salah satu contoh detail dasar dari komentar utama seperti channel id sebagai identitas unik dari suatu channel yang ada di media sosial YouTube.
#
# 4. Parameter videoId merupakan sebuah identitas unik dari video (ID dari suatu konten video YouTube) yang informasi dasarnya ingin diambil (data scraping) untuk kebutuhan yang berbeda-beda. Sebagai contohnya pada penelitian kali ini, saya ingin menggunakan video tentang debat babak ketiga capres-cawapres Republik Indonesia tahun 2024 dari channel YouTube KPU RI dan video tersebut memiliki alamat URL yakni https://www.youtube.com/watch?v=KJdt-HBBGIo. Jadi ID video "KJdt-HBBGIo" diambil dari URL pada video tersebut yang letaknya setelah v=.
#
# 2. Parameter maxResult merupakan sebuah parameter yang secara spesifik bertujuan untuk mengambil jumlah kuantitas dari data/informasi komentar utama yang ingin diambil dari suatu konten video di media sosial YouTube berdasarkan ID unik yang didefinisikan pada parameter videoId. Tetapi kuantitas jumlah data/informasi komentar yang dapat diambil menggunakan API dari service Google Client hanya 100 data saja, tidak bisa lebih dari 100 data. Sehingga karena penelitian kali ini akan mengambil lebih dari 100 data, maka diperlukan tahapan/teknik pengulangan supaya data komentar yang terambil dapat melebihi 100 data. Tahapan untuk mengambil data lebih dari 100 data akan dilakukan setelah berhasil mendapatkan 100 data komentar (berdasarkan jumlah maksimal data komentar yang dapat diambil menggunakan API Google YouTube v3).
#
# 4. Parameter order merupakan sebuah parameter yang dimiliki oleh fungsi commentThreads() yang bertujuan untuk menentukan urutan data komentar yang ingin diambil (di-scraping) sebagai permintaan/request dari Google API Client terhadap komentar yang dimiliki oleh konten-konten video yang berada di media sosial YouTube. Konten video tersebut ditentukan oleh video ID yang dimiliki oleh parameter videoId. Parameter order memiliki 2 nilai yang valid yaitu time dan relevance. Jika nilai dari parameter order adalah time, maka urutan data komentar yang diambil akan terdiri dari komentar-komentar yang paling baru dibuat pada video tersebut berdasarkan tanggal dan waktu dari setiap teks komentar. Sebagai contoh jika terdapat teks komentar pada suatu konten video YouTube yang ditulis seperti "Indonesia, Malaysia, Filipina, Singapura, Thailand merupakan 5 Negara pendiri ASEAN" dibuat di tanggal 2 Mei 2024 dan teks komentar lainnya adalah "Belanda, Jerman, Inggris, Denmark merupakan salah 4 dari Negara dari Benua Eropa" dibuat di tanggal 19 Mei tahun 2024, maka urutan data teks komentar yang tersimpan lebih dulu yang berada paling atas dari urutan data adalah teks komentar yang ditulis seperti "Belanda, Jerman, Inggris, Denmark merupakan salah 4 dari Negara dari Benua Eropa" dan selanjutnya yaitu teks komentar yakni "Indonesia, Malaysia, Filipina, Singapura, Thailand merupakan 5 Negara pendiri ASEAN". Jadi pada dasarnya nilai time di dalam parameter order akan mengurutkan rangkaian komentar utama dari suatu konten video di media sosial YouTube (berdasarkan video id) berdasarkan tingkat paling terbaru hingga paling terlama atas tanggal dan waktu dari komentar tersebut dibuat oleh penonton dari video tersebut.

# %%
"""
Menampilkan seluruh objek serta elemen yang dimiliki oleh 100 rangkaian komentar utama
(teks komentar yang bukan merupakan balasan/reply dari suatu komentar) dari video debat babak ketiga
capres-cawapres yang ditayangkan oleh channel YouTube KPU RI yang berhasil di-scraping
menggunakan API Key dari service Google Cloud Console yaitu YouTube Data API v3
"""
video_youtube_data_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'bg30pwoRpKH3zkSkdbn1NIjWZgs',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpSUlCZ0FFZ1VJaVNBWUFCSUZDS2dnR0FBU0JRaWRJQmdCR0FBaURRb0xDTkxhX3EwR0VORDBvVXM=',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Py6SmsP8fG0gaYjH8KqNfNNx5sM',
#    'id': 'UgxqDT9AVoxMThVBINF4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DhLasynAqElMUjUyZ4I1UnODQ9M',
#      'id': 'UgxqDT9AVoxMThVBINF4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=KJdt-HBBGIo&amp;t=1754">29:14</a>',
#       'textOriginal': '29:14',
#       'authorDisplayName': '@user-iq6yq1gt3w',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_najrNirkES91uW9O1x7uafNumbXLKuwgH-mLyamJqgfhwuBIDWRZGGBzH6fCNh-gOl0g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-iq6yq1gt3w',
#       'authorChannelId': {'value': 'UCd5dwZ8WO6x__bJpTOXgGgA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-05-02T02:23:01Z',
#       'updatedAt': '2024-05-02T02:23:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'cmQLuBoq58gnBs3LMy0P8qpU5Lk',
#    'id': 'UgzwTwjhMpSHtW-pZUp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'INSNlAQoIcKYIx4640GUfIUNYrs',
#      'id': 'UgzwTwjhMpSHtW-pZUp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Mantap',
#       'textOriginal': 'Mantap',
#       'authorDisplayName': '@smpteladanp.siantar6962',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_naVtQgGqLR2mEJBYsUptJWeahbG_5vnBCPaDOqBcwUdRBL6bJjSCLq-kGRbS6uIBwmZQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@smpteladanp.siantar6962',
#       'authorChannelId': {'value': 'UC23IV1tKMgo8VI4qnbi8Y5g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-10T01:44:13Z',
#       'updatedAt': '2024-04-10T01:44:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LMkBNx_U91ob6_3CNFrrEcRAnRc',
#    'id': 'UgwZ6efr3JiJmlhxf6h4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AlhXuJXqPIbhLZbHbtlBqQkb_JM',
#      'id': 'UgwZ6efr3JiJmlhxf6h4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'POKOKNYA ALL IN PRABOWO-GIBRAN ❤️❤️',
#       'textOriginal': 'POKOKNYA ALL IN PRABOWO-GIBRAN ❤️❤️',
#       'authorDisplayName': '@NamuDandelion',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nfsRMcdQ-VFoiGqSem9tOD6dD-rK6_7_L87-oT8m-LZ9_Zz1QPLPwPCuXy3MEW6JluRA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@NamuDandelion',
#       'authorChannelId': {'value': 'UC4Ju4sHLT-VdL4Bu1oQIYEA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-04T09:37:48Z',
#       'updatedAt': '2024-04-04T09:37:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'FLKV9YoJEt9IvoORvZQ4fgi1mFk',
#    'id': 'Ugxms8s8tQZqDD-UcOJ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '7aXiv4EQVpvBfeyN-PT_cuwh_xY',
#      'id': 'Ugxms8s8tQZqDD-UcOJ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'pemilu',
#       'textOriginal': 'pemilu',
#       'authorDisplayName': '@bendoro8428',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/l-N5fxn3yaZDQyb6S4C3FvIDJi_tWiPwIVMtwHxuG0yonxoB10GMxzDjRla_c02Gy7ixtr2iowY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@bendoro8428',
#       'authorChannelId': {'value': 'UCLCZyv_jh_n-sWU7zSXjoAg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-20T00:13:07Z',
#       'updatedAt': '2024-03-20T00:13:07Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'SpaYwVX2seZqxs33oYhgNt3avQk',
#    'id': 'Ugwq_LTsM7t9QTbK_Ft4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6k02-3oeNHl--yPYGH7YpfjLpyg',
#      'id': 'Ugwq_LTsM7t9QTbK_Ft4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Ketiga',
#       'textOriginal': 'Ketiga',
#       'authorDisplayName': '@user-ut5gc2zk3w',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lAnWXoQXSpNvvE_AcXpQWRgZhKkSFf1lxmhyOMabzmig_ZscSfbTZuInp2bg4XYctXVg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-ut5gc2zk3w',
#       'authorChannelId': {'value': 'UCRPtn3QLyPnHleffY-4-D4g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-12T22:12:07Z',
#       'updatedAt': '2024-03-12T22:12:07Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '6tBPBZVKPJFT2sGJKIu3lwki5V8',
#    'id': 'UgyJhQw2cqCtx4gtl594AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QilRpL0yjFrTV96Pmw1U_TOUZKI',
#      'id': 'UgyJhQw2cqCtx4gtl594AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'PANDUAN ENDAZMUNEGTONGKECUAN  UDELETEA BOOLONGTONGSAYUR NORACK KALAPMODDARATTAIWAN ABUD TAU U YEAA.4JJ1.',
#       'textOriginal': 'PANDUAN ENDAZMUNEGTONGKECUAN  UDELETEA BOOLONGTONGSAYUR NORACK KALAPMODDARATTAIWAN ABUD TAU U YEAA.4JJ1.',
#       'authorDisplayName': '@keliksetyawanmahatmanto7727',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/L2t9qz7gFWMDJ5z2snj9EslFnmAlXEU7tj97TGQHgqDFuZm7XOjf7k7z6XHrywaK1Xbq_ao2NA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@keliksetyawanmahatmanto7727',
#       'authorChannelId': {'value': 'UCwR7u64sgKSvKcKJSpAOzrw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-03-05T16:11:57Z',
#       'updatedAt': '2024-03-05T16:13:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'p0TIkKjU0vpebnjaaFC0kbHYhzA',
#    'id': 'UgyRZSI9XGW9oQHToBx4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SH768hyffnse_aQniO06yGkJ1dM',
#      'id': 'UgyRZSI9XGW9oQHToBx4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Yg tersakiti akhirnya pak Prabowo jadi presiden 🤣🤣🤣',
#       'textOriginal': 'Yg tersakiti akhirnya pak Prabowo jadi presiden 🤣🤣🤣',
#       'authorDisplayName': '@donidi374',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k6x9us74dBPZm4VN3C0csjjilqY6FZUlfJvEhaOEI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@donidi374',
#       'authorChannelId': {'value': 'UCgeXw8RrTLExFi9wH89ajTw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-03-01T07:25:33Z',
#       'updatedAt': '2024-03-01T07:25:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'DUVp7Fr7RUIUhF4paOP1rdMW7jY',
#    'id': 'UgykSiZ9b_F5kxVv3Ll4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'I6_1XcdmvJe5PYU33zyiHAkXewk',
#      'id': 'UgykSiZ9b_F5kxVv3Ll4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Di luar daerah jawa   ...banser keok.........ayam sayur...',
#       'textOriginal': 'Di luar daerah jawa   ...banser keok.........ayam sayur...',
#       'authorDisplayName': '@OppoAs-oc7rp',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kSOSw8iK5KNX5qEo7ZPQGu0hwOYdlahLtobe68OKo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@OppoAs-oc7rp',
#       'authorChannelId': {'value': 'UCZyLs6XpkcssY3EmO_jxJAg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-03-01T03:58:51Z',
#       'updatedAt': '2024-03-01T03:58:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zEjhURAs5lzkWDP7pV8R_FnEUU4',
#    'id': 'UgyXfp8k4wNy2qKS9xZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YlLPW-5p9lGTBdjUYpFG6GrJMjc',
#      'id': 'UgyXfp8k4wNy2qKS9xZ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'sumpah muka Anies ngeselin disini',
#       'textOriginal': 'sumpah muka Anies ngeselin disini',
#       'authorDisplayName': '@rifaldihidayat5884',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lTsn_SEf4XL2vXIaaoqLUud5NQ9oq-8qVva6nli6qHfYKIw450e_k2BCXQMQ4EGZfOvw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@rifaldihidayat5884',
#       'authorChannelId': {'value': 'UCPpxFqeiBc4gNJxq_4RDafg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-26T20:31:26Z',
#       'updatedAt': '2024-02-26T20:31:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ArF3PqoVMQaW1WuOtZr6TnDs6-o',
#    'id': 'Ugw4-2fnmmNISHYJvK54AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EortLK264E7DmnPEdAwRnAU7Hgw',
#      'id': 'Ugw4-2fnmmNISHYJvK54AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Hidup Hercules.. jawaban yg CERDAS ❤',
#       'textOriginal': 'Hidup Hercules.. jawaban yg CERDAS ❤',
#       'authorDisplayName': '@IlhamsamosirIlham-gf8ir',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/xTTHHdF0_f1elA_W-ozXEkUMKA6TgzpWGI2bRyod3HV75VfyOlORXU7XujQvWbABJ5aiV8-FiA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@IlhamsamosirIlham-gf8ir',
#       'authorChannelId': {'value': 'UCNIauEVBUpRTHpW4YFYGcaw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-25T18:54:32Z',
#       'updatedAt': '2024-02-25T18:54:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'DNgwASEX5LQXBzyX_BwBcQzWbHc',
#    'id': 'Ugxh7tFOUgjgMiHOv7V4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'STykNQq8pfIVJStt6872-s8HT7g',
#      'id': 'Ugxh7tFOUgjgMiHOv7V4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Kompak serang pak prabowo , nyatanyaaa pak prabowo menang 58%❤❤',
#       'textOriginal': 'Kompak serang pak prabowo , nyatanyaaa pak prabowo menang 58%❤❤',
#       'authorDisplayName': '@user-sj7cs7zv7s',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n68ziQLwlP2zE2AoW58ea3RWol98GNssqM9F9i2ODfKsPj4j3sBfuxm6Wo8-ppOXb3Jw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-sj7cs7zv7s',
#       'authorChannelId': {'value': 'UCiwcOmOqSu0rajarrGfMoZg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-25T18:36:30Z',
#       'updatedAt': '2024-02-25T18:36:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MwzJA34DEmC2Dv_FGyVB0yx3MJ4',
#    'id': 'UgwvIPQ1En5ufD4KYdl4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8lvnlY2-Cee0-vSdrK390Agl6fM',
#      'id': 'UgwvIPQ1En5ufD4KYdl4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'SUDAH 10 TAHUN GAK ADA LOWONGAN KERJA. YANG ADA LOWONGAN KERJA BUAT PEKERJA ASING. MALAM ADA YANG CARIKAN KERJA BUAT ANAKNYA. LEBIH MEMENTINGKAN DIRINYA DARI PADA RAKYATNYA. BUKAN KAH DIA DITUGASKAN UNTUK MENSEJAHTERAKAN RAKYATNYA.',
#       'textOriginal': 'SUDAH 10 TAHUN GAK ADA LOWONGAN KERJA. YANG ADA LOWONGAN KERJA BUAT PEKERJA ASING. MALAM ADA YANG CARIKAN KERJA BUAT ANAKNYA. LEBIH MEMENTINGKAN DIRINYA DARI PADA RAKYATNYA. BUKAN KAH DIA DITUGASKAN UNTUK MENSEJAHTERAKAN RAKYATNYA.',
#       'authorDisplayName': '@Odamjaya',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_loarI9cC0bgeXggsGjZm3460SKNpYd2tKbBFTPasLpa9m2VxD7XOPyyxiaGLm6MxSzWg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Odamjaya',
#       'authorChannelId': {'value': 'UCsVAuaJlpHryZsqVDbI4pDA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-23T23:45:13Z',
#       'updatedAt': '2024-02-23T23:45:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_lTv4_5Ir4CxUO57LDIanVT_gT4',
#    'id': 'UgwwRLUxCz_vr3QP9P94AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '1-sQ9E19chjZUu5iSbK0cZ6NPyo',
#      'id': 'UgwwRLUxCz_vr3QP9P94AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'B😊',
#       'textOriginal': 'B😊',
#       'authorDisplayName': '@charlessiagian8411',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mIRvbatgIhbSb6ZPk6xf1RseE2OnVQNGPxb1aMKCHiARw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@charlessiagian8411',
#       'authorChannelId': {'value': 'UCosv3efqBUe_JfuM12Ppw6A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-22T19:47:06Z',
#       'updatedAt': '2024-02-22T19:47:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ila3ki2vX6nahRzjDimkTiIuoxU',
#    'id': 'UgzVskBVqNCRlb7GKhl4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Kt9TDGSDr2mTIbwQFmcgoSPV6VU',
#      'id': 'UgzVskBVqNCRlb7GKhl4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Indonesiaku akan hebat pada saatnya',
#       'textOriginal': 'Indonesiaku akan hebat pada saatnya',
#       'authorDisplayName': '@basukibasukiimannugroho3155',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m2g__-AwGH6u1SreUmeLJsbDUdg8YZ10Q5tzJdqWSe_Y4L-l6LGvHa66Ro1s_bmfGeFw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@basukibasukiimannugroho3155',
#       'authorChannelId': {'value': 'UC2A-idocy01ewEp7Gt4AdhQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-22T17:00:39Z',
#       'updatedAt': '2024-02-22T17:00:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PNd5kDU9Kt6gz5LIMKDoX-nNm3Y',
#    'id': 'Ugxju6nGquT2Gpa_Url4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'yBFvC3_CHX8sPSJW-J34PzFIKR0',
#      'id': 'Ugxju6nGquT2Gpa_Url4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Joss lek😂',
#       'textOriginal': 'Joss lek😂',
#       'authorDisplayName': '@user-sz4jr4qz2b',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kVt-2KnstlTCEKQNERtFu1r0nkoGfCbDaBeHqzzAeOW6FjInY1ji4XDCDXS_eKGhY0Pw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-sz4jr4qz2b',
#       'authorChannelId': {'value': 'UCOU9K7T-jIiw8Ah_FPjzXhg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-21T23:10:50Z',
#       'updatedAt': '2024-02-21T23:10:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4-YZmNMqQMicgySa4oYjY6K26nw',
#    'id': 'UgzYdf3uq2BexpEijvh4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gx0IX0lfGzgc7AmNbcpEOWSuxBo',
#      'id': 'UgzYdf3uq2BexpEijvh4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Terus gimana nih ... Tuh banyak aduan beda perolehan suara, antara C1 sama yg di scan kok beda ? ...... Hanya minta maaf aja ya ?',
#       'textOriginal': 'Terus gimana nih ... Tuh banyak aduan beda perolehan suara, antara C1 sama yg di scan kok beda ? ...... Hanya minta maaf aja ya ?',
#       'authorDisplayName': '@hengkyyp4238',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nNUS12TiT9mwsOpaIxKeClN48qhQychIp7RPQDu3iVZAU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@hengkyyp4238',
#       'authorChannelId': {'value': 'UCkHV-8UuTTTUNceSTVIsZ6A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-19T03:19:40Z',
#       'updatedAt': '2024-02-19T03:19:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'q45xbZRcU3IEeNFpvLAo1ZJ-dno',
#    'id': 'Ugz7BUvxV5k_8jrlb6t4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 's4CuhbN-hszqDY5WnMjdqAVkiEo',
#      'id': 'Ugz7BUvxV5k_8jrlb6t4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Sembako mahal, bers mahal pajak bejibun naik lagi, cari duit sendiri cari kerja susah.intinya usaha sendiri beribadah sampai mati selesai nih hidup.',
#       'textOriginal': 'Sembako mahal, bers mahal pajak bejibun naik lagi, cari duit sendiri cari kerja susah.intinya usaha sendiri beribadah sampai mati selesai nih hidup.',
#       'authorDisplayName': '@cepihhidayat6994',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nCRuLC9_EoufcjUint-SuwkFn9nNmkHvFibzok2DU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@cepihhidayat6994',
#       'authorChannelId': {'value': 'UC8pydNBiCn17QBbDWDpxmaw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-18T06:52:42Z',
#       'updatedAt': '2024-02-18T06:52:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MHKWIjtAIeT-9zeJQJlvGPdEstE',
#    'id': 'UgzAteDqK0R1oljVsnd4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'jhzrkeBO7jM5FpowyYQlZ0HlU6c',
#      'id': 'UgzAteDqK0R1oljVsnd4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Rakyat hanya dijadikan kendaraan politik, begitu diantar menuju tempat singgasana, kendaraan itu dilupakan tidak diservice, tidak dirawat setelah 5 tahun kendaraan itu dijual belikan.',
#       'textOriginal': 'Rakyat hanya dijadikan kendaraan politik, begitu diantar menuju tempat singgasana, kendaraan itu dilupakan tidak diservice, tidak dirawat setelah 5 tahun kendaraan itu dijual belikan.',
#       'authorDisplayName': '@cepihhidayat6994',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nCRuLC9_EoufcjUint-SuwkFn9nNmkHvFibzok2DU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@cepihhidayat6994',
#       'authorChannelId': {'value': 'UC8pydNBiCn17QBbDWDpxmaw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-18T06:50:46Z',
#       'updatedAt': '2024-02-18T06:50:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Cd1AnSiXEGbcl_GEhNiJW6pwjrw',
#    'id': 'UgyqFL-MDSXGWcv6IsN4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'B74n6E0_t1Gug8hM5SkR8uyJFl4',
#      'id': 'UgyqFL-MDSXGWcv6IsN4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'SI REKAP APLIKASI YG SANGAT BANGSAD...  YG CIPTAIN ALPIKASI PASTI ANAK HARAM<br><br><br>.BANGSAT EMANG',
#       'textOriginal': 'SI REKAP APLIKASI YG SANGAT BANGSAD...  YG CIPTAIN ALPIKASI PASTI ANAK HARAM\n\n\n.BANGSAT EMANG',
#       'authorDisplayName': '@user-vp6kr1ec8x',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n-xdMPt15Uf5d3O0ddOhZZsKb6mCO13rL5bNsX6I6S6p0QPZzd2sV8xLSInXuZri5Maw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-vp6kr1ec8x',
#       'authorChannelId': {'value': 'UCCOWY9cBAvhM3DI07JX0sFg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-17T15:49:39Z',
#       'updatedAt': '2024-02-17T15:49:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'YH5SmwQedAKehOXQF1ZxIcYmTko',
#    'id': 'UgxWIhaPR41LxFDw1WJ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oGCsp2bOj1aRwVCK2HRbINR5egg',
#      'id': 'UgxWIhaPR41LxFDw1WJ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Pantes aja kubu prabowo takut anis jd presiden terutama orng yg di belakangnya ikut mengatur ,yg jelas pasti takut bokbroknya 😂',
#       'textOriginal': 'Pantes aja kubu prabowo takut anis jd presiden terutama orng yg di belakangnya ikut mengatur ,yg jelas pasti takut bokbroknya 😂',
#       'authorDisplayName': '@agusfitriadi1081',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kRksYUtcTjQzqWV4xVp5o6eo4d8mshStprNrQelR0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@agusfitriadi1081',
#       'authorChannelId': {'value': 'UCriURcZuGokPRkiLw-Tfs3g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-16T19:33:45Z',
#       'updatedAt': '2024-02-16T19:33:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jqYiitWdBeq3LR82XKzyojEySvk',
#    'id': 'UgyF-6UDpx9MypDGuzF4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'TXhGZszdi6rbW9npwjhc1nIWRj0',
#      'id': 'UgyF-6UDpx9MypDGuzF4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'siap siap bakalan ada demo besar besaran rakyat indonesia kalau KPU gk jujur 😠😠',
#       'textOriginal': 'siap siap bakalan ada demo besar besaran rakyat indonesia kalau KPU gk jujur 😠😠',
#       'authorDisplayName': '@kimjongpret-uv9gv',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n-6RW7yHnAVJghxO10WjUQZsKvMPGOD7WLkQp8UMcyRafOGcU9XC42RB35QvDCecSw1g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@kimjongpret-uv9gv',
#       'authorChannelId': {'value': 'UCC3e3nyM0ycePX2wfu3hxdA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-16T08:10:17Z',
#       'updatedAt': '2024-02-16T08:10:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'oGBAsis5jykJvV-ugPrAaJf43Vo',
#    'id': 'UgwWlnac-Vunzx1DZcB4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'R4DFOqNDa8o8vZkFcfvbSrLdOzk',
#      'id': 'UgwWlnac-Vunzx1DZcB4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'DILAPANGAN PUN BANYAK KECURANGAN. DI SIREKAP KPU PUN BANYAK MANIPULASI PENGHITUNGAN HASIL SUARA. SEMUA DITUNJUKKAN OLEH VIDEO YANG BERBEDA DI MEDSOS. SEMOGA KPU BISA DITUNTUT',
#       'textOriginal': 'DILAPANGAN PUN BANYAK KECURANGAN. DI SIREKAP KPU PUN BANYAK MANIPULASI PENGHITUNGAN HASIL SUARA. SEMUA DITUNJUKKAN OLEH VIDEO YANG BERBEDA DI MEDSOS. SEMOGA KPU BISA DITUNTUT',
#       'authorDisplayName': '@marahapmin9006',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzOrymcb7hBzg30BQS5zgBDABq_F1yjkbxOcXW_huGDEs=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@marahapmin9006',
#       'authorChannelId': {'value': 'UCwzLQW2q7TESYiG-v8KDhtw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-16T02:58:55Z',
#       'updatedAt': '2024-02-16T02:59:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Yfxmz7lvCtrgJVsPYFe5t-tBuU0',
#    'id': 'UgznfCXI59FC7ef-Lt94AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gRAIWX1A0GKuGFprAvFip0vPzCk',
#      'id': 'UgznfCXI59FC7ef-Lt94AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Ucdb 7dg 7eb uebdssdjjbdsssdudu udbcdiebicevdssogssgkddddddfhhwwoorewsdcfgrfdd',
#       'textOriginal': 'Ucdb 7dg 7eb uebdssdjjbdsssdudu udbcdiebicevdssogssgkddddddfhhwwoorewsdcfgrfdd',
#       'authorDisplayName': '@user-em4bn2cv4g',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lSxERKmuXpC-ZC9j7fDJwYA7IckYaELucXUsk6JqJMNWOrJkgdwEv1hl_g-6nsJoGqnQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-em4bn2cv4g',
#       'authorChannelId': {'value': 'UCiag6TF2bWUjlvYgSi-aJDw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-15T23:20:45Z',
#       'updatedAt': '2024-02-15T23:20:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5KjlW6sm6yGWYmKLDTIfpwgXdGA',
#    'id': 'Ugw_ednHuTlRT1UhgCl4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'y4cJodNKi4Y60Rzgv8Dz23uWXoM',
#      'id': 'Ugw_ednHuTlRT1UhgCl4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Terima kasih PAKDE, PAMAN, MKMK, POLRI,TNI, KPPU, BAWASLU, KEMENTRIAN BUMN,KEMENDAGRI ...telah berhasil mengadakan dan menyelenggarakan PEMILU TAHUN INI menjadi TERBURUK dan TERBUSUK dalam SEJARAH di indonesia ...🇲🇨❤🇲🇨',
#       'textOriginal': 'Terima kasih PAKDE, PAMAN, MKMK, POLRI,TNI, KPPU, BAWASLU, KEMENTRIAN BUMN,KEMENDAGRI ...telah berhasil mengadakan dan menyelenggarakan PEMILU TAHUN INI menjadi TERBURUK dan TERBUSUK dalam SEJARAH di indonesia ...🇲🇨❤🇲🇨',
#       'authorDisplayName': '@koedjangkaroehoen',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/x_o6aGCcGSEXLIM5hXfSNLozMtM0uZLF4nHhEBT4-uGT_NNyvUAAL4_P_Z3OInbyA9fWZ-CiDg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@koedjangkaroehoen',
#       'authorChannelId': {'value': 'UCYp-IO6W-CpMgSD9ttsULbQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-15T22:06:10Z',
#       'updatedAt': '2024-02-15T22:06:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dDzUrMoSgNYb62SxqJJuCerlELU',
#    'id': 'UgzdTK6jatPR4HKRH054AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-I99wXXAFgmZfLVobOLH_RThFow',
#      'id': 'UgzdTK6jatPR4HKRH054AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Ingat wahai KPU MASIH ADA SIKSA KUBUR DAN NERAKA, AZAB allah SAKIT, DUNIA HANYA SEMENTARA... SALAM',
#       'textOriginal': 'Ingat wahai KPU MASIH ADA SIKSA KUBUR DAN NERAKA, AZAB allah SAKIT, DUNIA HANYA SEMENTARA... SALAM',
#       'authorDisplayName': '@japulgentak9848',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mVVexfF1Og58OqVFQqfmKsFMbs3aw6zzpW8RAImrb9hoA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@japulgentak9848',
#       'authorChannelId': {'value': 'UCrT16AR3xbyj_C4TrLsZKOw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-15T11:50:30Z',
#       'updatedAt': '2024-02-15T11:50:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1H0Q9zH-nIdljc49gwip_NSUBBg',
#    'id': 'UgzlzHs74QNBZD3kKgZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4vwdgwKhgoYCEGLMx6uMLG88dmc',
#      'id': 'UgzlzHs74QNBZD3kKgZ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Kpu tolol',
#       'textOriginal': 'Kpu tolol',
#       'authorDisplayName': '@angky.v5535',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Yv5xj24AP60F3wcuIqc3yCUTDMPvozBp13bd9MneG-Wm0OnBIkcUrOlefvGaEOHbtrI-2sVD=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@angky.v5535',
#       'authorChannelId': {'value': 'UCT2bqcCrtciWOy33N1HOL7w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-15T07:01:59Z',
#       'updatedAt': '2024-02-15T07:01:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '45V4kd3Co0CCxzpdZN-HJhOsb7s',
#    'id': 'UgzlbaEMNWcq-gOTTKV4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'WByXgaVQJA4c5gS4-7aYJpkJmsU',
#      'id': 'UgzlbaEMNWcq-gOTTKV4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Hahaha ...memilih utk idonesia hanya slogan ..yg bener memilih utk yg kasih uang dan keluaga jokowi ....hahahaha',
#       'textOriginal': 'Hahaha ...memilih utk idonesia hanya slogan ..yg bener memilih utk yg kasih uang dan keluaga jokowi ....hahahaha',
#       'authorDisplayName': '@iyogorotna4677',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kT4akqT-5s4UcUaj7yTNkapqJKhzadOJtYOJSUseg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@iyogorotna4677',
#       'authorChannelId': {'value': 'UCx8OM5WY9W2__d8WTy5gQ4Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-15T06:13:39Z',
#       'updatedAt': '2024-02-15T06:13:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ygxki5XI30O1vx7pEDk71oIax8Q',
#    'id': 'Ugw-9D2-poTzNA0Dj9h4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mXwxKxIfmcJg5ggxKbCV7Yqqg00',
#      'id': 'Ugw-9D2-poTzNA0Dj9h4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'kpu ngpain kok bisa surat suara bisa habis data masih ada dan saya belum coblos waduh gawat nh kpu.',
#       'textOriginal': 'kpu ngpain kok bisa surat suara bisa habis data masih ada dan saya belum coblos waduh gawat nh kpu.',
#       'authorDisplayName': '@ppssumbangbujurtv',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/aow3D9cIuLvJ_pwfSPuVD30idkbKlvoOcT9tLPSJFcj08zDeY1fqyAqpmzTbC7Ag9usHtIGr=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ppssumbangbujurtv',
#       'authorChannelId': {'value': 'UCTJqJn8EA6BXmtQ4-o108Mg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T06:37:17Z',
#       'updatedAt': '2024-02-14T06:37:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nv9gqSK1LraB2QuepXUixYPDE5E',
#    'id': 'UgwwFJt84lXJMkFj8Pp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8CrB1bESSMSjnP2gd78J6Sjn8fo',
#      'id': 'UgwwFJt84lXJMkFj8Pp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Aku pilih prabowa<br>Indonesia😊',
#       'textOriginal': 'Aku pilih prabowa\nIndonesia😊',
#       'authorDisplayName': '@user-ui8oy2wp3w',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kDVWTVor4oDMnrA8JSn1QfWKy679_pAFdisj868GXmAFhdW5SbK7lG9s-tsd8cKauiOQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-ui8oy2wp3w',
#       'authorChannelId': {'value': 'UCSF6Jf5FD-ogVNzR6wvPUYg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T04:46:24Z',
#       'updatedAt': '2024-02-14T04:46:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A-Jo3HIXfASOtQcV2pc_yR-az9E',
#    'id': 'UgzxPegfH4T-ZlXR6Dl4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'izzTvD7bLOqGAYI9p8PJVVp3Pqs',
#      'id': 'UgzxPegfH4T-ZlXR6Dl4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Prabowo  debssss',
#       'textOriginal': 'Prabowo  debssss',
#       'authorDisplayName': '@nopetnopet6900',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_np9uDZXx8zYBh---5HbGBThUBZz__GXdFwLomwTx-ufss=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@nopetnopet6900',
#       'authorChannelId': {'value': 'UC12Tac4Pb-C3VSGxf36d84A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T04:43:42Z',
#       'updatedAt': '2024-02-14T04:43:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JjxqpMpHhtDK0Ze2o3RZnB29B40',
#    'id': 'UgxWFrzV3bMP0Q8WlLx4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2yvRrE5mco7rZpaEarZ6iZGiugM',
#      'id': 'UgxWFrzV3bMP0Q8WlLx4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Bapak Prabowo semoga menang 😊',
#       'textOriginal': 'Bapak Prabowo semoga menang 😊',
#       'authorDisplayName': '@RifaldoHutagalung-mm1np',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/jTaseS1TBh8lfcJFPyqUHfj8uU4Ar7zpwSX_m0BXcaiDzm0O3U9HlYjG60JEBfpRj4CJ9fqAug=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@RifaldoHutagalung-mm1np',
#       'authorChannelId': {'value': 'UCl2MJLI-ynDMWFjiSeEwYXA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T04:12:18Z',
#       'updatedAt': '2024-02-14T04:12:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'D2wK5DdEwB1ry4Wx60tNl56s62g',
#    'id': 'UgxXLKRdgxi2x3-fNZZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UiFbRPW3XmUdQMxwaSK2KzfxbOs',
#      'id': 'UgxXLKRdgxi2x3-fNZZ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'pemilu yg harus menang dengan pengertian sebenar nya sudah pasti cma kebanyakan tangan jadi bnyak yg rakus jadi bnyak yg kda sampai',
#       'textOriginal': 'pemilu yg harus menang dengan pengertian sebenar nya sudah pasti cma kebanyakan tangan jadi bnyak yg rakus jadi bnyak yg kda sampai',
#       'authorDisplayName': '@user-vb4mx4ez7z',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_np4HTDD9428QK57XHm455I-zCSgZyAmygR59D0AOW1_E_YTk60oOaDNaSZGvRpQ-rhQw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-vb4mx4ez7z',
#       'authorChannelId': {'value': 'UCnUFyxPSbPQtEYSoqlhtOrQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T03:27:44Z',
#       'updatedAt': '2024-02-14T03:27:44Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'D-RbvAAkArQnGqP9iRbnXEpA348',
#    'id': 'UgxJwTj6IISPcydAyOl4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hY8jp2gXae0JJ6-cYWpRETdwtpU',
#      'id': 'UgxJwTj6IISPcydAyOl4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Saya sdh nyoblos',
#       'textOriginal': 'Saya sdh nyoblos',
#       'authorDisplayName': '@dikaandiyana',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n4wJ1o745a8pX0WITv50Uujw4uXvzulMVIepHG4zeFQ8-oJCV9hJ7hsVaXbntXvYzOwA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@dikaandiyana',
#       'authorChannelId': {'value': 'UClNbhOAqRc60a0b3GuTdaKQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T03:10:34Z',
#       'updatedAt': '2024-02-14T03:10:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yEl-FStE9DIAmknnazmELw0XTyg',
#    'id': 'Ugz6WJhBgX16UTY4UdR4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BrAEBMMTWT0f4fg-k1dB_jsJPKc',
#      'id': 'Ugz6WJhBgX16UTY4UdR4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'GUNAKAN HAK PILIH DENGAN MENGGUNAKAN HATI NURANI DENGAN AZAZ LUBER....KITA OPTIMIS INDONESIA MAMPU DAN BERDAULAT UNTUK KEMAJUAN DEMI BANGSA INDONESIA RAYA😊❤',
#       'textOriginal': 'GUNAKAN HAK PILIH DENGAN MENGGUNAKAN HATI NURANI DENGAN AZAZ LUBER....KITA OPTIMIS INDONESIA MAMPU DAN BERDAULAT UNTUK KEMAJUAN DEMI BANGSA INDONESIA RAYA😊❤',
#       'authorDisplayName': '@user-cc1gn7yn4r',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_meYAh6NPkc3qZ9RQbztfozX2jknUqc69hcasQTLZa7CCWY6MHmzRI1I6I59gYFhEiQXA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-cc1gn7yn4r',
#       'authorChannelId': {'value': 'UCLRf47exmo902scGBPu_CoQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T02:30:33Z',
#       'updatedAt': '2024-02-14T02:30:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5sb977t0hyuAmWZsoEX32iqPO1s',
#    'id': 'UgysDwvGFp5wCatipN94AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Z-0_cntK8h9mhDXjQQZBGo94ztk',
#      'id': 'UgysDwvGFp5wCatipN94AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Prabowoooooo',
#       'textOriginal': 'Prabowoooooo',
#       'authorDisplayName': '@PancaMaulana-xw5to',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/bPOJiJQQ5SqKAnl3P4Ib3Optl2bOy5Ji1alU4v7ObKC3rrOks6wflwcFP44rpV94herHs7qevps=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@PancaMaulana-xw5to',
#       'authorChannelId': {'value': 'UCGHtqknFs7aKYPGfBmaU94Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T02:27:22Z',
#       'updatedAt': '2024-02-14T02:27:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5Ek2OdVO2515REpeIrJtGm4zTL4',
#    'id': 'UgzjLkFbtfDPZKnnDbV4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_1uSUy9g6fgc8ZyqdTzEisXmBDo',
#      'id': 'UgzjLkFbtfDPZKnnDbV4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Jendral bangkit ibu Pertiwi kembali memanggilmu lagi, maju benahi bangsa ini dari korupsi, kolusi dan nepotisme, aku bangga padamu jendral',
#       'textOriginal': 'Jendral bangkit ibu Pertiwi kembali memanggilmu lagi, maju benahi bangsa ini dari korupsi, kolusi dan nepotisme, aku bangga padamu jendral',
#       'authorDisplayName': '@nandangkustiawan5609',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Yo6IgOYKfjndNtJd9DY-FvfwcJp-VKkWV1y7DFn4scYVHsyyAHjo6YV0RowBYxj0DmMLEDJzcg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@nandangkustiawan5609',
#       'authorChannelId': {'value': 'UCCNeMiz4vvs0o6r8s5RdlwA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T02:25:47Z',
#       'updatedAt': '2024-02-14T02:25:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'B_RY9u1MSWs92rPNyQtjXAI9uVI',
#    'id': 'UgzbmJzeRX9NLFluVxp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wLpvV5OQ7Xu3hhDZI5ANGI9HrFQ',
#      'id': 'UgzbmJzeRX9NLFluVxp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Awali pagi ini dengan kebenaran dan kemenangan adalah berhasil.<br><br>                         Karya Yulyon Tanati.',
#       'textOriginal': 'Awali pagi ini dengan kebenaran dan kemenangan adalah berhasil.\n\n                         Karya Yulyon Tanati.',
#       'authorDisplayName': '@matheistanati8625',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lPI1DsS7jrBHCEAeShM5Pu7ImgtVUwqK4Agji37aCplg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@matheistanati8625',
#       'authorChannelId': {'value': 'UCbNt-l5N1kQXPYaxQ3FpGGA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T02:25:08Z',
#       'updatedAt': '2024-02-14T02:25:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zkUTSWVE4CDAif2yv4sBw8Luoeo',
#    'id': 'UgwsfNzWGLPEmFy2mFZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_g-JVP9PcgQCEjfFek2_DKMcOLE',
#      'id': 'UgwsfNzWGLPEmFy2mFZ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Awali pagi ini dengan kebenaran dan kemenangan adalah berhasil. <br><br>                Yulyon Tanati.',
#       'textOriginal': 'Awali pagi ini dengan kebenaran dan kemenangan adalah berhasil. \n\n                Yulyon Tanati.',
#       'authorDisplayName': '@matheistanati8625',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lPI1DsS7jrBHCEAeShM5Pu7ImgtVUwqK4Agji37aCplg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@matheistanati8625',
#       'authorChannelId': {'value': 'UCbNt-l5N1kQXPYaxQ3FpGGA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T01:46:53Z',
#       'updatedAt': '2024-02-14T01:46:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uHkk_D2EoFyZSN6lYAn2A6HeNWQ',
#    'id': 'UgwGjkSUbzvE4R1_3Ap4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'LUNoBpy783reh_t7buS-OSnQpDE',
#      'id': 'UgwGjkSUbzvE4R1_3Ap4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Terima kasih kepada semua pihak yang sudah menjaga keamanan dan kelancaran dalam pesta demokrasi. <br>Tuhan memberkati kita semua.',
#       'textOriginal': 'Terima kasih kepada semua pihak yang sudah menjaga keamanan dan kelancaran dalam pesta demokrasi. \nTuhan memberkati kita semua.',
#       'authorDisplayName': '@andreasgoru7977',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mB42wInA8WmfMWp5u_r_ibNtXk4Rn-wbWZ7yGEsY-MUXQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@andreasgoru7977',
#       'authorChannelId': {'value': 'UCV3Hmso0VZHX6H6qB0lCLrg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-14T00:43:32Z',
#       'updatedAt': '2024-02-14T00:43:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'pg2hzqtycuoL9eumed4dbcIPMfg',
#    'id': 'UgwwuF6xFQ6nkXWi6TF4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ov4COiqfmpnfnDiIKVEo2vGmS1o',
#      'id': 'UgwwuF6xFQ6nkXWi6TF4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
# ...
#       'authorChannelId': {'value': 'UCaDNKUQh_AEzbcyE5haGszQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-02-06T20:26:46Z',
#       'updatedAt': '2024-02-06T20:26:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uSTGCBvxzzd7JwLL6hA0-yLmRv8',
#    'id': 'UgxOaiwOXjiqRccrjyF4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'XNiHxptwcz2_fZAhbINkx1CpqJ4',
#      'id': 'UgxOaiwOXjiqRccrjyF4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Dari sini kita paham pentingnya belajar seperti membaca buku, belajar berorganisasi dll. Kinerja selama jadi menhan apa aja? Minimal bisa ngomong lah sangat lucu sekali tiap survei ko malah makin naik hahaha',
#       'textOriginal': 'Dari sini kita paham pentingnya belajar seperti membaca buku, belajar berorganisasi dll. Kinerja selama jadi menhan apa aja? Minimal bisa ngomong lah sangat lucu sekali tiap survei ko malah makin naik hahaha',
#       'authorDisplayName': '@gimaabidin8586',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nhBdOExkLZuQUj4M_ja-g6FcqfZbgiqyeX0fne-dMyog=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gimaabidin8586',
#       'authorChannelId': {'value': 'UC8niqqq3cT5rdIVEjEu6Hdw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-06T18:58:13Z',
#       'updatedAt': '2024-02-06T18:58:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'HIvfVZ4hlXoOCKfGkopAuCeFJIc',
#    'id': 'Ugz53fu4ceGgvyJVEEp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'O25Xn6RxBfEfjYqqGVxWvHGcxXM',
#      'id': 'Ugz53fu4ceGgvyJVEEp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Pembodohan tok jancok',
#       'textOriginal': 'Pembodohan tok jancok',
#       'authorDisplayName': '@infomaps8',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/cpgoOgZ-SWQc00oNSZ-Kf8ZFQE85B1P86eqkpB5yR9F9eW7fvHWdg7ND1AID52S9ZlTlJjs1qHY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@infomaps8',
#       'authorChannelId': {'value': 'UCdxuiIEQpfoXJ-bMHYF_pgw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-06T15:48:53Z',
#       'updatedAt': '2024-02-06T15:48:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'gWujbt91zd0KtAIU0whe4uxAlfo',
#    'id': 'UgzrR6wZbDAZIIe_SAV4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hyvxybebBEuNsTSRit5caHgX_ZI',
#      'id': 'UgzrR6wZbDAZIIe_SAV4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Solidd🤟🤟🤟🤟🤟🤟🤟🤟🤟🤟',
#       'textOriginal': 'Solidd🤟🤟🤟🤟🤟🤟🤟🤟🤟🤟',
#       'authorDisplayName': '@AlvarGie',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_li0yM6cYLIOWjD11MRFrJBTyO1UpGuxl0HXyI_Shaix_AohWC1X6iVYA2plRVEmtsyaw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@AlvarGie',
#       'authorChannelId': {'value': 'UCOlzJLyj2zHdF4ZxHBuAFkA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-06T14:28:23Z',
#       'updatedAt': '2024-02-06T14:28:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ClwwrBeUS2DBZ9OaPo-Yrg3xL00',
#    'id': 'UgwcbBgEmx_ns3bhgRd4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'W-pMpQ53Q7KzN5i6zPAjR-Ccm40',
#      'id': 'UgwcbBgEmx_ns3bhgRd4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Lanjutkan ❤',
#       'textOriginal': 'Lanjutkan ❤',
#       'authorDisplayName': '@lyana7478',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/acmA0QvfCn9lKKmiS7qLmrJ1i7EkfwDk7qYrb5d7WBuwlMqt7h_UEJ3oXpXjvjDuUTjx_QWrjQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@lyana7478',
#       'authorChannelId': {'value': 'UCAd4yU1kGXGeReHz_R8TToA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-06T12:48:04Z',
#       'updatedAt': '2024-02-06T12:48:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'S35thsawG2Cu3xMmxbhCijCKBkA',
#    'id': 'UgwG-YEsmJqj_ISgdBF4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mVUq9dmRL-HW8VPrTMUM7q1kG3g',
#      'id': 'UgwG-YEsmJqj_ISgdBF4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'saya like konten ini karena Pak Anies',
#       'textOriginal': 'saya like konten ini karena Pak Anies',
#       'authorDisplayName': '@eatella',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/4GGjupcF26N7r5fJ5IG1fmn5sfFowt6JEMlmns2UOYlq9D-z0uyvsdJ1jvUO6PWR2sSw14x8kQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@eatella',
#       'authorChannelId': {'value': 'UC81mSEzdyR3wjuhjAtCJz2w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-06T07:57:47Z',
#       'updatedAt': '2024-02-06T07:57:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'kkBAK6zKdusibzPLDZ5POBuxTT8',
#    'id': 'Ugy5nR3OG1LW2xkUlw94AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DZu2XjjP5A7hxO44-NkuPZkgwxI',
#      'id': 'Ugy5nR3OG1LW2xkUlw94AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Nggak benar aturan KPU untuk PEMILU tahun 2024, potensi GOLPUT begitu besar dikarenakan kesulitan mengurus formulir A5, banyak warga negara yang kehilangan hak pilihnya tahun 2024 ini.',
#       'textOriginal': 'Nggak benar aturan KPU untuk PEMILU tahun 2024, potensi GOLPUT begitu besar dikarenakan kesulitan mengurus formulir A5, banyak warga negara yang kehilangan hak pilihnya tahun 2024 ini.',
#       'authorDisplayName': '@Minderwaardigheids',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/0PT7AQFIznLuFMxT-SXKdq2o09F2VTtoi6O6HDuXbf8jHsXKkTSFe1H5gXPjjQgdRYA6NfR-3Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Minderwaardigheids',
#       'authorChannelId': {'value': 'UCvKmoxsY0xWmHvmEmp62gJg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-06T02:02:30Z',
#       'updatedAt': '2024-02-06T02:02:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'R0g4bq7Bj0y15KCeJiWf_aSfN7c',
#    'id': 'UgyzUBAzybDAshTE_QZ4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ml3veot67hi4NckAs_GfmXB8S1c',
#      'id': 'UgyzUBAzybDAshTE_QZ4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'GWE GOLPUN DAN GUE BANGGA.<br><br>MAU GANTI SIAPA KEK . YA SAMA AJA DIRI KITA SNDRI KALAU MAU MAKAN YA HRS KERJA !!!',
#       'textOriginal': 'GWE GOLPUN DAN GUE BANGGA.\n\nMAU GANTI SIAPA KEK . YA SAMA AJA DIRI KITA SNDRI KALAU MAU MAKAN YA HRS KERJA !!!',
#       'authorDisplayName': '@kolobolodwee6473',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kfHVAdAzujupFsaYelEldqPujN9F6S3OSh9d_onpc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@kolobolodwee6473',
#       'authorChannelId': {'value': 'UCwKgNIgQ_J8zBLRXQ9bem_A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-05T23:34:28Z',
#       'updatedAt': '2024-02-05T23:34:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qc97Gi8wcfN_q1nn8xKI7X5tAxI',
#    'id': 'UgxmGMN2C5GPFmCCTVh4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U3YNa0CS22BWN-jLoOL73STbZAA',
#      'id': 'UgxmGMN2C5GPFmCCTVh4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'apa bisa di percaya ketuanya saja pelanggar etika',
#       'textOriginal': 'apa bisa di percaya ketuanya saja pelanggar etika',
#       'authorDisplayName': '@ariesnexat8417',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/xcG9uSecvtrxKheVUaZyj9KVIrCJLDMQ3m76fgcl-chekYuUOG31NntxlSPBaw1k8kFqPfRq=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ariesnexat8417',
#       'authorChannelId': {'value': 'UChfX1GGP_MGO_kQuWmEH4dQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-05T18:22:34Z',
#       'updatedAt': '2024-02-05T18:22:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Nv7rUQHfNuDv6RmEdYvsQT2SkAg',
#    'id': 'UgzA0NziNkVb3-XeENd4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'm_NabkIChdN0SitudkiDfJkA1XM',
#      'id': 'UgzA0NziNkVb3-XeENd4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Siapa Pun PILIHAN KALIAN<br>SIAPAun yang  jadi Kelak... calon Presiden RI<br> Itulah yang tanggung Jawab umtuk Kita SEMUA.<br> Semoga jadi yang terbaik DI TAHUN INI Dan KEDEPANYA',
#       'textOriginal': 'Siapa Pun PILIHAN KALIAN\nSIAPAun yang  jadi Kelak... calon Presiden RI\n Itulah yang tanggung Jawab umtuk Kita SEMUA.\n Semoga jadi yang terbaik DI TAHUN INI Dan KEDEPANYA',
#       'authorDisplayName': '@BOKYAgacor',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/tnapSxoC_YUMGbe32Ig5wnzymL77-HCoAyVo4l2wHODWyePo_SmgfCEEdLDwjRZ7qVqAQ11IAw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@BOKYAgacor',
#       'authorChannelId': {'value': 'UCPMOsY5KpM-Pk5g8qvp8pVQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-04T17:23:52Z',
#       'updatedAt': '2024-02-04T17:23:52Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'U0i1oXV2pkDbIVCXQMOXPMUTeR8',
#    'id': 'UgxR3_WSRMGonucLj_J4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JWUIG8HGZwyirbl_qZkPmocrhhw',
#      'id': 'UgxR3_WSRMGonucLj_J4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': '❤❤❤👍👍👍👍',
#       'textOriginal': '❤❤❤👍👍👍👍',
#       'authorDisplayName': '@nurlailatuhelelu4073',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nqZeUbS8FszTBqi3tCPdNlzR2CT9O91bMveQljvn4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@nurlailatuhelelu4073',
#       'authorChannelId': {'value': 'UC_52TKGF60q-hcQe1xLP5qQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-04T16:52:55Z',
#       'updatedAt': '2024-02-04T16:52:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ffrEfdbJhN8DOee5Ee4Wcpa2OLU',
#    'id': 'UgyEz_HvR286RpoFP3Z4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oqogJho6kLnEu00OxQtHA_Cqsp0',
#      'id': 'UgyEz_HvR286RpoFP3Z4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': '😊',
#       'textOriginal': '😊',
#       'authorDisplayName': '@gepengpeng3532',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lAE3hoyJxRR9CjMC0T24dXXhMpvm2JtQ4-tulelTw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gepengpeng3532',
#       'authorChannelId': {'value': 'UCIyjT0llZ3_88s71yQIUJcA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-04T16:46:50Z',
#       'updatedAt': '2024-02-04T16:46:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ota8YtoxgBMW3Z20FCcl2E01CdM',
#    'id': 'UgwaN0IFMR1kucsMzYp4AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'A68T3FTDsrwuf0mye_OuvKXyK4M',
#      'id': 'UgwaN0IFMR1kucsMzYp4AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Selama ini perampasan hasil kekayaan alam oleh asih itu d sah kan oleh UUD dan dalam sistem demokerasi itu sah2 saja... Jadi sebenar nya akar masalah indonesia itu adalah pada sistem dan aturan yg kalian rekayasa...',
#       'textOriginal': 'Selama ini perampasan hasil kekayaan alam oleh asih itu d sah kan oleh UUD dan dalam sistem demokerasi itu sah2 saja... Jadi sebenar nya akar masalah indonesia itu adalah pada sistem dan aturan yg kalian rekayasa...',
#       'authorDisplayName': '@syafaatzein7339',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_njC0zNDt73vgkE3WbE5aquBkq-E8PZotNlFs61-Hc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@syafaatzein7339',
#       'authorChannelId': {'value': 'UCbMgwjpivR7ujJM-W9p1qbw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-04T16:39:29Z',
#       'updatedAt': '2024-02-04T16:39:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'XvrCAXKs8danY6bkxFj1PPW_Cik',
#    'id': 'UgxRqmPrQ5jzqGD9Bq14AaABAg',
#    'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#     'videoId': 'KJdt-HBBGIo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'IZ-NRF1mH9mf2K5ww26-fGlZRK8',
#      'id': 'UgxRqmPrQ5jzqGD9Bq14AaABAg',
#      'snippet': {'channelId': 'UCVdSz86o9q2cQKvAQ5QhOYg',
#       'videoId': 'KJdt-HBBGIo',
#       'textDisplay': 'Prabowo untuk indonesia maju🔥✌🏻',
#       'textOriginal': 'Prabowo untuk indonesia maju🔥✌🏻',
#       'authorDisplayName': '@kedawolfch.',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Tk2aUJpbE-ej2gI9ZX9w6qGFY_Yd24P-RzPK8xV6YfM1PBkYu4UwLGDtl6SLvKuDYbMVSy2ogg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@kedawolfch.',
#       'authorChannelId': {'value': 'UCWl7ao1uSXcMKvsde4oj4cQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-02-04T15:29:22Z',
#       'updatedAt': '2024-02-04T15:29:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# ## 3. Define Main Items (Video ID, Total Reply of Count, Comment ID, Text of Comment, Total of Comment Like, Name of Account Commenting, etc) from Video YouTube based on Video ID in YouTube

# %%
"""
Mendefinisikan beberapa elemen item yang membentuk serangkaian komentar utama yang akan digunakan
sebagai kolom di dalam DataFrame berdasarkan ID video YouTube yang sebelumnya telah didefinisikan
pada "video_youtube_data_request" (saat ini permintaan tersebut telah diterima sebagai respon dan disimpan
di dalam "video_youtube_data_response") dengan mengambil 100 data/informasi dari serangkaian komentar utama di dalam video
debat capres-cawapres Republik Indonesia babak ketiga yang di-upload oleh channel YouTube KPU RI
"""


"""
Variabel "list_third_video_debate_kpuri" adalah empty list untuk menyimpan beberapa elemen item dari rangkaian
teks komentar utama seperti ID video debat babak ketiga yang ditayangkan oleh channel KPU RI, ID channel KPU RI,
isi teks komentar khususnya komentar utama, nama akun user/penonton yang berkomentar di dalam video tersebut, dll
"""
list_third_video_debate_kpuri = []


for item in video_youtube_data_response["items"]:
    video_id = item["snippet"]["videoId"] # Mendapatkan ID video debat ketiga capres-cawapres yang di-upload channel KPU RI
    total_reply_count = item["snippet"]["totalReplyCount"] # Mendapatkan jumlah total balasan dari masing-masing teks komentar
    comment_id = item["id"] # Mendapatkan ID dari seluruh teks komentar utama (bukan teks komentar yang bersifat reply)
    
    
    """
    Mendapatkan seluruh elemen item per masing-masing komentar utama yang menjadi struktur pembentuk dasar dari komentar utama
    berdasarkan video ID yang sebelumnya telah diinisialisasikan.
    Jenis objek yang menjadi struktur/rangkaian detail atas masing-masing komentar utama adalah channel ID,
    teks komentar, jumlah like pada komentar tersebut, tanggal dan waktu dibuatnya komentar,
    nama akun user yang berkomentar di dalam video tersebut, dll
    
    Perlu diketahui jika elemen item yang terdapat pada top level comment dan commentThreads() berbeda tetapi
    dapat digabungkan menjadi satu kesatuan. Elemen seperti video id,
    jumlah user yang membalas/merespon teks komentar utama, dan lainnya
    termasuk di dalam elemen item yang dimiliki oleh commentThreads()
    karena sifatnya adalah informasi general dari rangkaian komentar utama
    
    Sedangkan elemen item yang dimiliki oleh top level comment lebih bersifat informasi yang spesifik yang dimiliki oleh
    masing-masing komentar utama atau komentar balasan atas komentar utama.
    Elemen item seperti nama user/akun yang berkomentar, isi atas masing-masing teks komentar yang dibuat oleh
    setiap akun yang berkomentar, jumlah user yang menyukai isi dari teks komentar utama, dan lainnya
    termasuk ke dalam item-item yang dimiliki oleh top level comment
    """
    comment_items = item["snippet"]["topLevelComment"]["snippet"]
    
    
    """
    Memasukkan atribut/elemen utama ke dalam variabel list kosong yaitu "list_third_video_debate_kpuri" yang akan
    berisikan beberapa objek item/elemen dari serangkaian komentar utama seperti ID video,
    ID Channel yang mem-publish/meng-upload video tersebut, nama akun user yang berkomentar beserta teks komentar,
    tanggal pembuatan komentar untuk video tersebut,
    jumlah total like sebagai bentuk respon setuju pada komentar yang telah dibuat oleh user, dll.
     
    Catatan tambahan bahwasanya variabel "video_id", "total_reply_count", "comment_id" dan "comment_items"
    termasuk ke dalam elemen utama yang akan dimasukkan ke dalam list kosong (empty list) yang bernama
    "list_third_video_debate_kpuri" yang nantinya list yang bernama "list_third_video_debate_kpuri"
    akan menjadi struktur kolom di dalam Pandas DataFrame
    """
    list_third_video_debate_kpuri.append([
        video_id, # Memasukkan ID video debat ketiga capres-cawapres yang di-upload oleh channel YouTube KPU RI ke dalam list
        comment_items["channelId"], # Memasukkan ID yang dimiliki oleh channel YouTube KPU RI ke dalam variabel list
        comment_id, # Memasukkan ID masing-masing komentar yang dibuat oleh para penonton video debat ketiga ke dalam list
        comment_items["authorDisplayName"], # Memasukkan nama akun YouTube yang berkomentar di video debat ke dalam empty list
        comment_items["textDisplay"], # Memasukkan 100 teks komentar utama pada video ketiga dari channel KPU RI ke dalam list
        comment_items["likeCount"], # Memasukkan jumlah total like yang diterima oleh teks komentar utama ke dalam variabel list
        total_reply_count, # Memasukkan jumlah total balasan (reply) yang diterima oleh teks komentar utama ke dalam list
        comment_items["authorChannelUrl"], # Memasukkan URL/link channel akun YouTube para penonton video debat ketiga ke list
        comment_items["publishedAt"], # Memasukkan tanggal dan waktu saat pertama kali teks komentar utama dibuat oleh user
        comment_items["updatedAt"] # Memasukkan tanggal dan waktu saat suatu teks komentar mengalami perubahan (update) tulisan
    ])
    

"""
Menampilkan jumlah data yang dimiliki oleh list setelah dilakukan proses pemilihan
elemen-elemen yang akan menampilkan struktur dari rangkaian komentar utama dari video debat
capres-cawapres babak ketiga dari YouTube channel KPU RI
"""
print("Jumlah Data yang Dimiliki oleh Variabel List 'list_third_video_debate_kpuri' sebelum Proses Looping adalah",
      len(list_third_video_debate_kpuri))
# Out:
# Jumlah Data yang Dimiliki oleh Variabel List 'list_third_video_debate_kpuri' sebelum Proses Looping adalah 100

# %% [markdown]
# Jika hanya menggunakan code script diatas saja maka data komentar yang didapatkan hanya berjumlah 100 data saja karena jumlah maksimal untuk mengambil data komentar dari suatu konten video YouTube dengan menggunakan Google YouTube API dibatasi hanya 100 data. Maka dari itu karena menurut saya 100 data sangat tidak cukup untuk penelitian kali ini, maka saya akan mengambil data komentar dari video debat capres-cawapres babak ketiga dari YouTube channel KPU RI lebih dari 100 data komentar.
#
# Untuk mengatasi permasalahan ini, saya akan melakukan proses looping/pengulangan permintaan untuk mengambil data komentar lebih dari 100 data. Jumlah data yang saya inginkan pada penelitian kali ini berjumlah sebanyak 2.600 data dari 5.374 komentar (per tanggal 4 Mei 2024) sehingga permintaan yang code script dibawah ini akan mengulangi permintaan mengambil data sebanyak 2.600 data komentar yang akan ditempatkan di dalam 10 kolom/object/elemen utama dari video debat capres-cawapres babak ketiga yang di-upload oleh channel YouTube KPU RI. Sepuluh kolom/elemen utama yang akan membentuk DataFrame adalah kolom elemen "videoId", "channelId", "id" sebgaai comment_id, "authorDisplayName", "textDisplay", "likeCount", "totalReplyCount", "authorChannelUrl", "publishedAt", dan "updatedAt".
#
# Sebagai catatan dan pengingat bahwasanya saat ini objek list yang bernama "list_third_video_debate_kpuri" baru memiliki 100 rangkaian data/informasi komentar dan akan dilakukan proses pengulangan permintaan hingga variabel list "list_third_video_debate_kpuri" memiliki 2.600 data komentar beserta elemen-elemen utamanya. Agar dapat mengambil data komentar sebanyak 2.600 data, maka saya akan menerapkan teknik TokenPagination.
#
# TokenPagination merupakan cara untuk mengambil data-data yang berada di halaman selanjutnya (data yang bukan berada di halaman utama/halaman paling awal dari suatu konten/informasi). TokenPagination yang akan digunakan di dalam penelitian kali ini memiliki tujuan untuk mendapatkan data-data komentar seperti teks komentar, data nama akun/user yang berkomentar, tanggal pembuatan komentar, dsb, yang berada di halaman-halaman berikutnya atau halaman setelah 100 data paling awal (data yang menjadi batasan maksimal/limit yang dapat diambil menggunakan YouTube Data API v3).

# %%
"""
Menampilkan seluruh data dari beberapa elemen item yang sebelumnya telah dilakukan proses elemen yang akan ditampilkan
dari serangkaian teks komentar utama yang terdapat di dalam variabel list "list_third_video_debate_kpuri"
yang sumber data komentarnya berasal dari video debat capres-cawapres babak ketiga yang ditayangkan
oleh channel Youtube KPU RI yang memiliki ID Video KJdt-HBBGIo
"""
list_third_video_debate_kpuri
# Out:
# [['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxqDT9AVoxMThVBINF4AaABAg',
#   '@user-iq6yq1gt3w',
#   '<a href="https://www.youtube.com/watch?v=KJdt-HBBGIo&amp;t=1754">29:14</a>',
#   0,
#   0,
#   'http://www.youtube.com/@user-iq6yq1gt3w',
#   '2024-05-02T02:23:01Z',
#   '2024-05-02T02:23:01Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzwTwjhMpSHtW-pZUp4AaABAg',
#   '@smpteladanp.siantar6962',
#   'Mantap',
#   0,
#   0,
#   'http://www.youtube.com/@smpteladanp.siantar6962',
#   '2024-04-10T01:44:13Z',
#   '2024-04-10T01:44:13Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwZ6efr3JiJmlhxf6h4AaABAg',
#   '@NamuDandelion',
#   'POKOKNYA ALL IN PRABOWO-GIBRAN ❤️❤️',
#   0,
#   0,
#   'http://www.youtube.com/@NamuDandelion',
#   '2024-04-04T09:37:48Z',
#   '2024-04-04T09:37:48Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxms8s8tQZqDD-UcOJ4AaABAg',
#   '@bendoro8428',
#   'pemilu',
#   0,
#   0,
#   'http://www.youtube.com/@bendoro8428',
#   '2024-03-20T00:13:07Z',
#   '2024-03-20T00:13:07Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugwq_LTsM7t9QTbK_Ft4AaABAg',
#   '@user-ut5gc2zk3w',
#   'Ketiga',
#   0,
#   0,
#   'http://www.youtube.com/@user-ut5gc2zk3w',
#   '2024-03-12T22:12:07Z',
#   '2024-03-12T22:12:07Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyJhQw2cqCtx4gtl594AaABAg',
#   '@keliksetyawanmahatmanto7727',
#   'PANDUAN ENDAZMUNEGTONGKECUAN  UDELETEA BOOLONGTONGSAYUR NORACK KALAPMODDARATTAIWAN ABUD TAU U YEAA.4JJ1.',
#   1,
#   0,
#   'http://www.youtube.com/@keliksetyawanmahatmanto7727',
#   '2024-03-05T16:11:57Z',
#   '2024-03-05T16:13:04Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyRZSI9XGW9oQHToBx4AaABAg',
#   '@donidi374',
#   'Yg tersakiti akhirnya pak Prabowo jadi presiden 🤣🤣🤣',
#   2,
#   0,
#   'http://www.youtube.com/@donidi374',
#   '2024-03-01T07:25:33Z',
#   '2024-03-01T07:25:33Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgykSiZ9b_F5kxVv3Ll4AaABAg',
#   '@OppoAs-oc7rp',
#   'Di luar daerah jawa   ...banser keok.........ayam sayur...',
#   0,
#   0,
#   'http://www.youtube.com/@OppoAs-oc7rp',
#   '2024-03-01T03:58:51Z',
#   '2024-03-01T03:58:51Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyXfp8k4wNy2qKS9xZ4AaABAg',
#   '@rifaldihidayat5884',
#   'sumpah muka Anies ngeselin disini',
#   0,
#   0,
#   'http://www.youtube.com/@rifaldihidayat5884',
#   '2024-02-26T20:31:26Z',
#   '2024-02-26T20:31:26Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw4-2fnmmNISHYJvK54AaABAg',
#   '@IlhamsamosirIlham-gf8ir',
#   'Hidup Hercules.. jawaban yg CERDAS ❤',
#   0,
#   0,
#   'http://www.youtube.com/@IlhamsamosirIlham-gf8ir',
#   '2024-02-25T18:54:32Z',
#   '2024-02-25T18:54:32Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxh7tFOUgjgMiHOv7V4AaABAg',
#   '@user-sj7cs7zv7s',
#   'Kompak serang pak prabowo , nyatanyaaa pak prabowo menang 58%❤❤',
#   0,
#   0,
#   'http://www.youtube.com/@user-sj7cs7zv7s',
#   '2024-02-25T18:36:30Z',
#   '2024-02-25T18:36:30Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwvIPQ1En5ufD4KYdl4AaABAg',
#   '@Odamjaya',
#   'SUDAH 10 TAHUN GAK ADA LOWONGAN KERJA. YANG ADA LOWONGAN KERJA BUAT PEKERJA ASING. MALAM ADA YANG CARIKAN KERJA BUAT ANAKNYA. LEBIH MEMENTINGKAN DIRINYA DARI PADA RAKYATNYA. BUKAN KAH DIA DITUGASKAN UNTUK MENSEJAHTERAKAN RAKYATNYA.',
#   0,
#   0,
#   'http://www.youtube.com/@Odamjaya',
#   '2024-02-23T23:45:13Z',
#   '2024-02-23T23:45:13Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwwRLUxCz_vr3QP9P94AaABAg',
#   '@charlessiagian8411',
#   'B😊',
#   0,
#   0,
#   'http://www.youtube.com/@charlessiagian8411',
#   '2024-02-22T19:47:06Z',
#   '2024-02-22T19:47:06Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzVskBVqNCRlb7GKhl4AaABAg',
#   '@basukibasukiimannugroho3155',
#   'Indonesiaku akan hebat pada saatnya',
#   0,
#   0,
#   'http://www.youtube.com/@basukibasukiimannugroho3155',
#   '2024-02-22T17:00:39Z',
#   '2024-02-22T17:00:39Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxju6nGquT2Gpa_Url4AaABAg',
#   '@user-sz4jr4qz2b',
#   'Joss lek😂',
#   0,
#   0,
#   'http://www.youtube.com/@user-sz4jr4qz2b',
#   '2024-02-21T23:10:50Z',
#   '2024-02-21T23:10:50Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzYdf3uq2BexpEijvh4AaABAg',
#   '@hengkyyp4238',
#   'Terus gimana nih ... Tuh banyak aduan beda perolehan suara, antara C1 sama yg di scan kok beda ? ...... Hanya minta maaf aja ya ?',
#   0,
#   0,
#   'http://www.youtube.com/@hengkyyp4238',
#   '2024-02-19T03:19:40Z',
#   '2024-02-19T03:19:40Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz7BUvxV5k_8jrlb6t4AaABAg',
#   '@cepihhidayat6994',
#   'Sembako mahal, bers mahal pajak bejibun naik lagi, cari duit sendiri cari kerja susah.intinya usaha sendiri beribadah sampai mati selesai nih hidup.',
#   0,
#   0,
#   'http://www.youtube.com/@cepihhidayat6994',
#   '2024-02-18T06:52:42Z',
#   '2024-02-18T06:52:42Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzAteDqK0R1oljVsnd4AaABAg',
#   '@cepihhidayat6994',
#   'Rakyat hanya dijadikan kendaraan politik, begitu diantar menuju tempat singgasana, kendaraan itu dilupakan tidak diservice, tidak dirawat setelah 5 tahun kendaraan itu dijual belikan.',
#   0,
#   0,
#   'http://www.youtube.com/@cepihhidayat6994',
#   '2024-02-18T06:50:46Z',
#   '2024-02-18T06:50:46Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyqFL-MDSXGWcv6IsN4AaABAg',
#   '@user-vp6kr1ec8x',
#   'SI REKAP APLIKASI YG SANGAT BANGSAD...  YG CIPTAIN ALPIKASI PASTI ANAK HARAM<br><br><br>.BANGSAT EMANG',
#   0,
#   0,
#   'http://www.youtube.com/@user-vp6kr1ec8x',
#   '2024-02-17T15:49:39Z',
#   '2024-02-17T15:49:39Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxWIhaPR41LxFDw1WJ4AaABAg',
#   '@agusfitriadi1081',
#   'Pantes aja kubu prabowo takut anis jd presiden terutama orng yg di belakangnya ikut mengatur ,yg jelas pasti takut bokbroknya 😂',
#   0,
#   0,
#   'http://www.youtube.com/@agusfitriadi1081',
#   '2024-02-16T19:33:45Z',
#   '2024-02-16T19:33:45Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyF-6UDpx9MypDGuzF4AaABAg',
#   '@kimjongpret-uv9gv',
#   'siap siap bakalan ada demo besar besaran rakyat indonesia kalau KPU gk jujur 😠😠',
#   0,
#   0,
#   'http://www.youtube.com/@kimjongpret-uv9gv',
#   '2024-02-16T08:10:17Z',
#   '2024-02-16T08:10:17Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwWlnac-Vunzx1DZcB4AaABAg',
#   '@marahapmin9006',
#   'DILAPANGAN PUN BANYAK KECURANGAN. DI SIREKAP KPU PUN BANYAK MANIPULASI PENGHITUNGAN HASIL SUARA. SEMUA DITUNJUKKAN OLEH VIDEO YANG BERBEDA DI MEDSOS. SEMOGA KPU BISA DITUNTUT',
#   0,
#   0,
#   'http://www.youtube.com/@marahapmin9006',
#   '2024-02-16T02:58:55Z',
#   '2024-02-16T02:59:25Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgznfCXI59FC7ef-Lt94AaABAg',
#   '@user-em4bn2cv4g',
#   'Ucdb 7dg 7eb uebdssdjjbdsssdudu udbcdiebicevdssogssgkddddddfhhwwoorewsdcfgrfdd',
#   0,
#   0,
#   'http://www.youtube.com/@user-em4bn2cv4g',
#   '2024-02-15T23:20:45Z',
#   '2024-02-15T23:20:45Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw_ednHuTlRT1UhgCl4AaABAg',
#   '@koedjangkaroehoen',
#   'Terima kasih PAKDE, PAMAN, MKMK, POLRI,TNI, KPPU, BAWASLU, KEMENTRIAN BUMN,KEMENDAGRI ...telah berhasil mengadakan dan menyelenggarakan PEMILU TAHUN INI menjadi TERBURUK dan TERBUSUK dalam SEJARAH di indonesia ...🇲🇨❤🇲🇨',
#   0,
#   0,
#   'http://www.youtube.com/@koedjangkaroehoen',
#   '2024-02-15T22:06:10Z',
#   '2024-02-15T22:06:10Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzdTK6jatPR4HKRH054AaABAg',
#   '@japulgentak9848',
#   'Ingat wahai KPU MASIH ADA SIKSA KUBUR DAN NERAKA, AZAB allah SAKIT, DUNIA HANYA SEMENTARA... SALAM',
#   0,
#   0,
#   'http://www.youtube.com/@japulgentak9848',
#   '2024-02-15T11:50:30Z',
#   '2024-02-15T11:50:30Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzlzHs74QNBZD3kKgZ4AaABAg',
#   '@angky.v5535',
#   'Kpu tolol',
#   0,
#   0,
#   'http://www.youtube.com/@angky.v5535',
#   '2024-02-15T07:01:59Z',
#   '2024-02-15T07:01:59Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzlbaEMNWcq-gOTTKV4AaABAg',
#   '@iyogorotna4677',
#   'Hahaha ...memilih utk idonesia hanya slogan ..yg bener memilih utk yg kasih uang dan keluaga jokowi ....hahahaha',
#   0,
#   0,
#   'http://www.youtube.com/@iyogorotna4677',
#   '2024-02-15T06:13:39Z',
#   '2024-02-15T06:13:39Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugw-9D2-poTzNA0Dj9h4AaABAg',
#   '@ppssumbangbujurtv',
#   'kpu ngpain kok bisa surat suara bisa habis data masih ada dan saya belum coblos waduh gawat nh kpu.',
#   0,
#   0,
#   'http://www.youtube.com/@ppssumbangbujurtv',
#   '2024-02-14T06:37:17Z',
#   '2024-02-14T06:37:17Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwwFJt84lXJMkFj8Pp4AaABAg',
#   '@user-ui8oy2wp3w',
#   'Aku pilih prabowa<br>Indonesia😊',
#   0,
#   0,
#   'http://www.youtube.com/@user-ui8oy2wp3w',
#   '2024-02-14T04:46:24Z',
#   '2024-02-14T04:46:24Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzxPegfH4T-ZlXR6Dl4AaABAg',
#   '@nopetnopet6900',
#   'Prabowo  debssss',
#   0,
#   0,
#   'http://www.youtube.com/@nopetnopet6900',
#   '2024-02-14T04:43:42Z',
#   '2024-02-14T04:43:42Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxWFrzV3bMP0Q8WlLx4AaABAg',
#   '@RifaldoHutagalung-mm1np',
#   'Bapak Prabowo semoga menang 😊',
#   0,
#   0,
#   'http://www.youtube.com/@RifaldoHutagalung-mm1np',
#   '2024-02-14T04:12:18Z',
#   '2024-02-14T04:12:18Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxXLKRdgxi2x3-fNZZ4AaABAg',
#   '@user-vb4mx4ez7z',
#   'pemilu yg harus menang dengan pengertian sebenar nya sudah pasti cma kebanyakan tangan jadi bnyak yg rakus jadi bnyak yg kda sampai',
#   0,
#   0,
#   'http://www.youtube.com/@user-vb4mx4ez7z',
#   '2024-02-14T03:27:44Z',
#   '2024-02-14T03:27:44Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxJwTj6IISPcydAyOl4AaABAg',
#   '@dikaandiyana',
#   'Saya sdh nyoblos',
#   0,
#   0,
#   'http://www.youtube.com/@dikaandiyana',
#   '2024-02-14T03:10:34Z',
#   '2024-02-14T03:10:34Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz6WJhBgX16UTY4UdR4AaABAg',
#   '@user-cc1gn7yn4r',
#   'GUNAKAN HAK PILIH DENGAN MENGGUNAKAN HATI NURANI DENGAN AZAZ LUBER....KITA OPTIMIS INDONESIA MAMPU DAN BERDAULAT UNTUK KEMAJUAN DEMI BANGSA INDONESIA RAYA😊❤',
#   0,
#   0,
#   'http://www.youtube.com/@user-cc1gn7yn4r',
#   '2024-02-14T02:30:33Z',
#   '2024-02-14T02:30:33Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgysDwvGFp5wCatipN94AaABAg',
#   '@PancaMaulana-xw5to',
#   'Prabowoooooo',
#   0,
#   0,
#   'http://www.youtube.com/@PancaMaulana-xw5to',
#   '2024-02-14T02:27:22Z',
#   '2024-02-14T02:27:22Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzjLkFbtfDPZKnnDbV4AaABAg',
#   '@nandangkustiawan5609',
#   'Jendral bangkit ibu Pertiwi kembali memanggilmu lagi, maju benahi bangsa ini dari korupsi, kolusi dan nepotisme, aku bangga padamu jendral',
#   0,
#   0,
#   'http://www.youtube.com/@nandangkustiawan5609',
#   '2024-02-14T02:25:47Z',
#   '2024-02-14T02:25:47Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzbmJzeRX9NLFluVxp4AaABAg',
#   '@matheistanati8625',
#   'Awali pagi ini dengan kebenaran dan kemenangan adalah berhasil.<br><br>                         Karya Yulyon Tanati.',
#   0,
#   0,
#   'http://www.youtube.com/@matheistanati8625',
#   '2024-02-14T02:25:08Z',
#   '2024-02-14T02:25:08Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwsfNzWGLPEmFy2mFZ4AaABAg',
#   '@matheistanati8625',
#   'Awali pagi ini dengan kebenaran dan kemenangan adalah berhasil. <br><br>                Yulyon Tanati.',
#   0,
#   0,
#   'http://www.youtube.com/@matheistanati8625',
#   '2024-02-14T01:46:53Z',
#   '2024-02-14T01:46:53Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwGjkSUbzvE4R1_3Ap4AaABAg',
#   '@andreasgoru7977',
#   'Terima kasih kepada semua pihak yang sudah menjaga keamanan dan kelancaran dalam pesta demokrasi. <br>Tuhan memberkati kita semua.',
#   0,
#   0,
#   'http://www.youtube.com/@andreasgoru7977',
#   '2024-02-14T00:43:32Z',
#   '2024-02-14T00:43:32Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwwuF6xFQ6nkXWi6TF4AaABAg',
#   '@benyaminelu7493',
#   'Mohon infonya, apa diperbolehkan warga yang belum ada KTP bisa ikut pemilu dgn membawa KK?',
#   0,
#   0,
#   'http://www.youtube.com/@benyaminelu7493',
#   '2024-02-14T00:31:36Z',
#   '2024-02-14T00:31:36Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyqYuYP5vK8FCdLad14AaABAg',
#   '@bedesnjowo-jg9kj',
#   '❤ INDONESIA',
#   0,
#   0,
#   'http://www.youtube.com/@bedesnjowo-jg9kj',
#   '2024-02-14T00:28:25Z',
#   '2024-02-14T00:28:25Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz9q8dBxTGtnI7yt-J4AaABAg',
#   '@JensesJensesLaando-di3zg',
#   'Presiden yang terpilih nanti akan memimpin yang terbaik🎉🎉🎉🎉',
#   0,
#   0,
#   'http://www.youtube.com/@JensesJensesLaando-di3zg',
#   '2024-02-14T00:20:35Z',
#   '2024-02-14T00:20:35Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzNA3zD16IVRKPMltV4AaABAg',
#   '@elisabethika4612',
#   'Ganjar itu luar biasa sampai Prabowo selalu setuju dengan pendapat x❤ hebat 🥰',
#   0,
#   0,
#   'http://www.youtube.com/@elisabethika4612',
#   '2024-02-13T23:40:13Z',
#   '2024-02-13T23:40:13Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxFJJu-AhbmwCPKvZh4AaABAg',
#   '@elisabethika4612',
#   'Hidup Ganjar ❤️',
#   0,
#   0,
#   'http://www.youtube.com/@elisabethika4612',
#   '2024-02-13T23:36:28Z',
#   '2024-02-13T23:36:28Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugyv3C8L5wMbvhbIhl94AaABAg',
#   '@elisabethika4612',
#   'Ganjar syg bijaksana 🥰 kita butuh pemimpin yang memiliki jiwa muda bukan yg sudah lanjut usia... dan Ganjar adalah pemimpin yang baik',
#   0,
#   0,
#   'http://www.youtube.com/@elisabethika4612',
#   '2024-02-13T23:31:58Z',
#   '2024-02-13T23:31:58Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzxGqfwEtigpEy5bvV4AaABAg',
#   '@sharenofficial6343',
#   'Siapa pun presiden nya dia tetap presiden kita yg penting bisa menjalanin negara dengan amanah serta tanggungjawab😊',
#   0,
#   0,
#   'http://www.youtube.com/@sharenofficial6343',
#   '2024-02-13T23:31:31Z',
#   '2024-02-13T23:31:31Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwGI3BRGeMgLiCLtVF4AaABAg',
#   '@chenaldarinntsumbabaratday8642',
#   'mantap pak prabowo✌✌👍🛐',
#   0,
#   0,
#   'http://www.youtube.com/@chenaldarinntsumbabaratday8642',
#   '2024-02-13T23:28:42Z',
#   '2024-02-13T23:28:42Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyiF3bsE1-rgu5t-uh4AaABAg',
#   '@ketutsukrenisukreni2790',
#   'zxzzzz*<b>****</b>',
#   0,
#   0,
#   'http://www.youtube.com/@ketutsukrenisukreni2790',
#   '2024-02-13T23:26:51Z',
#   '2024-02-13T23:26:51Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyOMhHBRs5AWTIISmB4AaABAg',
#   '@chenaldarinntsumbabaratday8642',
#   'anis ngomong tentang pelestina, kamu warga nk ri atau manusia pelestina😅😅',
#   1,
#   0,
#   'http://www.youtube.com/@chenaldarinntsumbabaratday8642',
#   '2024-02-13T23:25:01Z',
#   '2024-02-13T23:25:01Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzt2w7nGvOKUQd_L0J4AaABAg',
#   '@user-nm9cd4lx1i',
#   '❤❤❤😊',
#   1,
#   0,
#   'http://www.youtube.com/@user-nm9cd4lx1i',
#   '2024-02-13T22:21:33Z',
#   '2024-02-13T22:21:33Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxQqeN5wLScS-x3uqV4AaABAg',
#   '@intandamalu8770',
#   'Semoga siapa yg jadi presiden, semoga merubah nasib saya ya Allah🤲🤲🤲 banyak cobaan banyak utang selama pak Jokowi menjadi presiden selama ni',
#   1,
#   0,
#   'http://www.youtube.com/@intandamalu8770',
#   '2024-02-13T21:45:09Z',
#   '2024-02-13T21:45:09Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwU5_wAS6NN7BqAJ1N4AaABAg',
#   '@kemasisa8301',
#   'Luar biasa....<br>Trslah berjuang utk Indonesia lebih baik',
#   0,
#   0,
#   'http://www.youtube.com/@kemasisa8301',
#   '2024-02-13T17:43:26Z',
#   '2024-02-13T17:43:26Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugwui30qS9Ua7oZe4oV4AaABAg',
#   '@user-wk7ol5fc9l',
#   'Pas banget ketemu sama KPU RI ,,,<br> Itu apk siwaslu bagaimana , kenapa selalu gagal pas kirim laporan , apk kalian ini bodong atau bagaimana.???<br>Kalau tidak jelas mending tidur aja KPU , kita yang dibawah dibikin bingung semua dengan Apk yang tidak bisa digunakan.',
#   0,
#   0,
#   'http://www.youtube.com/@user-wk7ol5fc9l',
#   '2024-02-13T16:55:35Z',
#   '2024-02-13T16:55:35Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyFaAhfgUlFTLZGadl4AaABAg',
#   '@erlanggaattamimi5064',
#   'B di 0',
#   0,
#   0,
#   'http://www.youtube.com/@erlanggaattamimi5064',
#   '2024-02-12T19:22:43Z',
#   '2024-02-12T19:22:43Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgycvEeJue7baeqAKsl4AaABAg',
#   '@user-yj1cj2eq3s',
#   'Menhan di kuliahi sama pak anis',
#   0,
#   0,
#   'http://www.youtube.com/@user-yj1cj2eq3s',
#   '2024-02-12T18:59:39Z',
#   '2024-02-12T18:59:39Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgydigqsSaAv0xyp8W14AaABAg',
#   '@hendriafuk5438',
#   'Alhamdulillah.... 👍🙏🏻',
#   0,
#   0,
#   'http://www.youtube.com/@hendriafuk5438',
#   '2024-02-12T18:49:21Z',
#   '2024-02-12T18:49:21Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzJTvFWAhMyPhTf0TV4AaABAg',
#   '@hendriafuk5438',
#   'Alhamdulillah.... 😃😀👍🙏🏻',
#   0,
#   0,
#   'http://www.youtube.com/@hendriafuk5438',
#   '2024-02-12T18:48:36Z',
#   '2024-02-12T18:48:36Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwNblJhUhUSkqzve2h4AaABAg',
#   '@juruspamungkas1288',
#   '❤❤❤',
#   0,
#   0,
#   'http://www.youtube.com/@juruspamungkas1288',
#   '2024-02-12T18:42:13Z',
#   '2024-02-12T18:42:13Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugx97dQExpJJW_ZDKw94AaABAg',
#   '@juruspamungkas1288',
#   'Ll<br><br><br><br>L<br><br><br><br>L<br><br><br>L<br><br><br><br><br><br><br><br><br><br>L<br>L<br><br><br>L',
#   0,
#   0,
#   'http://www.youtube.com/@juruspamungkas1288',
#   '2024-02-12T18:41:38Z',
#   '2024-02-12T18:41:38Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzBib_LfubwELOjMMd4AaABAg',
#   '@lesleiop',
#   '(Ayo tonton biar tahu bagaimana pola kecurangan) tonton full biar g salah faham.',
#   0,
#   0,
#   'http://www.youtube.com/@lesleiop',
#   '2024-02-12T13:45:51Z',
#   '2024-02-12T13:45:51Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy2KNaOSFMznriHAvR4AaABAg',
#   '@ragequ1t944',
#   '<a href="https://www.youtube.com/watch?v=KJdt-HBBGIo&amp;t=3264">54:24</a> suara apaan itu ?',
#   0,
#   0,
#   'http://www.youtube.com/@ragequ1t944',
#   '2024-02-12T05:00:22Z',
#   '2024-02-12T05:00:22Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgznemV3zpyAo_11tVV4AaABAg',
#   '@Indraariadika',
#   'Mampus ajalah',
#   0,
#   0,
#   'http://www.youtube.com/@Indraariadika',
#   '2024-02-12T02:51:45Z',
#   '2024-02-12T02:51:45Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzP9E4fYm20qImslGt4AaABAg',
#   '@henysurya5111',
#   'Ini debat bukan rasa debat cawapres  yg hrsnya lbh ke visi mksi to rasa penyerangan ke mentri oeetahsnan bkn serang vidi misi cawapres',
#   1,
#   0,
#   'http://www.youtube.com/@henysurya5111',
#   '2024-02-12T01:38:06Z',
#   '2024-02-12T01:38:06Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz5_MpUylJxVVllmgJ4AaABAg',
#   '@RensKyYT',
#   'gaada waktu lain buat rilis kah, selain masa tenang 🗿',
#   0,
#   0,
#   'http://www.youtube.com/@RensKyYT',
#   '2024-02-12T00:21:18Z',
#   '2024-02-12T00:21:18Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzFAtiBeJuYJGBif7N4AaABAg',
#   '@stephanus_kw12345',
#   'Btw Ekonomi yang mana? Pada seret tuh Ekonomi kita😊😂',
#   0,
#   0,
#   'http://www.youtube.com/@stephanus_kw12345',
#   '2024-02-11T20:05:15Z',
#   '2024-02-11T20:05:15Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzPWEeRefKVwt1eWHF4AaABAg',
#   '@SitiNurJanni',
#   'Indonesia gak butuh makan siang dan susu gratis, tapi KORUPTOR musnah, bahan pokok dan BBM murah, juga pembangunan merata, itu yang Indonesia butuhkan, kita negara kaya raya, kenapa gak bisa dimanfaatkan dan merasa terjajah di negara sendiri🥴',
#   0,
#   0,
#   'http://www.youtube.com/@SitiNurJanni',
#   '2024-02-11T02:09:54Z',
#   '2024-02-11T02:09:54Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzS3IDHQwtXhbtY2oF4AaABAg',
#   '@user-rq4nv9cx6i',
#   'pak anies mewakili seluruh unek-unek para rakyaattt😇good pak anies👍☝',
#   0,
#   0,
#   'http://www.youtube.com/@user-rq4nv9cx6i',
#   '2024-02-10T04:00:12Z',
#   '2024-02-10T04:00:12Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgykTOqxvtLHxxKpbpB4AaABAg',
#   '@tynodam',
#   'strimer viral',
#   0,
#   0,
#   'http://www.youtube.com/@tynodam',
#   '2024-02-09T23:51:54Z',
#   '2024-02-09T23:51:54Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyQrgNCdUx8KEWmNe54AaABAg',
#   '@wong.desa.channel43',
#   'Ini perempuan ngakak bagus klu konten jangan nelpo sms video kol suami orang dak bagus',
#   0,
#   0,
#   'http://www.youtube.com/@wong.desa.channel43',
#   '2024-02-09T20:11:02Z',
#   '2024-02-09T20:11:02Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy0UVFirXh3tiukk3p4AaABAg',
#   '@user-cd7sd9gw6h',
#   'Dengan tidak memilih Anis, maka kita sudah menyelamatkan NKRI',
#   0,
#   0,
#   'http://www.youtube.com/@user-cd7sd9gw6h',
#   '2024-02-09T17:04:25Z',
#   '2024-02-09T17:04:25Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzyua620DXMOkeyh5N4AaABAg',
#   '@AntoStres88-ih3zn',
#   'Mengingatkan saja buat calon no 3..salam assalamualaikum dan salam agama yg lain lupa ya pak',
#   0,
#   0,
#   'http://www.youtube.com/@AntoStres88-ih3zn',
#   '2024-02-09T09:53:03Z',
#   '2024-02-09T09:53:03Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwDV2R4HfnHrWSJFN94AaABAg',
#   '@lukman4366',
#   'Cantiknya baju biry',
#   0,
#   0,
#   'http://www.youtube.com/@lukman4366',
#   '2024-02-09T00:29:09Z',
#   '2024-02-09T00:29:09Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwuNK0ZNg4Mga7Oxfx4AaABAg',
#   '@Ciwang858',
#   'Tetap semangat pak parabowo💪🏻',
#   0,
#   0,
#   'http://www.youtube.com/@Ciwang858',
#   '2024-02-08T17:56:57Z',
#   '2024-02-08T17:56:57Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzgStwXUrhuYsMop1Z4AaABAg',
#   '@mediabanjarjakutchannel',
#   'Jangan sampe salah pilih, salah pilih HTI bisa muncul lagi mengoyak keberagaman beragama di indonesia.',
#   0,
#   2,
#   'http://www.youtube.com/@mediabanjarjakutchannel',
#   '2024-02-08T16:34:15Z',
#   '2024-02-08T16:34:15Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyrBH6RgQmG0Xx9qqp4AaABAg',
#   '@fahrimuhammad4631',
#   'teman-teman KPU digaji oleh uang negara, tapi kenapa peraturan dirubah sesuai pesanan penguasa?',
#   0,
#   1,
#   'http://www.youtube.com/@fahrimuhammad4631',
#   '2024-02-08T09:27:52Z',
#   '2024-02-08T09:27:52Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy12TPaqyv3kGVmK_t4AaABAg',
#   '@fahrimuhammad4631',
#   'teman-teman KPU digaji oleh uang negara, tapi kenapa peraturan dirubah sesuai pesanan penguasa?',
#   0,
#   0,
#   'http://www.youtube.com/@fahrimuhammad4631',
#   '2024-02-08T09:27:47Z',
#   '2024-02-08T09:27:47Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyJQSP-v5N9-eVzdYx4AaABAg',
#   '@vaica_giran013',
#   'Fokus pada investasi tinggi akan mendorong inovasi dan pengembangan produk baru.',
#   0,
#   0,
#   'http://www.youtube.com/@vaica_giran013',
#   '2024-02-08T06:14:48Z',
#   '2024-02-08T06:14:48Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwjHL6yEvZb-x8ZREx4AaABAg',
#   '@user-oe9en4ln2l',
#   'Siapapun pilihanya Indonesia harus tetap DAMAI,RUKUN,SALING MENJAGA😁',
#   0,
#   0,
#   'http://www.youtube.com/@user-oe9en4ln2l',
#   '2024-02-08T05:45:15Z',
#   '2024-02-08T05:45:15Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyjIR2MhToGEWy7_bR4AaABAg',
#   '@sandinurkhoer9489',
#   'Gunakanlah etika yang baik saat berdebat',
#   0,
#   0,
#   'http://www.youtube.com/@sandinurkhoer9489',
#   '2024-02-08T04:50:42Z',
#   '2024-02-08T04:50:42Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugxoz7yjq1LueIv5kNJ4AaABAg',
#   '@sandinurkhoer9489',
#   'Pa anis terlalu mengorek pribadi Prabowo, bukan menanggapi visi misi nga',
#   0,
#   0,
#   'http://www.youtube.com/@sandinurkhoer9489',
#   '2024-02-08T04:50:13Z',
#   '2024-02-08T04:50:13Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy9Gj6Li64hWOOBbf94AaABAg',
#   '@gamegames7975',
#   'Oppa prabowo pensiun jokowidodo pensiun gibran pengusaha saja anies nggak jelas diduga, GAMA terpercaya merakyat🎉❤❤❤🙏🏻🙏🏻🙏🏻🙏🏻👍🏻👍🏻👍🏻👍🏻💪🏻💪🏻💪🏻💪🏻💪🏻💪🏻💪🏻💪🏻',
#   0,
#   0,
#   'http://www.youtube.com/@gamegames7975',
#   '2024-02-07T21:02:29Z',
#   '2024-02-07T21:02:29Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxRkrfpQdjKaQ_Q1KN4AaABAg',
#   '@user-ug4ek1co1u',
#   'Anis koclok jd RT aj',
#   0,
#   0,
#   'http://www.youtube.com/@user-ug4ek1co1u',
#   '2024-02-07T19:21:23Z',
#   '2024-02-07T19:21:23Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugzk3Ujb95ihzvXXP0Z4AaABAg',
#   '@user-vi8ds2fg6u',
#   'Senyumnya anis senyum merendahkan banget',
#   0,
#   0,
#   'http://www.youtube.com/@user-vi8ds2fg6u',
#   '2024-02-07T08:19:27Z',
#   '2024-02-07T08:19:27Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzMTjQiuzHndtyxEdB4AaABAg',
#   '@user-vi8ds2fg6u',
#   'Ko benci bgr anis si. Mukanya angkuhhh',
#   0,
#   0,
#   'http://www.youtube.com/@user-vi8ds2fg6u',
#   '2024-02-07T07:53:54Z',
#   '2024-02-07T07:53:54Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzdL6tqkAlEKisunwJ4AaABAg',
#   '@taufikkurohman6101',
#   '😮😅😅😅😅😅😮😮😅😅😅😮😅',
#   0,
#   0,
#   'http://www.youtube.com/@taufikkurohman6101',
#   '2024-02-07T03:07:05Z',
#   '2024-02-07T03:07:05Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwivoxNZaGecsRJBdp4AaABAg',
#   '@domidaeli8299',
#   'ngibul kau anis',
#   0,
#   0,
#   'http://www.youtube.com/@domidaeli8299',
#   '2024-02-06T21:07:09Z',
#   '2024-02-06T21:07:09Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugwp1io3mw5a9VezzgR4AaABAg',
#   '@muhaminuddin31',
#   'Gas Ampe meledak',
#   1,
#   0,
#   'http://www.youtube.com/@muhaminuddin31',
#   '2024-02-06T20:26:46Z',
#   '2024-02-06T20:26:46Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxOaiwOXjiqRccrjyF4AaABAg',
#   '@gimaabidin8586',
#   'Dari sini kita paham pentingnya belajar seperti membaca buku, belajar berorganisasi dll. Kinerja selama jadi menhan apa aja? Minimal bisa ngomong lah sangat lucu sekali tiap survei ko malah makin naik hahaha',
#   0,
#   0,
#   'http://www.youtube.com/@gimaabidin8586',
#   '2024-02-06T18:58:13Z',
#   '2024-02-06T18:58:13Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugz53fu4ceGgvyJVEEp4AaABAg',
#   '@infomaps8',
#   'Pembodohan tok jancok',
#   0,
#   0,
#   'http://www.youtube.com/@infomaps8',
#   '2024-02-06T15:48:53Z',
#   '2024-02-06T15:48:53Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzrR6wZbDAZIIe_SAV4AaABAg',
#   '@AlvarGie',
#   'Solidd🤟🤟🤟🤟🤟🤟🤟🤟🤟🤟',
#   0,
#   0,
#   'http://www.youtube.com/@AlvarGie',
#   '2024-02-06T14:28:23Z',
#   '2024-02-06T14:28:23Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwcbBgEmx_ns3bhgRd4AaABAg',
#   '@lyana7478',
#   'Lanjutkan ❤',
#   0,
#   0,
#   'http://www.youtube.com/@lyana7478',
#   '2024-02-06T12:48:04Z',
#   '2024-02-06T12:48:04Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwG-YEsmJqj_ISgdBF4AaABAg',
#   '@eatella',
#   'saya like konten ini karena Pak Anies',
#   0,
#   0,
#   'http://www.youtube.com/@eatella',
#   '2024-02-06T07:57:47Z',
#   '2024-02-06T07:57:47Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'Ugy5nR3OG1LW2xkUlw94AaABAg',
#   '@Minderwaardigheids',
#   'Nggak benar aturan KPU untuk PEMILU tahun 2024, potensi GOLPUT begitu besar dikarenakan kesulitan mengurus formulir A5, banyak warga negara yang kehilangan hak pilihnya tahun 2024 ini.',
#   0,
#   0,
#   'http://www.youtube.com/@Minderwaardigheids',
#   '2024-02-06T02:02:30Z',
#   '2024-02-06T02:02:30Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyzUBAzybDAshTE_QZ4AaABAg',
#   '@kolobolodwee6473',
#   'GWE GOLPUN DAN GUE BANGGA.<br><br>MAU GANTI SIAPA KEK . YA SAMA AJA DIRI KITA SNDRI KALAU MAU MAKAN YA HRS KERJA !!!',
#   0,
#   0,
#   'http://www.youtube.com/@kolobolodwee6473',
#   '2024-02-05T23:34:28Z',
#   '2024-02-05T23:34:28Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxmGMN2C5GPFmCCTVh4AaABAg',
#   '@ariesnexat8417',
#   'apa bisa di percaya ketuanya saja pelanggar etika',
#   0,
#   0,
#   'http://www.youtube.com/@ariesnexat8417',
#   '2024-02-05T18:22:34Z',
#   '2024-02-05T18:22:34Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgzA0NziNkVb3-XeENd4AaABAg',
#   '@BOKYAgacor',
#   'Siapa Pun PILIHAN KALIAN<br>SIAPAun yang  jadi Kelak... calon Presiden RI<br> Itulah yang tanggung Jawab umtuk Kita SEMUA.<br> Semoga jadi yang terbaik DI TAHUN INI Dan KEDEPANYA',
#   0,
#   0,
#   'http://www.youtube.com/@BOKYAgacor',
#   '2024-02-04T17:23:52Z',
#   '2024-02-04T17:23:52Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxR3_WSRMGonucLj_J4AaABAg',
#   '@nurlailatuhelelu4073',
#   '❤❤❤👍👍👍👍',
#   0,
#   0,
#   'http://www.youtube.com/@nurlailatuhelelu4073',
#   '2024-02-04T16:52:55Z',
#   '2024-02-04T16:52:55Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgyEz_HvR286RpoFP3Z4AaABAg',
#   '@gepengpeng3532',
#   '😊',
#   0,
#   0,
#   'http://www.youtube.com/@gepengpeng3532',
#   '2024-02-04T16:46:50Z',
#   '2024-02-04T16:46:50Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgwaN0IFMR1kucsMzYp4AaABAg',
#   '@syafaatzein7339',
#   'Selama ini perampasan hasil kekayaan alam oleh asih itu d sah kan oleh UUD dan dalam sistem demokerasi itu sah2 saja... Jadi sebenar nya akar masalah indonesia itu adalah pada sistem dan aturan yg kalian rekayasa...',
#   0,
#   0,
#   'http://www.youtube.com/@syafaatzein7339',
#   '2024-02-04T16:39:29Z',
#   '2024-02-04T16:39:29Z'],
#  ['KJdt-HBBGIo',
#   'UCVdSz86o9q2cQKvAQ5QhOYg',
#   'UgxRqmPrQ5jzqGD9Bq14AaABAg',
#   '@kedawolfch.',
#   'Prabowo untuk indonesia maju🔥✌🏻',
#   0,
#   0,
#   'http://www.youtube.com/@kedawolfch.',
#   '2024-02-04T15:29:22Z',
#   '2024-02-04T15:29:22Z']]

# %%
"""
Melakukan proses pengambilan data sebanyak 2.600 data rangkaian komentar utama dari video
debat babak ketiga capres-cawapres yang ditayangkan dan di-upload oleh channel Youtube KPU RI
"""
next_page_data_scraping = 2600


while len(list_third_video_debate_kpuri) < next_page_data_scraping:
    """
    Mendapatkan data-data komentar pada video YouTube debat babak ketiga calon
    Presiden-Wakil Presiden Indonesia dari channel YouTube KPU RI yang berada di halaman
    berikutnya (data-data setelah baris ke-100/indeks baris data ke-99)
    
    Di samping itu, "video_youtube_response" merupakan variabel yang menjalankan
    perintah untuk mendapatkan 100 data komentar dari video ID yang telah didefinisikan pada commentThreads().
    Itu berarti jumlah data yang akan diambil pada halaman-halaman berikutnya berjumlah 100 data komentar
    """
    try:
        nextPageToken = video_youtube_data_response["nextPageToken"]
    except KeyError:
        break
    nextPageToken = video_youtube_data_response["nextPageToken"]
    
    
    """
    Melakukan proses pengambilan objek kembali menggunakan fungsi "commentThreads()" atas data-data
    rangkaian komentar utama dari video YouTube berdasarkan identifikasi unik dari video tersebut yaitu ID Video yang membahas
    tentang debat capres-cawapres 2024. Namun yang membedakan antara "commentThreads()" sebelumnya dengan saat ini
    adalah jika "commentThreads()" sebelumnya hanya dapat mengambil jumlah maksimal data komentar yang ditentukan oleh
    Google YouTube Data API. Walaupun kita menginginkan lebih dari 100 data sehingga kita mendefinisikan nilai pada
    parameter "maxResults" yakni 270 komentar, 1.619 teks komentar, 9.390 komentar, dll., tetapi hasil akhirnya
    tidak berpengaruh terhadap jumlah data yang berhasil diambil dengan teknik data scraping pada video YouTube.
    Karena pada dasarnya service YouTube Data API v3 memiliki limit/batasan jumlah data yang dapat diambil dari
    suatu konten video YouTube yaitu hanya 100 komentar.
    
    Maka dari itu dengan menggunakan parameter baru yang terdapat di dalam "commentThreads()" yaitu parameter "pageToken"
    dengan nilai yakni nextPageToken, proses pengambilan data komentar lebih dari 100 sangat memungkinkan untuk dilakukan
    sebab nilai nextPageToken akan melakukan proses identifikasi, mencari dan mengambil data/informasi dari rangkaian
    komentar utama yang berada di halaman-halaman berikutnya selain data yang sebelumnya telah berhasil diambil
    menggunakan format default dari parameter maxResults yaitu hanya 100 data komentar sesuai limit dari API YouTube Data v3
    """
    nextRequest = youtube_scrape_comment_objects.commentThreads().list(
        part = "snippet", # snippet pada parameter part adalah objek list dari seluruh elemen yang dimiliki oleh komentar utama
        videoId = "KJdt-HBBGIo", # ID dari video debat babak ketiga capres-cawapres yang di-upload oleh channel YouTube KPU RI 
        #maxResults = 2600, # Jumlah data yang ingin diambil setelah 100 data berhasil di-scraping (sesuai dengan limit API)
        order = "time", # Permintaan untuk mendapatkan tanggal dan waktu komentar paling terbaru dari ID video
        pageToken = nextPageToken # Data selanjutnya akan diambil dari halaman-halaman selain halaman paling awal dari video
    )
    
    
    """
    Mengeksekusi proses permintaan untuk dapat mengambil data-data komentar yang berada
    di halaman-halaman berikutnya (selain 100 data komentar yang telah berhasil diambil pada script sebelumnya) dari video
    debat capres-cawapres babak ketiga yang di-upload oleh Channel YouTube KPU RI yang memiliki ID video yaitu KJdt-HBBGIo
    """
    video_youtube_data_response = nextRequest.execute()
    
    
    for item in video_youtube_data_response["items"]:
        video_id = item["snippet"]["videoId"] # Mendapatkan ID video debat babak ketiga capres-cawapres
        total_reply_count = item["snippet"]["totalReplyCount"] # Mendapatkan jumlah total balasan/reply dari komentar utama
        comment_id = item["id"] # Mendapatkan seluruh ID dari setiap teks komentar utama dari video debat babak ketiga
    
    
        """
        Mendapatkan seluruh elemen item per masing-masing komentar utama yang menjadi struktur
        pembentuk dasar dari komentar utama berdasarkan video ID yang sebelumnya telah diinisialisasikan.
        Jenis objek yang menjadi struktur/rangkaian detail atas masing-masing komentar utama adalah channel ID,
        teks komentar, jumlah like pada komentar tersebut, tanggal dan waktu dibuatnya komentar,
        nama akun user yang berkomentar di dalam video tersebut, dll

        Perlu diketahui jika elemen item yang terdapat pada top level comment dan commentThreads() berbeda tetapi
        dapat digabungkan menjadi satu kesatuan. Elemen seperti video id,
        jumlah user yang membalas/merespon teks komentar utama, dan lainnya
        termasuk di dalam elemen item yang dimiliki oleh commentThreads()
        karena sifatnya adalah informasi general dari rangkaian komentar utama

        Sedangkan elemen item yang dimiliki oleh top level comment lebih bersifat informasi yang spesifik yang dimiliki oleh
        masing-masing komentar utama atau komentar balasan atas komentar utama.
        Elemen item seperti nama user/akun yang berkomentar, isi atas masing-masing teks komentar yang dibuat oleh
        setiap akun yang berkomentar, jumlah user yang menyukai isi dari teks komentar utama, dan lainnya
        termasuk ke dalam item-item yang dimiliki oleh top level comment
        """
        comment_items = item["snippet"]["topLevelComment"]["snippet"]
    

        """
        Memasukkan atribut/elemen utama ke dalam variabel list kosong yaitu "list_third_video_debate_kpuri" yang akan
        berisikan beberapa objek item/elemen dari serangkaian komentar utama seperti ID video,
        ID Channel yang mem-publish/meng-upload video tersebut, nama akun user yang berkomentar beserta teks komentar,
        tanggal pembuatan komentar untuk video tersebut,
        jumlah total like sebagai bentuk respon setuju pada komentar yang telah dibuat oleh user, dll.

        Catatan tambahan bahwasanya variabel "video_id", "total_reply_count", "comment_id" dan "comment_items"
        termasuk ke dalam elemen utama yang akan dimasukkan ke dalam list kosong (empty list) yang bernama
        "list_third_video_debate_kpuri" yang nantinya list yang bernama "list_third_video_debate_kpuri"
        akan menjadi struktur kolom di dalam Pandas DataFrame
        """
        list_third_video_debate_kpuri.append([
            video_id, # Memasukkan ID video debat babak ketiga capres-cawapres yang di-upload oleh channel YouTube KPU RI
            comment_items["channelId"], # Memasukkan ID yang dimiliki oleh channel YouTube KPU RI ke dalam variabel list
            comment_id, # Memasukkan ID dari seluruh komentar yang dibuat oleh penonton video debat babak ketiga ke dalam list
            comment_items["authorDisplayName"], # Memasukkan seluruh nama akun YouTube yang berkomentar ke dalam empty list
            comment_items["textDisplay"], # Memasukkan teks komentar utama yang ada di dalam video debat ketiga ke dalam list
            comment_items["likeCount"], # Memasukkan jumlah total yang menyukai isi teks komentar utama ke dalam list
            total_reply_count, # Memasukkan jumlah total balasan yang diterima oleh teks komentar utama ke dalam empty list
            comment_items["authorChannelUrl"], # Memasukkan URL/link channel akun YouTube para penonton video debat babak ketiga
            comment_items["publishedAt"], # Memasukkan tanggal dan waktu saat teks komentar utama dibuat pertama kali oleh user
            comment_items["updatedAt"] # Memasukkan tanggal dan waktu saat teks komentar utama mengalami perubahan isi
        ])
        

"""
Menampilkan jumlah data yang dimiliki beberapa elemen item yang saat ini disimpan di dalam
variabel list "list_third_video_debate_kpuri" setelah dilakukan proses
penyeleksian (filter) atas beberapa elemen item dari serangkaian komentar utama dan juga telah
dilakukan proses looping request untuk mendapatkan data lebih dari 100 komentar
"""
print("Jumlah Data yang Dimiliki oleh Variabel List 'list_third_video_debate_kpuri' setelah Proses Looping adalah",
      len(list_third_video_debate_kpuri))
# Out:
# Jumlah Data yang Dimiliki oleh Variabel List 'list_third_video_debate_kpuri' setelah Proses Looping adalah 2692
