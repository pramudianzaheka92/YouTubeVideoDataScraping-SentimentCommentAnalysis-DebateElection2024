# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
##

API_Service_Name = "youtube"
API_Version = "v3"
API_KEY = "AIzaSyBLsMk7c30s8MbuSHQYQ7JfKiugTwgedTo"

youtube_scrape_comment_objects = build(API_Service_Name, API_Version, developerKey = API_KEY)

request = youtube_scrape_comment_objects.commentThreads().list(
    part="snippet",
    videoId="gUz_MgdwKg0",
    maxResults=10000
)

youtube_video_comments = [] # List kosong
response = request.execute()

for item in response["items"]:
    video_id = item["snippet"]["videoId"]
    
    video_comments1 = item["snippet"]["topLevelComment"]["snippet"]
    total_reply_count = item["snippet"]["totalReplyCount"]
    youtube_video_comments.append([
        video_id,
        video_comments1["channelId"],
        video_comments1["authorChannelUrl"],
        video_comments1["authorDisplayName"],
        video_comments1["publishedAt"],
        video_comments1["updatedAt"],
        video_comments1["likeCount"],
        video_comments1["textDisplay"],
        total_reply_count
    ])
    
while (1 == 1):
    try:
        nextPageToken = response["nextPageToken"]
    except KeyError:
        break
    nextPageToken = response["nextPageToken"]
    
    nextRequest = youtube_scrape_comment_objects.commentThreads().list(part = "snippet",
                                                                       videoId = "gUz_MgdwKg0",
                                                                       maxResults = 100,
                                                                       pageToken = nextPageToken)
    response = nextRequest.execute()
    for item in response["items"]:
        video_id = item["snippet"]["videoId"]
        video_comments1 = item["snippet"]["topLevelComment"]["snippet"]
        total_reply_count = item["snippet"]["totalReplyCount"]
        youtube_video_comments.append([
            video_id,
            video_comments1["channelId"],
            video_comments1["authorChannelUrl"],
            video_comments1["authorDisplayName"],
            video_comments1["publishedAt"],
            video_comments1["updatedAt"],
            video_comments1["likeCount"],
            video_comments1["textDisplay"],
            total_reply_count
        ])

# %%
    
    
data = pd.DataFrame(youtube_video_comments, columns=["video_id", "channel_id", "channel_url", "author",
                                                     "published_at", "updated_at", "like_count", "text_comment", "total_reply"])

data.head(15)
# Out:
#        video_id                channel_id  \
# 0   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 1   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 2   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 3   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 4   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 5   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 6   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 7   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 8   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 9   gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 10  gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 11  gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 12  gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 13  gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
# 14  gUz_MgdwKg0  UCo8h2TY_uBkAVUIc14m_KCA
#
#                                      channel_url                 author  \
# 0        http://www.youtube.com/@user-qf9nw7xo8g       @user-qf9nw7xo8g
# 1              http://www.youtube.com/@user-8154             @user-8154
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6901 entries, 0 to 6900
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      6901 non-null   object
#  1   channel_id    6901 non-null   object
#  2   channel_url   6901 non-null   object
#  3   author        6901 non-null   object
#  4   published_at  6901 non-null   object
#  5   updated_at    6901 non-null   object
#  6   like_count    6901 non-null   int64
#  7   text_comment  6901 non-null   object
#  8   total_reply   6901 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 485.4+ KB

# %%
data.to_excel("test123.xlsx", index=False)

# %%
print("Fetching Video Comment Youtube from Najwa Shihab Channel...")
youtube_video_comments = [] # Melakukan proses inisialisasi list kosong untuk menyimpan data-data komentar dari video youtube
nextPageToken = None

while len(youtube_video_comments) < 100:
    request = youtube_first_channel_object.commentThreads().list(
        part = "snippet",
        videoId = "gUz_MgdwKg0",
        maxResults = 100, # Hanya dapat melakukan proses pengambilan 100 data komentar untuk 1 video saja
        pageToken = nextPageToken
    )
    
    response = request.execute()
    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]
        #if comment["authorChannelId"]["value"] != uploader_channel_id:
        #    youtube_video_comments.append(comment["textDisplay"])
        nextPageToken = response.get("nextPageToken")
        
        if not nextPageToken:
            break
print(youtube_video_comments)
# Out:
# Fetching Video Comment Youtube from Najwa Shihab Channel...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 5>()
#       5 while len(youtube_video_comments) < 100:
#       6     request = youtube_first_channel_object.commentThreads().list(
#       7         part = "snippet",
#       8         videoId = "gUz_MgdwKg0",
#       9         maxResults = 100, # Hanya dapat melakukan proses pengambilan 100 data komentar untuk 1 video saja
#      10         pageToken = nextPageToken
#      11     )
# ---> 13     response = request.execute()
#      14     for item in response["items"]:
#      15         comment = item["snippet"]["topLevelComment"]["snippet"]
#
# File ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
# ...

# %%
API_KEY = "AIzaSyBLsMk7c30s8MbuSHQYQ7JfKiugTwgedTo"

youtube_first_channel_object = build("youtube", "v3", developerKey = API_KEY)
request = youtube_first_channel_object.commentThreads().list(
    part = "snippet",
    videoId = "gUz_MgdwKg0"
).execute()

# %%
def video_youtube_comments(video_id):
    youtube_video_comments = [] # Melakukan proses inisialisasi list kosong untuk menyimpan data-data komentar dari video youtube
    
    youtube = build("youtube", "v3", developerKey = api_key)
    
    video_response = youtube.commentThreads().list(part = "snippet,replies",
                                                   videoId = video_id).execute()

    while video_response:
        for item in video_response["items"]:
            
            channel_video = item["snippet"]["topLevelComment"]["snippet"]["channelId"]
            author_channel_link = item["snippet"]["topLevelComment"]["snippet"]["authorChannelUrl"]
            user = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]
            date_comment_publish = item["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
            date_updated_comment = item["snippet"]["topLevelComment"]["snippet"]["updatedAt"]
            like_count = item["snippet"]["topLevelComment"]["snippet"]["likeCount"]
            text_comment_video = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            
            youtube_video_comments.append([channel_video, author_channel_link, user,
                                           date_comment_publish, date_updated_comment, like_count, text_comment_video])
            
            replycount = item["snippet"]["totalReplyCount"]
            
            if replycount > 0:
                for reply in item["replies"]["comments"]:
                    date_comment_publish = reply['snippet']['publishedAt']
                    user = reply['snippet']['authorDisplayName']
                    text_reply = reply['snippet']['textDisplay']
                    likeCount = reply['snippet']['likeCount']
                    
                    youtube_video_comments.append([date_comment_publish, user, text_reply, likeCount])
            
            
        if "nextPageToken" in video_response:
            video_response = youtube_first_channel_object.commentThreads().list(
                part = "snippet, replies",
                pageToken = video_response["nextPageToken"],
                videoId = video_id
            ).execute()
        else:
            break
        return youtube_video_comments

# %%
api_key = "AIzaSyBLsMk7c30s8MbuSHQYQ7JfKiugTwgedTo"

video_id = "gUz_MgdwKg0"

comments = video_youtube_comments(video_id)

print(comments)
# Out:
# [['UCo8h2TY_uBkAVUIc14m_KCA', 'http://www.youtube.com/@user-qf9nw7xo8g', '@user-qf9nw7xo8g', '2024-03-09T02:42:22Z', '2024-03-09T02:42:22Z', 1, 'Saya kesini lagi'], ['UCo8h2TY_uBkAVUIc14m_KCA', 'http://www.youtube.com/@user-8154', '@user-8154', '2024-03-07T15:17:25Z', '2024-03-07T15:17:25Z', 0, 'Lagi nyari ketika statement Bung Maman viral di SHORT &quot;Pak Prabowo bukan Superman......&quot;'], ['UCo8h2TY_uBkAVUIc14m_KCA', 'http://www.youtube.com/@fasmaulmursolina9902', '@fasmaulmursolina9902', '2024-03-03T14:01:17Z', '2024-03-03T14:01:17Z', 0, 'ronde 2 mana ya'], ['UCo8h2TY_uBkAVUIc14m_KCA', 'http://www.youtube.com/@bobamochi2679', '@bobamochi2679', '2024-02-23T21:13:45Z', '2024-02-23T21:13:45Z', 0, 'Bismillah Anies Baswedan. Salam perubahan!'], ['UCo8h2TY_uBkAVUIc14m_KCA', 'http://www.youtube.com/@muhammadhasan3622', '@muhammadhasan3622', '2024-02-18T12:55:19Z', '2024-02-18T12:55:19Z', 1, 'Kok bisa si orang orang-orang pada dukung prabowo'], ['UCo8h2TY_uBkAVUIc14m_KCA', 'http://ww
# ...

# %%
data = pd.DataFrame(first_video_comment, columns=["Channel ID", "Channel URL", "Author", "Published_At", "Updated_At", "Like_Count", "text_Comment"])

data.head(15)
# Out:
#                   Channel ID                                   Channel URL  \
# 0   UCo8h2TY_uBkAVUIc14m_KCA       http://www.youtube.com/@user-qf9nw7xo8g
# 1   UCo8h2TY_uBkAVUIc14m_KCA             http://www.youtube.com/@user-8154
# 2   UCo8h2TY_uBkAVUIc14m_KCA  http://www.youtube.com/@fasmaulmursolina9902
# 3   UCo8h2TY_uBkAVUIc14m_KCA         http://www.youtube.com/@bobamochi2679
# 4   UCo8h2TY_uBkAVUIc14m_KCA     http://www.youtube.com/@muhammadhasan3622
# 5   UCo8h2TY_uBkAVUIc14m_KCA           http://www.youtube.com/@aeyshamy457
# 6   UCo8h2TY_uBkAVUIc14m_KCA        http://www.youtube.com/@RageboySaputra
# 7   UCo8h2TY_uBkAVUIc14m_KCA       http://www.youtube.com/@user-jo3nc8bx5s
# 8   UCo8h2TY_uBkAVUIc14m_KCA       http://www.youtube.com/@user-jo3nc8bx5s
# 9   UCo8h2TY_uBkAVUIc14m_KCA       http://www.youtube.com/@user-jo3nc8bx5s
# 10  UCo8h2TY_uBkAVUIc14m_KCA     http://www.youtube.com/@ibnusholichan3065
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Channel ID    20 non-null     object
#  1   Channel URL   20 non-null     object
#  2   Author        20 non-null     object
#  3   Published_At  20 non-null     object
#  4   Updated_At    20 non-null     object
#  5   Like_Count    20 non-null     int64
#  6   text_Comment  20 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB
